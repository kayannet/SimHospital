# %% [markdown]
# Setup

# %%
# Load libraries
library(simmer)
library(simmer.plot)
library(tidyverse)
library(tidymodels)

# Set seed for reproducibility
set.seed(42)
# Out:
# ── Attaching packages ────────────────────────────────────── tidymodels 1.4.1 ──
#
# ✔ broom        1.0.10     ✔ rsample      1.3.1
# ✔ dials        1.4.2      ✔ tailor       0.1.0
# ✔ infer        1.0.9      ✔ tune         2.0.1
# ✔ modeldata    1.5.1      ✔ workflows    1.3.0
# ✔ parsnip      1.3.3      ✔ workflowsets 1.1.1
# ✔ recipes      1.3.1      ✔ yardstick    1.3.2
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ dplyr::select()   masks simmer::select()
# ✖ tidyr::separate() masks simmer::separate()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
# Load MIMIC-IV data

# Define data directory
# data_dir <- "~/Desktop/MIMIC_ED/processed/"
data_dir <- "../../../MIMIC_ED/processed/" 


# Load all four tables
ed_stays <- read_csv(paste0(data_dir, "ed_stays.csv"))
ed_activities <- read_csv(paste0(data_dir, "ed_activity_log.csv"))
ed_diagnoses <- read_csv(paste0(data_dir, "ed_diagnoses.csv"))
ed_medications <- read_csv(paste0(data_dir, "ed_medications.csv"))


# query medcount per stay
med_count_per_stay <- ed_medications %>%
  group_by(stay_id) %>%
  summarise(medication_count = n())
# Out:
# Rows: 425028 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): gender, race, arrival_transport, disposition, chiefcomplaint
# dbl  (5): stay_id, subject_id, hadm_id, acuity, ed_los_hours
# lgl  (1): is_admitted
# dttm (3): arrival_time, triage_time, depart_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3737756 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): activity
# dbl  (5): stay_id, subject_id, hadm_id, acuity, activity_seq
# dttm (1): timestamps
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 898730 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): icd_code, icd_title
# dbl (3): stay_id, subject_id, icd_version
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3607490 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): medication_name, gsn, ndc
# dbl  (2): stay_id, subject_id
# dttm (1): timestamps
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# DATA CLEANING FOR ED SIMULATION

# Filter for admitted patients only
ed_admitted <- ed_stays %>%
  filter(is_admitted == TRUE) %>%
  mutate(
    los_minutes = ed_los_hours * 60,
    los_minutes = if_else(is.na(los_minutes) | los_minutes <= 0, 
                          median(los_minutes, na.rm = TRUE), 
                          los_minutes)
  )

# Check for inconsistencies
inconsistencies <- ed_stays %>%
  filter(disposition == "ADMITTED" & is_admitted == FALSE) %>%
  nrow()

cat("\n=== DATA QUALITY CHECKS ===\n")
cat("Inconsistent records (disposition=ADMITTED but is_admitted=FALSE):", inconsistencies, "\n")

# Overall statistics
total_visits <- nrow(ed_stays)
total_admitted <- nrow(ed_admitted)
admission_rate <- round(100 * total_admitted / total_visits, 1)

cat("\n=== COHORT SUMMARY ===\n")
cat("Total ED visits:", format(total_visits, big.mark = ","), "\n")
cat("Admitted patients:", format(total_admitted, big.mark = ","), 
    "(", admission_rate, "%)\n")

# LOS distribution for admitted patients
cat("\n=== LOS DISTRIBUTION (Admitted Patients) ===\n")
cat("Minutes:\n")
print(summary(ed_admitted$los_minutes))
cat("\nHours:\n")
print(summary(ed_admitted$ed_los_hours))

# Calculate 80th percentile threshold
los_threshold_80 <- quantile(ed_admitted$los_minutes, 0.80, na.rm = TRUE)
cat("\n=== TRANSFER THRESHOLD (for Phase 2) ===\n")
cat("80th percentile:", round(los_threshold_80, 2), "minutes")
cat(" (", round(los_threshold_80/60, 2), "hours)\n")

# Visualize real MIMIC distribution
ggplot(ed_admitted, aes(x = los_minutes)) +
  geom_histogram(bins = 50, fill = "steelblue", color = "white", alpha = 0.8) +
  geom_vline(aes(xintercept = mean(los_minutes, na.rm = TRUE)), 
             color = "red", linetype = "dashed", linewidth = 1) +
  geom_vline(aes(xintercept = los_threshold_80), 
             color = "orange", linetype = "dashed", linewidth = 1) +
  labs(
    title = "MIMIC-IV: Distribution of LOS for Admitted ED Patients",
    subtitle = "Red = mean | Orange = 80th percentile (future transfer threshold)",
    x = "Length of Stay (minutes)",
    y = "Count of Patients"
  ) +
  theme_minimal() +
  theme(plot.title = element_text(face = "bold"))
# Out:
# === DATA QUALITY CHECKS ===
# Inconsistent records (disposition=ADMITTED but is_admitted=FALSE): 0
#
# === COHORT SUMMARY ===
# Total ED visits: 425,028
# Admitted patients: 158,010 ( 37.2 %)
#
# === LOS DISTRIBUTION (Admitted Patients) ===
# Minutes:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0   260.0   374.0   436.6   527.0 29584.2
#
# Hours:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#   0.0167   4.3333   6.2333   7.2772   8.7833 493.0694
#
# === TRANSFER THRESHOLD (for Phase 2) ===
# 80th percentile: 573 minutes ( 9.55 hours)
# plot without title

# %% [markdown]
# Parameters

# %%
# function that simplifies race into 6 main categories (the model uses it so it needs to be defined here)
simplify_race <- function(r) {
  r <- toupper(as.character(r))
  
  if (grepl("WHITE", r)) {
    "WHITE"
  } else if (grepl("BLACK", r) || grepl("AFRICAN", r)) {
    "BLACK"
  } else if (grepl("HISPANIC", r) || grepl("LATINO", r)) {
    "HISPANIC"
  } else if (grepl("ASIAN", r)) {
    "ASIAN"
  } else if (grepl("NATIVE", r) || grepl("PACIFIC", r) || grepl("ALASKA", r)) {
    "NATIVE/PI"
  } else {
    "OTHER"
  }
}

simplify_race_vec <- function(r) {
  sapply(r, simplify_race)
}

# log_hosp_los_hours ~ acuity + race + gender + ed_los_hours + medication_count
mod <- readRDS("../models/model_v1.rds")

# %%
# Resource capacities (start with infinite as Karandeep suggested)
ED_BED_CAPACITY <- Inf

# Time distributions using MIMIC IV data
los_time <- function() sample(ed_admitted$los_minutes, 1)



# Arrival rate (placeholder, used Karandeep's code ~3.33 patients per hour)
arrival_interval <- function() rexp(1, 1/(18/60))

# Store the transfer threshold for Phase 2
LOS_TRANSFER_THRESHOLD <- los_threshold_80

cat("   - LOS: Sampling from", format(nrow(ed_admitted), big.mark = ","), 
    "admitted patient records\n")
cat("   - Mean LOS:", round(mean(ed_admitted$los_minutes), 1), "minutes",
    "(", round(mean(ed_admitted$los_minutes)/60, 2), "hours)\n")
cat("   - Transfer threshold:", round(LOS_TRANSFER_THRESHOLD, 1), "minutes",
    "(", round(LOS_TRANSFER_THRESHOLD/60, 2), "hours)\n")
# Out:
#    - LOS: Sampling from 158,010 admitted patient records
#    - Mean LOS: 436.6 minutes ( 7.28 hours)
#    - Transfer threshold: 573 minutes ( 9.55 hours)

# %% [markdown]
# Patient Trajectory

# %%
# Create an empty tibble to store results
hospital_los_log <- tibble(patient_id = integer(), pred_hosp_los = numeric())

# Counter for patient IDs
patient_counter <- 0

# %%
# Define patient flow through ED
patient_trajectory <- trajectory("ED patient flow") %>%
  seize("ed_bed", 1) %>%              # Patient occupies ED bed
  timeout(los_time) %>%               # Stay for length of stay
  release("ed_bed", 1) %>%               # Leave ED (disposition)

# Predict hospital LOS and store it
  log_(function() {
    patient_counter <<- patient_counter + 1  # increment patient ID
    
    # Sample predictors
    new_patient <- tibble(
      acuity = sample(ed_stays$acuity, 1),
      race = sample(ed_stays$race, 1),
      gender = sample(ed_stays$gender, 1),
      ed_los_hours = sample(ed_stays$ed_los_hours, 1),
      medication_count = sample(med_count_per_stay$medication_count, 1)
    )
    
    # Predict hospital LOS
    pred_hours <- predict(mod, new_data = new_patient)$.pred %>% expm1()
    
    # Save to tibble
    hospital_los_log <<- bind_rows(
      hospital_los_log,
      tibble(patient_id = patient_counter, pred_hosp_los = pred_hours)
    )
    
    paste("Patient", patient_counter, "predicted hospital LOS:", round(pred_hours, 1))
    
  })

# %% [markdown]
# Build Sim Environment

# %%
# Create environment
ed_sim <- simmer("ED Simulation V1")

# Add resources
ed_sim %>%
  add_resource("ed_bed", capacity = ED_BED_CAPACITY)

# Add patient generator
ed_sim %>%
  add_generator("patient", patient_trajectory, arrival_interval, mon = 2)
# Out:
# simmer environment: ED Simulation V1 | now: 0 | next:
# { Monitor: in memory }
# { Resource: ed_bed | monitored: TRUE | server status: 0(Inf) | queue status: 0(Inf) }
# simmer environment: ED Simulation V1 | now: 0 | next: 0
# { Monitor: in memory }
# { Resource: ed_bed | monitored: TRUE | server status: 0(Inf) | queue status: 0(Inf) }
# { Source: patient | monitored: 2 | n_generated: 0 }

# %% [markdown]
# Run Sim

# %%
# Run for 24 hours (1440 minutes)
ed_sim %>% run(until = 1440)

# Check final time
simmer::now(ed_sim)
# Out:
# 65.8912: patient98: Patient 1 predicted hospital LOS: 72.3
# 90.9503: patient90: Patient 2 predicted hospital LOS: 44.5
# 105.527: patient44: Patient 3 predicted hospital LOS: 65.9
# 107.893: patient4: Patient 4 predicted hospital LOS: 86.6
# 118.308: patient58: Patient 5 predicted hospital LOS: 12.3
# 124.811: patient85: Patient 6 predicted hospital LOS: 56.7
# 135.342: patient121: Patient 7 predicted hospital LOS: 80.9
# 135.745: patient311: Patient 8 predicted hospital LOS: 33.7
# 143.974: patient185: Patient 9 predicted hospital LOS: 28.9
# 180.633: patient291: Patient 10 predicted hospital LOS: 89.3
# 181.058: patient281: Patient 11 predicted hospital LOS: 68.6
# 183.186: patient23: Patient 12 predicted hospital LOS: 75
# 185.575: patient41: Patient 13 predicted hospital LOS: 61.5
# 194.055: patient258: Patient 14 predicted hospital LOS: 26
# 198.381: patient37: Patient 15 predicted hospital LOS: 65.7
# 200.747: patient301: Patient 16 predicted hospital LOS: 34.3
# 203.667: patient226: Patient 17 predicted hospital LOS: 58
# 206.11: patient183: Patient 18 predicted hospital LOS: 70.7
# 207.006: patient109: Patient 19 predicted hospital LOS: 61
# 209.782: patient80: Patient 20 predicted hospital LOS: 80.8
# 210.199: patient20: Patient 21 predicted hospital LOS: 18.9
# 212.824: patient286: Patient 22 predicted hospital LOS: 41.1
# 220.694: patient48: Patient 23 predicted hospital LOS: 40.6
# 223.901: patient141: Patient 24 predicted hospital LOS: 59.6
# 224.313: patient491: Patient 25 predicted hospital LOS: 58.2
# 225.008: patient17: Patient 26 predicted hospital LOS: 84.3
# 225.583: patient253: Patient 27 predicted hospital LOS: 85.7
# 226.207: patient89: Patient 28 predicted hospital LOS: 8.1
# 227.059: patient161: Patient 29 predicted hospital LOS: 41.6
# 228.355: patient83: Patient 30 predicted hospital LOS: 48.4
# 231.296: patient315: Patient 31 predicted hospital LOS: 75.9
# 232.204: patient578: Patient 32 predicted hospital LOS: 31.5
# 233.795: patient15: Patient 33 predicted hospital LOS: 214.2
# 234.834: patient7: Patient 34 predicted hospital LOS: 75.4
# 234.841: patient60: Patient 35 predicted hospital LOS: 76.9
# 235.836: patient458: Patient 36 predicted hospital LOS: 27.4
# 236.076: patient383: Patient 37 predicted hospital LOS: 68.9
# 236.746: patient26: Patient 38 predicted hospital LOS: 87.4
# 239.065: patient66: Patient 39 predicted hospital LOS: 44.6
# 239.745: patient347: Patient 40 predicted hospital LOS: 61
# 239.98: patient129: Patient 41 predicted hospital LOS: 59.4
# 240.99: patient8: Patient 42 predicted hospital LOS: 81.4
# 241.721: patient345: Patient 43 predicted hospital LOS: 39.1
# 242.954: patient127: Patient 44 predicted hospital LOS: 41.2
# 246.22: patient217: Patient 45 predicted hospital LOS: 69.8
# 246.284: patient50: Patient 46 predicted hospital LOS: 104.5
# 246.288: patient433: Patient 47 predicted hospital LOS: 61.9
# 246.88: patient134: Patient 48 predicted hospital LOS: 26.3
# 247.409: patient190: Patient 49 predicted hospital LOS: 69.7
# 248.739: patient156: Patient 50 predicted hospital LOS: 91.9
# 248.992: patient423: Patient 51 predicted hospital LOS: 59
# 251.041: patient213: Patient 52 predicted hospital LOS: 53.2
# 251.135: patient111: Patient 53 predicted hospital LOS: 12.2
# 251.901: patient266: Patient 54 predicted hospital LOS: 81.7
# 252.767: patient312: Patient 55 predicted hospital LOS: 50.3
# 254.692: patient611: Patient 56 predicted hospital LOS: 96
# 254.836: patient394: Patient 57 predicted hospital LOS: 93
# 255.813: patient74: Patient 58 predicted hospital LOS: 41.2
# 256.041: patient68: Patient 59 predicted hospital LOS: 30.8
# 259.918: patient444: Patient 60 predicted hospital LOS: 40.8
# 260.484: patient439: Patient 61 predicted hospital LOS: 64.8
# 261.226: patient16: Patient 62 predicted hospital LOS: 100.8
# 261.29: patient3: Patient 63 predicted hospital LOS: 58.3
# 261.971: patient295: Patient 64 predicted hospital LOS: 36.1
# 263.12: patient397: Patient 65 predicted hospital LOS: 80.9
# 263.988: patient92: Patient 66 predicted hospital LOS: 20.9
# 264.428: patient602: Patient 67 predicted hospital LOS: 27.3
# 266.356: patient43: Patient 68 predicted hospital LOS: 33.4
# 266.38: patient40: Patient 69 predicted hospital LOS: 67.5
# 267.179: patient47: Patient 70 predicted hospital LOS: 32.2
# 268.197: patient152: Patient 71 predicted hospital LOS: 103.8
# 270.234: patient770: Patient 72 predicted hospital LOS: 58.4
# 270.392: patient1: Patient 73 predicted hospital LOS: 27.3
# 270.887: patient222: Patient 74 predicted hospital LOS: 39.7
# 271.697: patient623: Patient 75 predicted hospital LOS: 43.7
# 273.355: patient139: Patient 76 predicted hospital LOS: 15.6
# 274.02: patient53: Patient 77 predicted hospital LOS: 77.1
# 275.504: patient22: Patient 78 predicted hospital LOS: 98.3
# 275.916: patient125: Patient 79 predicted hospital LOS: 66.5
# 275.953: patient57: Patient 80 predicted hospital LOS: 95.8
# 276.043: patient273: Patient 81 predicted hospital LOS: 21.5
# 276.306: patient51: Patient 82 predicted hospital LOS: 47.8
# 276.779: patient360: Patient 83 predicted hospital LOS: 50.3
# 277.369: patient24: Patient 84 predicted hospital LOS: 58.7
# 277.51: patient703: Patient 85 predicted hospital LOS: 63.8
# 278.02: patient178: Patient 86 predicted hospital LOS: 67.8
# 281.997: patient714: Patient 87 predicted hospital LOS: 72.3
# 283.126: patient42: Patient 88 predicted hospital LOS: 27.8
# 287.418: patient243: Patient 89 predicted hospital LOS: 95.5
# 289.293: patient460: Patient 90 predicted hospital LOS: 29.8
# 289.622: patient342: Patient 91 predicted hospital LOS: 21.6
# 293.132: patient119: Patient 92 predicted hospital LOS: 52.9
# 295.514: patient170: Patient 93 predicted hospital LOS: 55.5
# 295.702: patient555: Patient 94 predicted hospital LOS: 37.2
# 297.234: patient794: Patient 95 predicted hospital LOS: 67.6
# 298.95: patient277: Patient 96 predicted hospital LOS: 64.4
# 299.084: patient306: Patient 97 predicted hospital LOS: 61.8
# 299.415: patient503: Patient 98 predicted hospital LOS: 83.5
# 300.101: patient157: Patient 99 predicted hospital LOS: 32.3
# 300.566: patient375: Patient 100 predicted hospital LOS: 67.1
# 302.717: patient259: Patient 101 predicted hospital LOS: 74.7
# 304.722: patient67: Patient 102 predicted hospital LOS: 38.5
# 305.957: patient107: Patient 103 predicted hospital LOS: 102.7
# 306.357: patient302: Patient 104 predicted hospital LOS: 25
# 306.561: patient103: Patient 105 predicted hospital LOS: 43.2
# 307.396: patient52: Patient 106 predicted hospital LOS: 72.5
# 307.51: patient257: Patient 107 predicted hospital LOS: 30.1
# 307.535: patient108: Patient 108 predicted hospital LOS: 59.8
# 307.648: patient386: Patient 109 predicted hospital LOS: 71.2
# 307.971: patient280: Patient 110 predicted hospital LOS: 82.4
# 309.228: patient94: Patient 111 predicted hospital LOS: 53.8
# 309.427: patient64: Patient 112 predicted hospital LOS: 53.1
# 310.007: patient300: Patient 113 predicted hospital LOS: 36.3
# 311.623: patient220: Patient 114 predicted hospital LOS: 36.1
# 311.917: patient754: Patient 115 predicted hospital LOS: 92
# 313.821: patient450: Patient 116 predicted hospital LOS: 20.6
# 314.769: patient150: Patient 117 predicted hospital LOS: 17.2
# 314.812: patient21: Patient 118 predicted hospital LOS: 75.7
# 314.831: patient204: Patient 119 predicted hospital LOS: 72.3
# 319.379: patient6: Patient 120 predicted hospital LOS: 69.7
# 320.898: patient241: Patient 121 predicted hospital LOS: 53.2
# 320.927: patient77: Patient 122 predicted hospital LOS: 70.4
# 321.327: patient379: Patient 123 predicted hospital LOS: 52
# 321.761: patient131: Patient 124 predicted hospital LOS: 24.2
# 322.683: patient229: Patient 125 predicted hospital LOS: 71.8
# 324.127: patient270: Patient 126 predicted hospital LOS: 25.1
# 324.825: patient165: Patient 127 predicted hospital LOS: 37.5
# 325.065: patient261: Patient 128 predicted hospital LOS: 56.5
# 325.123: patient224: Patient 129 predicted hospital LOS: 104.7
# 326.156: patient293: Patient 130 predicted hospital LOS: 41.9
# 327.196: patient688: Patient 131 predicted hospital LOS: 86.3
# 328.194: patient169: Patient 132 predicted hospital LOS: 43.6
# 328.312: patient31: Patient 133 predicted hospital LOS: 20.1
# 330.727: patient359: Patient 134 predicted hospital LOS: 69.6
# 331.142: patient672: Patient 135 predicted hospital LOS: 106.7
# 331.902: patient424: Patient 136 predicted hospital LOS: 47.7
# 332.237: patient231: Patient 137 predicted hospital LOS: 58.1
# 334.642: patient35: Patient 138 predicted hospital LOS: 30.2
# 336.288: patient489: Patient 139 predicted hospital LOS: 62.3
# 337.567: patient357: Patient 140 predicted hospital LOS: 60.5
# 338.375: patient319: Patient 141 predicted hospital LOS: 56.9
# 338.906: patient404: Patient 142 predicted hospital LOS: 75.4
# 339.291: patient329: Patient 143 predicted hospital LOS: 67.8
# 339.895: patient271: Patient 144 predicted hospital LOS: 109.5
# 340.286: patient54: Patient 145 predicted hospital LOS: 94.9
# 340.475: patient370: Patient 146 predicted hospital LOS: 68.6
# 340.756: patient180: Patient 147 predicted hospital LOS: 66.6
# 341.859: patient32: Patient 148 predicted hospital LOS: 39.9
# 344.101: patient245: Patient 149 predicted hospital LOS: 48
# 344.702: patient13: Patient 150 predicted hospital LOS: 25.5
# 345.569: patient481: Patient 151 predicted hospital LOS: 54.7
# 346.152: patient560: Patient 152 predicted hospital LOS: 78.1
# 346.441: patient377: Patient 153 predicted hospital LOS: 39.3
# 346.631: patient179: Patient 154 predicted hospital LOS: 55.7
# 348.344: patient207: Patient 155 predicted hospital LOS: 18.9
# 348.807: patient284: Patient 156 predicted hospital LOS: 28.1
# 349.199: patient438: Patient 157 predicted hospital LOS: 64.7
# 350.045: patient372: Patient 158 predicted hospital LOS: 37
# 350.67: patient184: Patient 159 predicted hospital LOS: 54.4
# 351.37: patient102: Patient 160 predicted hospital LOS: 49.3
# 351.779: patient417: Patient 161 predicted hospital LOS: 76.9
# 351.787: patient279: Patient 162 predicted hospital LOS: 45.9
# 352.182: patient274: Patient 163 predicted hospital LOS: 70.3
# 352.283: patient333: Patient 164 predicted hospital LOS: 18.8
# 352.668: patient12: Patient 165 predicted hospital LOS: 18.7
# 352.862: patient322: Patient 166 predicted hospital LOS: 76
# 353.096: patient267: Patient 167 predicted hospital LOS: 83.4
# 353.331: patient526: Patient 168 predicted hospital LOS: 44.8
# 354.391: patient469: Patient 169 predicted hospital LOS: 82.1
# 354.861: patient584: Patient 170 predicted hospital LOS: 44.8
# 355.959: patient101: Patient 171 predicted hospital LOS: 61.9
# 356.234: patient117: Patient 172 predicted hospital LOS: 84.5
# 356.465: patient46: Patient 173 predicted hospital LOS: 74.5
# 356.551: patient706: Patient 174 predicted hospital LOS: 37.3
# 358.202: patient704: Patient 175 predicted hospital LOS: 45.4
# 358.278: patient149: Patient 176 predicted hospital LOS: 41.3
# 358.771: patient114: Patient 177 predicted hospital LOS: 48.1
# 359.109: patient61: Patient 178 predicted hospital LOS: 39
# 359.134: patient478: Patient 179 predicted hospital LOS: 68
# 359.291: patient685: Patient 180 predicted hospital LOS: 67
# 360.519: patient784: Patient 181 predicted hospital LOS: 43.3
# 360.586: patient30: Patient 182 predicted hospital LOS: 88.8
# 360.844: patient305: Patient 183 predicted hospital LOS: 64.2
# 361.307: patient499: Patient 184 predicted hospital LOS: 88.6
# 361.593: patient320: Patient 185 predicted hospital LOS: 66.3
# 361.64: patient225: Patient 186 predicted hospital LOS: 63.1
# 362.955: patient325: Patient 187 predicted hospital LOS: 111.1
# 363.149: patient255: Patient 188 predicted hospital LOS: 37.8
# 363.603: patient788: Patient 189 predicted hospital LOS: 50.7
# 363.925: patient65: Patient 190 predicted hospital LOS: 224.5
# 364.031: patient172: Patient 191 predicted hospital LOS: 55.6
# 364.072: patient581: Patient 192 predicted hospital LOS: 71
# 364.888: patient353: Patient 193 predicted hospital LOS: 72.5
# 365.373: patient5: Patient 194 predicted hospital LOS: 63.4
# 365.449: patient837: Patient 195 predicted hospital LOS: 81.3
# 366.77: patient454: Patient 196 predicted hospital LOS: 97.3
# 368.15: patient338: Patient 197 predicted hospital LOS: 70.4
# 368.178: patient673: Patient 198 predicted hospital LOS: 62.3
# 369.181: patient666: Patient 199 predicted hospital LOS: 31.7
# 370.792: patient27: Patient 200 predicted hospital LOS: 31.5
# 371.106: patient323: Patient 201 predicted hospital LOS: 20.8
# 371.501: patient209: Patient 202 predicted hospital LOS: 89.6
# 372.294: patient476: Patient 203 predicted hospital LOS: 53.3
# 372.73: patient45: Patient 204 predicted hospital LOS: 74.9
# 373.051: patient504: Patient 205 predicted hospital LOS: 40.9
# 373.209: patient490: Patient 206 predicted hospital LOS: 36.8
# 373.469: patient600: Patient 207 predicted hospital LOS: 34.7
# 373.536: patient705: Patient 208 predicted hospital LOS: 30.4
# 374.02: patient110: Patient 209 predicted hospital LOS: 48.8
# 374.518: patient782: Patient 210 predicted hospital LOS: 108
# 374.553: patient395: Patient 211 predicted hospital LOS: 24.7
# 374.795: patient630: Patient 212 predicted hospital LOS: 85.7
# 374.8: patient211: Patient 213 predicted hospital LOS: 54.8
# 375.13: patient722: Patient 214 predicted hospital LOS: 39.6
# 375.371: patient304: Patient 215 predicted hospital LOS: 89.8
# 376.07: patient488: Patient 216 predicted hospital LOS: 41.8
# 377.34: patient670: Patient 217 predicted hospital LOS: 103.1
# 378.423: patient619: Patient 218 predicted hospital LOS: 31.8
# 379.421: patient208: Patient 219 predicted hospital LOS: 83
# 379.89: patient825: Patient 220 predicted hospital LOS: 72.5
# 379.942: patient409: Patient 221 predicted hospital LOS: 54.4
# 381.241: patient373: Patient 222 predicted hospital LOS: 24.2
# 383.242: patient176: Patient 223 predicted hospital LOS: 66.3
# 383.625: patient622: Patient 224 predicted hospital LOS: 19.7
# 383.752: patient227: Patient 225 predicted hospital LOS: 19.5
# 385.605: patient104: Patient 226 predicted hospital LOS: 24.4
# 386.03: patient14: Patient 227 predicted hospital LOS: 93.2
# 386.48: patient203: Patient 228 predicted hospital LOS: 74
# 386.551: patient859: Patient 229 predicted hospital LOS: 43.9
# 386.645: patient928: Patient 230 predicted hospital LOS: 63.6
# 387.889: patient118: Patient 231 predicted hospital LOS: 63.5
# 388.196: patient228: Patient 232 predicted hospital LOS: 59.5
# 388.532: patient767: Patient 233 predicted hospital LOS: 59
# 388.612: patient330: Patient 234 predicted hospital LOS: 43.5
# 389.241: patient781: Patient 235 predicted hospital LOS: 56.2
# 389.592: patient146: Patient 236 predicted hospital LOS: 55.4
# 390.1: patient651: Patient 237 predicted hospital LOS: 22.6
# 390.211: patient189: Patient 238 predicted hospital LOS: 53
# 390.238: patient965: Patient 239 predicted hospital LOS: 49.9
# 391.524: patient904: Patient 240 predicted hospital LOS: 76.8
# 391.774: patient477: Patient 241 predicted hospital LOS: 34.3
# 394.26: patient562: Patient 242 predicted hospital LOS: 69.7
# 394.3: patient275: Patient 243 predicted hospital LOS: 17.6
# 394.357: patient278: Patient 244 predicted hospital LOS: 62.3
# 394.879: patient665: Patient 245 predicted hospital LOS: 71
# 395.166: patient631: Patient 246 predicted hospital LOS: 58.8
# 396.953: patient441: Patient 247 predicted hospital LOS: 63.5
# 397.005: patient917: Patient 248 predicted hospital LOS: 37.6
# 398.091: patient392: Patient 249 predicted hospital LOS: 96.2
# 398.139: patient328: Patient 250 predicted hospital LOS: 25.2
# 398.39: patient72: Patient 251 predicted hospital LOS: 19.6
# 398.68: patient406: Patient 252 predicted hospital LOS: 119.7
# 399.011: patient701: Patient 253 predicted hospital LOS: 40.6
# 399.794: patient683: Patient 254 predicted hospital LOS: 13.5
# 399.798: patient440: Patient 255 predicted hospital LOS: 27.9
# 402.485: patient445: Patient 256 predicted hospital LOS: 77.7
# 402.617: patient200: Patient 257 predicted hospital LOS: 84.9
# 404.221: patient513: Patient 258 predicted hospital LOS: 62
# 405.263: patient585: Patient 259 predicted hospital LOS: 80.8
# 406.028: patient667: Patient 260 predicted hospital LOS: 69
# 406.491: patient854: Patient 261 predicted hospital LOS: 78.6
# 407.509: patient485: Patient 262 predicted hospital LOS: 91
# 408.255: patient520: Patient 263 predicted hospital LOS: 94.9
# 408.883: patient708: Patient 264 predicted hospital LOS: 26
# 408.983: patient534: Patient 265 predicted hospital LOS: 32
# 409.147: patient432: Patient 266 predicted hospital LOS: 56.6
# 409.503: patient822: Patient 267 predicted hospital LOS: 57.7
# 409.563: patient87: Patient 268 predicted hospital LOS: 74.4
# 409.658: patient358: Patient 269 predicted hospital LOS: 74
# 410.329: patient496: Patient 270 predicted hospital LOS: 35.2
# 411.345: patient294: Patient 271 predicted hospital LOS: 79.1
# 412.071: patient437: Patient 272 predicted hospital LOS: 14.3
# 413.865: patient718: Patient 273 predicted hospital LOS: 56.2
# 414.389: patient194: Patient 274 predicted hospital LOS: 39.1
# 417.643: patient376: Patient 275 predicted hospital LOS: 61.2
# 418.003: patient721: Patient 276 predicted hospital LOS: 217.7
# 419.75: patient473: Patient 277 predicted hospital LOS: 67.1
# 419.812: patient887: Patient 278 predicted hospital LOS: 77.3
# 419.922: patient1265: Patient 279 predicted hospital LOS: 66.6
# 419.928: patient82: Patient 280 predicted hospital LOS: 76.6
# 420.024: patient341: Patient 281 predicted hospital LOS: 69.3
# 420.459: patient745: Patient 282 predicted hospital LOS: 95
# 420.815: patient736: Patient 283 predicted hospital LOS: 73.1
# 420.911: patient348: Patient 284 predicted hospital LOS: 29.9
# 422.741: patient699: Patient 285 predicted hospital LOS: 11.2
# 422.882: patient18: Patient 286 predicted hospital LOS: 61.3
# 423.366: patient620: Patient 287 predicted hospital LOS: 54.2
# 424.74: patient187: Patient 288 predicted hospital LOS: 81.5
# 424.806: patient78: Patient 289 predicted hospital LOS: 54.9
# 425.645: patient429: Patient 290 predicted hospital LOS: 54.6
# 426.06: patient579: Patient 291 predicted hospital LOS: 72.2
# 426.128: patient71: Patient 292 predicted hospital LOS: 83.1
# 427.056: patient1080: Patient 293 predicted hospital LOS: 69
# 427.181: patient19: Patient 294 predicted hospital LOS: 61.7
# 427.932: patient537: Patient 295 predicted hospital LOS: 21.1
# 428.147: patient889: Patient 296 predicted hospital LOS: 90.4
# 428.355: patient533: Patient 297 predicted hospital LOS: 57.2
# 428.48: patient472: Patient 298 predicted hospital LOS: 63.2
# 428.588: patient436: Patient 299 predicted hospital LOS: 39.8
# 429.517: patient212: Patient 300 predicted hospital LOS: 73.6
# 430.274: patient663: Patient 301 predicted hospital LOS: 45.9
# 430.511: patient310: Patient 302 predicted hospital LOS: 38.3
# 430.718: patient1030: Patient 303 predicted hospital LOS: 86.5
# 431.731: patient171: Patient 304 predicted hospital LOS: 65.1
# 431.817: patient550: Patient 305 predicted hospital LOS: 78
# 433.299: patient616: Patient 306 predicted hospital LOS: 67.5
# 433.591: patient645: Patient 307 predicted hospital LOS: 41.2
# 434.666: patient514: Patient 308 predicted hospital LOS: 40.1
# 434.938: patient682: Patient 309 predicted hospital LOS: 85.3
# 435.961: patient857: Patient 310 predicted hospital LOS: 70.1
# 436.424: patient599: Patient 311 predicted hospital LOS: 54
# 437.171: patient368: Patient 312 predicted hospital LOS: 202.4
# 437.487: patient765: Patient 313 predicted hospital LOS: 27.9
# 437.96: patient168: Patient 314 predicted hospital LOS: 44.1
# 438.364: patient186: Patient 315 predicted hospital LOS: 205.3
# 438.399: patient759: Patient 316 predicted hospital LOS: 86.6
# 438.76: patient592: Patient 317 predicted hospital LOS: 43.3
# 439.167: patient561: Patient 318 predicted hospital LOS: 36.1
# 439.418: patient498: Patient 319 predicted hospital LOS: 62.1
# 439.428: patient521: Patient 320 predicted hospital LOS: 48.1
# 439.64: patient486: Patient 321 predicted hospital LOS: 26.3
# 441.041: patient86: Patient 322 predicted hospital LOS: 57.4
# 441.062: patient576: Patient 323 predicted hospital LOS: 70.6
# 441.639: patient113: Patient 324 predicted hospital LOS: 65.9
# 441.734: patient518: Patient 325 predicted hospital LOS: 72.6
# 442.018: patient656: Patient 326 predicted hospital LOS: 24.3
# 442.724: patient577: Patient 327 predicted hospital LOS: 86.3
# 443.008: patient327: Patient 328 predicted hospital LOS: 82.6
# 443.628: patient160: Patient 329 predicted hospital LOS: 37
# 444.231: patient332: Patient 330 predicted hospital LOS: 79.3
# 445.154: patient546: Patient 331 predicted hospital LOS: 63.4
# 446.021: patient1170: Patient 332 predicted hospital LOS: 15.8
# 447.742: patient196: Patient 333 predicted hospital LOS: 42.2
# 450.066: patient223: Patient 334 predicted hospital LOS: 61.2
# 450.796: patient886: Patient 335 predicted hospital LOS: 70.2
# 450.954: patient613: Patient 336 predicted hospital LOS: 53.3
# 452.131: patient1116: Patient 337 predicted hospital LOS: 24
# 452.3: patient55: Patient 338 predicted hospital LOS: 80.4
# 452.729: patient727: Patient 339 predicted hospital LOS: 66.3
# 453.027: patient132: Patient 340 predicted hospital LOS: 19.5
# 453.654: patient752: Patient 341 predicted hospital LOS: 47.1
# 454.476: patient804: Patient 342 predicted hospital LOS: 17.7
# 455.236: patient908: Patient 343 predicted hospital LOS: 57.4
# 455.399: patient351: Patient 344 predicted hospital LOS: 323.2
# 455.795: patient367: Patient 345 predicted hospital LOS: 71
# 455.905: patient29: Patient 346 predicted hospital LOS: 12.1
# 457.583: patient845: Patient 347 predicted hospital LOS: 101.8
# 459.114: patient70: Patient 348 predicted hospital LOS: 34.1
# 459.46: patient298: Patient 349 predicted hospital LOS: 87.5
# 459.923: patient93: Patient 350 predicted hospital LOS: 78.1
# 460.048: patient479: Patient 351 predicted hospital LOS: 75.5
# 460.25: patient522: Patient 352 predicted hospital LOS: 30.4
# 460.854: patient502: Patient 353 predicted hospital LOS: 79
# 461.289: patient746: Patient 354 predicted hospital LOS: 14.7
# 461.417: patient816: Patient 355 predicted hospital LOS: 58.2
# 461.516: patient647: Patient 356 predicted hospital LOS: 60.7
# 461.565: patient84: Patient 357 predicted hospital LOS: 84.9
# 461.936: patient936: Patient 358 predicted hospital LOS: 36.3
# 462.393: patient654: Patient 359 predicted hospital LOS: 50.7
# 463.256: patient985: Patient 360 predicted hospital LOS: 78.7
# 463.452: patient637: Patient 361 predicted hospital LOS: 58
# 463.554: patient401: Patient 362 predicted hospital LOS: 41.4
# 463.713: patient135: Patient 363 predicted hospital LOS: 18.5
# 464.226: patient875: Patient 364 predicted hospital LOS: 24.5
# 464.676: patient1045: Patient 365 predicted hospital LOS: 44.3
# 464.683: patient974: Patient 366 predicted hospital LOS: 57.8
# 464.912: patient677: Patient 367 predicted hospital LOS: 96.2
# 465.658: patient475: Patient 368 predicted hospital LOS: 36.2
# 466.284: patient148: Patient 369 predicted hospital LOS: 55
# 466.361: patient97: Patient 370 predicted hospital LOS: 23
# 466.594: patient818: Patient 371 predicted hospital LOS: 58.5
# 466.684: patient363: Patient 372 predicted hospital LOS: 35.9
# 467.288: patient426: Patient 373 predicted hospital LOS: 28.7
# 467.705: patient36: Patient 374 predicted hospital LOS: 32.9
# 467.916: patient596: Patient 375 predicted hospital LOS: 71.1
# 469.188: patient540: Patient 376 predicted hospital LOS: 47.2
# 469.994: patient614: Patient 377 predicted hospital LOS: 94.9
# 470.004: patient344: Patient 378 predicted hospital LOS: 23.2
# 470.641: patient1299: Patient 379 predicted hospital LOS: 72.3
# 470.686: patient494: Patient 380 predicted hospital LOS: 78.8
# 470.778: patient339: Patient 381 predicted hospital LOS: 21.3
# 471.38: patient938: Patient 382 predicted hospital LOS: 20.2
# 471.821: patient951: Patient 383 predicted hospital LOS: 62.3
# 472.21: patient162: Patient 384 predicted hospital LOS: 49.1
# 472.538: patient563: Patient 385 predicted hospital LOS: 85.7
# 473.216: patient318: Patient 386 predicted hospital LOS: 68
# 473.53: patient308: Patient 387 predicted hospital LOS: 60.8
# 473.813: patient430: Patient 388 predicted hospital LOS: 53.7
# 475.015: patient757: Patient 389 predicted hospital LOS: 19.2
# 475.069: patient140: Patient 390 predicted hospital LOS: 50
# 475.181: patient155: Patient 391 predicted hospital LOS: 71
# 475.801: patient73: Patient 392 predicted hospital LOS: 70.7
# 476.131: patient446: Patient 393 predicted hospital LOS: 56.7
# 476.245: patient0: Patient 394 predicted hospital LOS: 92.4
# 476.602: patient1212: Patient 395 predicted hospital LOS: 84.1
# 476.968: patient76: Patient 396 predicted hospital LOS: 60.6
# 477.108: patient1300: Patient 397 predicted hospital LOS: 63
# 477.198: patient465: Patient 398 predicted hospital LOS: 70.4
# 477.229: patient33: Patient 399 predicted hospital LOS: 18.3
# 477.484: patient418: Patient 400 predicted hospital LOS: 82.5
# 477.734: patient343: Patient 401 predicted hospital LOS: 40.4
# 477.811: patient856: Patient 402 predicted hospital LOS: 93.1
# 478.367: patient582: Patient 403 predicted hospital LOS: 78.1
# 479.05: patient604: Patient 404 predicted hospital LOS: 34.2
# 480.494: patient633: Patient 405 predicted hospital LOS: 79.7
# 481.422: patient860: Patient 406 predicted hospital LOS: 45.1
# 481.574: patient402: Patient 407 predicted hospital LOS: 76.1
# 482.788: patient795: Patient 408 predicted hospital LOS: 44.1
# 483.128: patient792: Patient 409 predicted hospital LOS: 73.1
# 483.659: patient823: Patient 410 predicted hospital LOS: 72.9
# 483.928: patient144: Patient 411 predicted hospital LOS: 89.1
# 483.991: patient861: Patient 412 predicted hospital LOS: 50
# 484.118: patient145: Patient 413 predicted hospital LOS: 56.2
# 484.185: patient290: Patient 414 predicted hospital LOS: 62.6
# 484.202: patient927: Patient 415 predicted hospital LOS: 58.7
# 485.043: patient953: Patient 416 predicted hospital LOS: 39
# 485.384: patient420: Patient 417 predicted hospital LOS: 63.9
# 485.742: patient868: Patient 418 predicted hospital LOS: 78.4
# 486.062: patient384: Patient 419 predicted hospital LOS: 52.7
# 486.113: patient482: Patient 420 predicted hospital LOS: 88.6
# 486.413: patient361: Patient 421 predicted hospital LOS: 28.3
# 486.489: patient352: Patient 422 predicted hospital LOS: 84.1
# 486.852: patient570: Patient 423 predicted hospital LOS: 73.1
# 487.07: patient254: Patient 424 predicted hospital LOS: 69.5
# 489.33: patient775: Patient 425 predicted hospital LOS: 48.2
# 489.616: patient136: Patient 426 predicted hospital LOS: 25.1
# 490.136: patient463: Patient 427 predicted hospital LOS: 21
# 490.189: patient779: Patient 428 predicted hospital LOS: 61.6
# 490.204: patient529: Patient 429 predicted hospital LOS: 49.9
# 491.191: patient1183: Patient 430 predicted hospital LOS: 93.2
# 491.211: patient715: Patient 431 predicted hospital LOS: 58.5
# 491.294: patient1189: Patient 432 predicted hospital LOS: 19.4
# 491.976: patient939: Patient 433 predicted hospital LOS: 113
# 492.515: patient681: Patient 434 predicted hospital LOS: 110.5
# 492.537: patient215: Patient 435 predicted hospital LOS: 70.5
# 493.847: patient38: Patient 436 predicted hospital LOS: 49.7
# 494.135: patient879: Patient 437 predicted hospital LOS: 69
# 495.176: patient1016: Patient 438 predicted hospital LOS: 58.5
# 496.155: patient133: Patient 439 predicted hospital LOS: 36
# 496.833: patient635: Patient 440 predicted hospital LOS: 82.5
# 497.114: patient1430: Patient 441 predicted hospital LOS: 20.2
# 497.724: patient371: Patient 442 predicted hospital LOS: 36.4
# 498.39: patient980: Patient 443 predicted hospital LOS: 55.5
# 499.832: patient201: Patient 444 predicted hospital LOS: 123.8
# 499.907: patient456: Patient 445 predicted hospital LOS: 75.4
# 500.34: patient598: Patient 446 predicted hospital LOS: 34.7
# 500.35: patient369: Patient 447 predicted hospital LOS: 37.3
# 500.442: patient970: Patient 448 predicted hospital LOS: 34.2
# 500.619: patient1294: Patient 449 predicted hospital LOS: 195.3
# 500.88: patient674: Patient 450 predicted hospital LOS: 91.3
# 501.088: patient749: Patient 451 predicted hospital LOS: 54.6
# 502.401: patient303: Patient 452 predicted hospital LOS: 63
# 503.485: patient735: Patient 453 predicted hospital LOS: 59.4
# 503.834: patient265: Patient 454 predicted hospital LOS: 42
# 504.136: patient1035: Patient 455 predicted hospital LOS: 62.7
# 504.162: patient872: Patient 456 predicted hospital LOS: 34.4
# 504.319: patient710: Patient 457 predicted hospital LOS: 97.3
# 504.769: patient299: Patient 458 predicted hospital LOS: 107.5
# 504.958: patient556: Patient 459 predicted hospital LOS: 65.6
# 505.76: patient288: Patient 460 predicted hospital LOS: 67.6
# 506.25: patient717: Patient 461 predicted hospital LOS: 85.9
# 506.345: patient528: Patient 462 predicted hospital LOS: 98.7
# 506.831: patient914: Patient 463 predicted hospital LOS: 68.1
# 507.344: patient1203: Patient 464 predicted hospital LOS: 44.1
# 508.171: patient464: Patient 465 predicted hospital LOS: 15.8
# 509.42: patient756: Patient 466 predicted hospital LOS: 40.7
# 509.486: patient1099: Patient 467 predicted hospital LOS: 26.2
# 509.626: patient943: Patient 468 predicted hospital LOS: 34.9
# 510.249: patient49: Patient 469 predicted hospital LOS: 71.8
# 510.326: patient1366: Patient 470 predicted hospital LOS: 21.9
# 510.884: patient588: Patient 471 predicted hospital LOS: 41.3
# 511.224: patient605: Patient 472 predicted hospital LOS: 88.8
# 511.362: patient116: Patient 473 predicted hospital LOS: 97.8
# 511.638: patient531: Patient 474 predicted hospital LOS: 14
# 511.934: patient692: Patient 475 predicted hospital LOS: 31.4
# 512.734: patient743: Patient 476 predicted hospital LOS: 291.3
# 512.901: patient809: Patient 477 predicted hospital LOS: 30.8
# 513.091: patient354: Patient 478 predicted hospital LOS: 30.6
# 515.108: patient863: Patient 479 predicted hospital LOS: 56.7
# 515.508: patient587: Patient 480 predicted hospital LOS: 68.7
# 516.677: patient268: Patient 481 predicted hospital LOS: 78.6
# 518.183: patient532: Patient 482 predicted hospital LOS: 23.7
# 518.767: patient776: Patient 483 predicted hospital LOS: 54.5
# 518.95: patient790: Patient 484 predicted hospital LOS: 41.5
# 519.332: patient979: Patient 485 predicted hospital LOS: 92.3
# 520.436: patient467: Patient 486 predicted hospital LOS: 42.4
# 520.507: patient159: Patient 487 predicted hospital LOS: 87.3
# 520.65: patient755: Patient 488 predicted hospital LOS: 52.3
# 520.912: patient1128: Patient 489 predicted hospital LOS: 41
# 520.926: patient81: Patient 490 predicted hospital LOS: 23.6
# 521.496: patient276: Patient 491 predicted hospital LOS: 269.5
# 522.341: patient1071: Patient 492 predicted hospital LOS: 99.2
# 522.885: patient75: Patient 493 predicted hospital LOS: 33
# 523.25: patient457: Patient 494 predicted hospital LOS: 58
# 523.492: patient883: Patient 495 predicted hospital LOS: 21.8
# 524.124: patient785: Patient 496 predicted hospital LOS: 20.7
# 524.496: patient958: Patient 497 predicted hospital LOS: 57.5
# 524.709: patient827: Patient 498 predicted hospital LOS: 89.5
# 525.035: patient536: Patient 499 predicted hospital LOS: 48
# 525.462: patient1378: Patient 500 predicted hospital LOS: 86.1
# 525.541: patient219: Patient 501 predicted hospital LOS: 36.7
# 525.581: patient248: Patient 502 predicted hospital LOS: 30.3
# 525.633: patient870: Patient 503 predicted hospital LOS: 19.4
# 525.687: patient967: Patient 504 predicted hospital LOS: 64.5
# 525.728: patient138: Patient 505 predicted hospital LOS: 76.4
# 525.953: patient313: Patient 506 predicted hospital LOS: 55.8
# 526.317: patient25: Patient 507 predicted hospital LOS: 44.5
# 526.451: patient390: Patient 508 predicted hospital LOS: 47.2
# 526.571: patient1014: Patient 509 predicted hospital LOS: 101.2
# 526.78: patient1302: Patient 510 predicted hospital LOS: 72.1
# 526.95: patient543: Patient 511 predicted hospital LOS: 21.3
# 526.966: patient128: Patient 512 predicted hospital LOS: 72.9
# 527.236: patient63: Patient 513 predicted hospital LOS: 20.6
# 527.301: patient554: Patient 514 predicted hospital LOS: 72.6
# 527.615: patient11: Patient 515 predicted hospital LOS: 71.5
# 528.114: patient766: Patient 516 predicted hospital LOS: 32
# 528.138: patient880: Patient 517 predicted hospital LOS: 64.6
# 528.321: patient624: Patient 518 predicted hospital LOS: 68.3
# 528.691: patient282: Patient 519 predicted hospital LOS: 54.2
# 528.892: patient774: Patient 520 predicted hospital LOS: 91
# 528.93: patient167: Patient 521 predicted hospital LOS: 54.1
# 528.969: patient511: Patient 522 predicted hospital LOS: 13.7
# 529.433: patient676: Patient 523 predicted hospital LOS: 46.3
# 530.636: patient1398: Patient 524 predicted hospital LOS: 82
# 530.757: patient1312: Patient 525 predicted hospital LOS: 71
# 532.572: patient210: Patient 526 predicted hospital LOS: 59.1
# 532.817: patient236: Patient 527 predicted hospital LOS: 90.2
# 532.876: patient603: Patient 528 predicted hospital LOS: 72
# 533.687: patient1247: Patient 529 predicted hospital LOS: 63.4
# 534.188: patient640: Patient 530 predicted hospital LOS: 76.7
# 535.437: patient1103: Patient 531 predicted hospital LOS: 55.1
# 535.787: patient1015: Patient 532 predicted hospital LOS: 28.9
# 535.883: patient900: Patient 533 predicted hospital LOS: 65.5
# 536.199: patient1062: Patient 534 predicted hospital LOS: 40.6
# 537.287: patient593: Patient 535 predicted hospital LOS: 47.2
# 538.073: patient1069: Patient 536 predicted hospital LOS: 58.1
# 538.914: patient1124: Patient 537 predicted hospital LOS: 65.4
# 540.185: patient797: Patient 538 predicted hospital LOS: 12.9
# 541.001: patient1038: Patient 539 predicted hospital LOS: 41.4
# 541.411: patient399: Patient 540 predicted hospital LOS: 67.5
# 542.601: patient232: Patient 541 predicted hospital LOS: 46
# 542.721: patient143: Patient 542 predicted hospital LOS: 89.8
# 543.149: patient988: Patient 543 predicted hospital LOS: 31.2
# 544.285: patient996: Patient 544 predicted hospital LOS: 77.4
# 545.449: patient621: Patient 545 predicted hospital LOS: 22.7
# 545.769: patient1055: Patient 546 predicted hospital LOS: 54.3
# 546.215: patient495: Patient 547 predicted hospital LOS: 25.8
# 547.023: patient952: Patient 548 predicted hospital LOS: 47.4
# 547.603: patient993: Patient 549 predicted hospital LOS: 71.3
# 548.075: patient326: Patient 550 predicted hospital LOS: 67.7
# 548.558: patient1193: Patient 551 predicted hospital LOS: 71.7
# 548.783: patient380: Patient 552 predicted hospital LOS: 75.8
# 548.832: patient1000: Patient 553 predicted hospital LOS: 55.3
# 549.082: patient250: Patient 554 predicted hospital LOS: 85.6
# 550.269: patient1200: Patient 555 predicted hospital LOS: 68.8
# 550.783: patient256: Patient 556 predicted hospital LOS: 30.8
# 550.901: patient559: Patient 557 predicted hospital LOS: 31.1
# 551.338: patient660: Patient 558 predicted hospital LOS: 93.1
# 551.519: patient751: Patient 559 predicted hospital LOS: 26.3
# 551.913: patient1288: Patient 560 predicted hospital LOS: 102.9
# 552.291: patient580: Patient 561 predicted hospital LOS: 50.8
# 552.63: patient366: Patient 562 predicted hospital LOS: 67.1
# 552.658: patient389: Patient 563 predicted hospital LOS: 31.4
# 553.118: patient649: Patient 564 predicted hospital LOS: 17
# 553.384: patient1513: Patient 565 predicted hospital LOS: 27.7
# 553.471: patient214: Patient 566 predicted hospital LOS: 33.3
# 553.716: patient1173: Patient 567 predicted hospital LOS: 84.5
# 554.03: patient791: Patient 568 predicted hospital LOS: 70.4
# 554.856: patient1018: Patient 569 predicted hospital LOS: 62
# 555.471: patient247: Patient 570 predicted hospital LOS: 54.3
# 555.628: patient618: Patient 571 predicted hospital LOS: 52.3
# 556.104: patient1241: Patient 572 predicted hospital LOS: 49.2
# 556.747: patient732: Patient 573 predicted hospital LOS: 60.9
# 557: patient493: Patient 574 predicted hospital LOS: 59.3
# 557.296: patient1644: Patient 575 predicted hospital LOS: 29.3
# 557.568: patient1113: Patient 576 predicted hospital LOS: 36.7
# 558.208: patient1289: Patient 577 predicted hospital LOS: 80.3
# 558.854: patient840: Patient 578 predicted hospital LOS: 60.2
# 559.224: patient1359: Patient 579 predicted hospital LOS: 14.2
# 559.656: patient234: Patient 580 predicted hospital LOS: 62.3
# 559.741: patient324: Patient 581 predicted hospital LOS: 16.8
# 559.785: patient1046: Patient 582 predicted hospital LOS: 27
# 560.227: patient646: Patient 583 predicted hospital LOS: 256.6
# 560.794: patient448: Patient 584 predicted hospital LOS: 38
# 561.111: patient899: Patient 585 predicted hospital LOS: 112.7
# 561.129: patient414: Patient 586 predicted hospital LOS: 89.5
# 561.328: patient309: Patient 587 predicted hospital LOS: 57.8
# 561.516: patient1094: Patient 588 predicted hospital LOS: 78.1
# 562.02: patient679: Patient 589 predicted hospital LOS: 80.4
# 562.126: patient262: Patient 590 predicted hospital LOS: 64.9
# 563.033: patient337: Patient 591 predicted hospital LOS: 87
# 563.237: patient989: Patient 592 predicted hospital LOS: 65.7
# 563.363: patient1292: Patient 593 predicted hospital LOS: 71.1
# 563.845: patient317: Patient 594 predicted hospital LOS: 22.6
# 564.139: patient1491: Patient 595 predicted hospital LOS: 93
# 564.389: patient783: Patient 596 predicted hospital LOS: 53.3
# 564.462: patient1168: Patient 597 predicted hospital LOS: 81.2
# 564.781: patient629: Patient 598 predicted hospital LOS: 78.7
# 564.857: patient1114: Patient 599 predicted hospital LOS: 50.2
# 564.98: patient192: Patient 600 predicted hospital LOS: 85.3
# 567.136: patient626: Patient 601 predicted hospital LOS: 64.3
# 568.076: patient1224: Patient 602 predicted hospital LOS: 47.9
# 568.353: patient763: Patient 603 predicted hospital LOS: 59.5
# 568.453: patient412: Patient 604 predicted hospital LOS: 31.9
# 568.518: patient1172: Patient 605 predicted hospital LOS: 79
# 568.989: patient123: Patient 606 predicted hospital LOS: 53.9
# 569.074: patient524: Patient 607 predicted hospital LOS: 56.9
# 570.3: patient1546: Patient 608 predicted hospital LOS: 58.1
# 570.337: patient849: Patient 609 predicted hospital LOS: 24.1
# 571.467: patient1169: Patient 610 predicted hospital LOS: 34.4
# 571.897: patient642: Patient 611 predicted hospital LOS: 70.2
# 571.972: patient1110: Patient 612 predicted hospital LOS: 80
# 572.024: patient734: Patient 613 predicted hospital LOS: 64.3
# 572.142: patient697: Patient 614 predicted hospital LOS: 36.7
# 572.744: patient1021: Patient 615 predicted hospital LOS: 63.5
# 573.281: patient393: Patient 616 predicted hospital LOS: 58.4
# 573.82: patient507: Patient 617 predicted hospital LOS: 60
# 573.926: patient657: Patient 618 predicted hospital LOS: 48
# 574.678: patient1190: Patient 619 predicted hospital LOS: 39.5
# 575.145: patient567: Patient 620 predicted hospital LOS: 49.7
# 575.206: patient977: Patient 621 predicted hospital LOS: 68.5
# 575.448: patient1316: Patient 622 predicted hospital LOS: 34.3
# 575.527: patient365: Patient 623 predicted hospital LOS: 75.9
# 576.095: patient669: Patient 624 predicted hospital LOS: 80.4
# 576.574: patient1230: Patient 625 predicted hospital LOS: 21.7
# 576.861: patient1260: Patient 626 predicted hospital LOS: 21.6
# 577.576: patient492: Patient 627 predicted hospital LOS: 79.3
# 578.779: patient1264: Patient 628 predicted hospital LOS: 22.3
# 580.218: patient907: Patient 629 predicted hospital LOS: 73
# 580.594: patient474: Patient 630 predicted hospital LOS: 62.1
# 580.793: patient910: Patient 631 predicted hospital LOS: 28.4
# 581.406: patient882: Patient 632 predicted hospital LOS: 78.4
# 581.471: patient912: Patient 633 predicted hospital LOS: 93.3
# 581.538: patient1137: Patient 634 predicted hospital LOS: 47.3
# 582.14: patient442: Patient 635 predicted hospital LOS: 61.6
# 582.521: patient158: Patient 636 predicted hospital LOS: 236.2
# 582.791: patient1144: Patient 637 predicted hospital LOS: 56.6
# 583.262: patient591: Patient 638 predicted hospital LOS: 78.9
# 583.652: patient1058: Patient 639 predicted hospital LOS: 64.3
# 584.637: patient762: Patient 640 predicted hospital LOS: 76.1
# 584.637: patient972: Patient 641 predicted hospital LOS: 72.6
# 584.687: patient1222: Patient 642 predicted hospital LOS: 32
# 585.088: patient968: Patient 643 predicted hospital LOS: 64.6
# 585.121: patient1304: Patient 644 predicted hospital LOS: 73
# 585.447: patient806: Patient 645 predicted hospital LOS: 72.7
# 585.611: patient737: Patient 646 predicted hospital LOS: 64.5
# 585.889: patient459: Patient 647 predicted hospital LOS: 54.6
# 586.11: patient350: Patient 648 predicted hospital LOS: 24.6
# 586.704: patient1068: Patient 649 predicted hospital LOS: 55.3
# 586.757: patient1166: Patient 650 predicted hospital LOS: 87.7
# 586.782: patient181: Patient 651 predicted hospital LOS: 64.5
# 587.227: patient668: Patient 652 predicted hospital LOS: 61
# 588.037: patient9: Patient 653 predicted hospital LOS: 59.4
# 588.218: patient865: Patient 654 predicted hospital LOS: 50.2
# 589.23: patient680: Patient 655 predicted hospital LOS: 36.1
# 589.492: patient698: Patient 656 predicted hospital LOS: 83
# 590.16: patient1040: Patient 657 predicted hospital LOS: 68.8
# 590.287: patient986: Patient 658 predicted hospital LOS: 27
# 590.338: patient1286: Patient 659 predicted hospital LOS: 71.7
# 590.56: patient362: Patient 660 predicted hospital LOS: 16.6
# 590.797: patient519: Patient 661 predicted hospital LOS: 80.4
# 591.347: patient772: Patient 662 predicted hospital LOS: 42.6
# 592.173: patient719: Patient 663 predicted hospital LOS: 16.8
# 592.193: patient957: Patient 664 predicted hospital LOS: 20.4
# 592.292: patient1649: Patient 665 predicted hospital LOS: 26
# 592.765: patient716: Patient 666 predicted hospital LOS: 55
# 592.996: patient242: Patient 667 predicted hospital LOS: 55.6
# 593.875: patient707: Patient 668 predicted hospital LOS: 270.1
# 595.253: patient687: Patient 669 predicted hospital LOS: 76.4
# 595.795: patient987: Patient 670 predicted hospital LOS: 45.9
# 595.916: patient500: Patient 671 predicted hospital LOS: 77.6
# 596.139: patient198: Patient 672 predicted hospital LOS: 48.7
# 596.446: patient1050: Patient 673 predicted hospital LOS: 74.7
# 597.194: patient586: Patient 674 predicted hospital LOS: 82.4
# 597.628: patient1524: Patient 675 predicted hospital LOS: 41.1
# 598.605: patient1698: Patient 676 predicted hospital LOS: 42.3
# 598.798: patient851: Patient 677 predicted hospital LOS: 27.2
# 599.177: patient1277: Patient 678 predicted hospital LOS: 76.8
# 599.178: patient553: Patient 679 predicted hospital LOS: 290.4
# 599.403: patient798: Patient 680 predicted hospital LOS: 17.2
# 600.104: patient700: Patient 681 predicted hospital LOS: 107
# 600.401: patient1179: Patient 682 predicted hospital LOS: 24.8
# 600.692: patient742: Patient 683 predicted hospital LOS: 68.1
# 600.958: patient942: Patient 684 predicted hospital LOS: 104
# 602.111: patient866: Patient 685 predicted hospital LOS: 23.6
# 602.427: patient1357: Patient 686 predicted hospital LOS: 62.6
# 602.57: patient174: Patient 687 predicted hospital LOS: 21.1
# 602.721: patient1079: Patient 688 predicted hospital LOS: 16.3
# 602.871: patient100: Patient 689 predicted hospital LOS: 68
# 602.916: patient638: Patient 690 predicted hospital LOS: 61.4
# 602.988: patient678: Patient 691 predicted hospital LOS: 21.5
# 603.377: patient569: Patient 692 predicted hospital LOS: 68.7
# 603.661: patient1067: Patient 693 predicted hospital LOS: 45.7
# 603.688: patient744: Patient 694 predicted hospital LOS: 28.7
# 603.837: patient1516: Patient 695 predicted hospital LOS: 212.2
# 603.894: patient1462: Patient 696 predicted hospital LOS: 81.8
# 604.189: patient842: Patient 697 predicted hospital LOS: 74.4
# 604.827: patient252: Patient 698 predicted hospital LOS: 72.8
# 605.85: patient1205: Patient 699 predicted hospital LOS: 64.8
# 606.192: patient1043: Patient 700 predicted hospital LOS: 75.6
# 606.243: patient940: Patient 701 predicted hospital LOS: 68.1
# 606.846: patient1088: Patient 702 predicted hospital LOS: 38.1
# 606.913: patient1457: Patient 703 predicted hospital LOS: 66.7
# 607.155: patient1129: Patient 704 predicted hospital LOS: 63.1
# 607.232: patient881: Patient 705 predicted hospital LOS: 22.7
# 607.295: patient1192: Patient 706 predicted hospital LOS: 72
# 607.321: patient1461: Patient 707 predicted hospital LOS: 35.2
# 607.401: patient398: Patient 708 predicted hospital LOS: 71.2
# 608.139: patient1019: Patient 709 predicted hospital LOS: 33.4
# 608.71: patient1006: Patient 710 predicted hospital LOS: 64.4
# 609.236: patient1151: Patient 711 predicted hospital LOS: 44.1
# 609.355: patient844: Patient 712 predicted hospital LOS: 54.9
# 609.921: patient289: Patient 713 predicted hospital LOS: 66.4
# 610.888: patient1147: Patient 714 predicted hospital LOS: 28.3
# 610.904: patient269: Patient 715 predicted hospital LOS: 16.5
# 610.939: patient572: Patient 716 predicted hospital LOS: 69.3
# 611.159: patient292: Patient 717 predicted hospital LOS: 31.8
# 611.268: patient1456: Patient 718 predicted hospital LOS: 262.3
# 611.422: patient713: Patient 719 predicted hospital LOS: 74.3
# 612.044: patient956: Patient 720 predicted hospital LOS: 85.9
# 612.782: patient79: Patient 721 predicted hospital LOS: 61.9
# 612.807: patient950: Patient 722 predicted hospital LOS: 55
# 613.811: patient346: Patient 723 predicted hospital LOS: 31.7
# 614.137: patient824: Patient 724 predicted hospital LOS: 33.3
# 614.249: patient590: Patient 725 predicted hospital LOS: 63.8
# 614.486: patient542: Patient 726 predicted hospital LOS: 27.4
# 614.839: patient527: Patient 727 predicted hospital LOS: 211.7
# 615.681: patient240: Patient 728 predicted hospital LOS: 52.3
# 616.351: patient836: Patient 729 predicted hospital LOS: 78.6
# 617.114: patient731: Patient 730 predicted hospital LOS: 50.8
# 617.411: patient1392: Patient 731 predicted hospital LOS: 62.1
# 617.788: patient1081: Patient 732 predicted hospital LOS: 33.3
# 617.791: patient175: Patient 733 predicted hospital LOS: 94.5
# 618.097: patient1449: Patient 734 predicted hospital LOS: 73.6
# 618.709: patient407: Patient 735 predicted hospital LOS: 65.7
# 618.762: patient564: Patient 736 predicted hospital LOS: 61
# 618.934: patient1466: Patient 737 predicted hospital LOS: 56.6
# 619.239: patient1525: Patient 738 predicted hospital LOS: 80.7
# 619.248: patient501: Patient 739 predicted hospital LOS: 88.5
# 619.402: patient1102: Patient 740 predicted hospital LOS: 48.2
# 620.097: patient462: Patient 741 predicted hospital LOS: 22
# 620.436: patient1269: Patient 742 predicted hospital LOS: 68.8
# 621.408: patient664: Patient 743 predicted hospital LOS: 77.7
# 621.473: patient1397: Patient 744 predicted hospital LOS: 83.6
# 621.848: patient538: Patient 745 predicted hospital LOS: 38.5
# 622.104: patient905: Patient 746 predicted hospital LOS: 71.1
# 622.305: patient1090: Patient 747 predicted hospital LOS: 68
# 622.408: patient741: Patient 748 predicted hospital LOS: 12.7
# 622.821: patient606: Patient 749 predicted hospital LOS: 57.2
# 623.145: patient864: Patient 750 predicted hospital LOS: 67.3
# 623.327: patient843: Patient 751 predicted hospital LOS: 37.4
# 624.04: patient10: Patient 752 predicted hospital LOS: 50.2
# 624.188: patient1665: Patient 753 predicted hospital LOS: 264.3
# 624.639: patient855: Patient 754 predicted hospital LOS: 66.5
# 624.829: patient1134: Patient 755 predicted hospital LOS: 55.8
# 624.856: patient808: Patient 756 predicted hospital LOS: 23.5
# 625.15: patient1470: Patient 757 predicted hospital LOS: 67
# 625.678: patient655: Patient 758 predicted hospital LOS: 56
# 626.764: patient925: Patient 759 predicted hospital LOS: 91.8
# 627.299: patient830: Patient 760 predicted hospital LOS: 72.3
# 627.951: patient1582: Patient 761 predicted hospital LOS: 41.5
# 628.097: patient69: Patient 762 predicted hospital LOS: 23.7
# 629.451: patient1217: Patient 763 predicted hospital LOS: 43
# 629.879: patient1322: Patient 764 predicted hospital LOS: 41.5
# 631.002: patient1346: Patient 765 predicted hospital LOS: 77.5
# 631.268: patient137: Patient 766 predicted hospital LOS: 35.3
# 631.571: patient435: Patient 767 predicted hospital LOS: 66.7
# 632.121: patient480: Patient 768 predicted hospital LOS: 51
# 632.411: patient869: Patient 769 predicted hospital LOS: 50.3
# 632.67: patient1140: Patient 770 predicted hospital LOS: 23.5
# 632.802: patient408: Patient 771 predicted hospital LOS: 32.3
# 633.25: patient557: Patient 772 predicted hospital LOS: 64.4
# 633.472: patient285: Patient 773 predicted hospital LOS: 59.6
# 633.735: patient738: Patient 774 predicted hospital LOS: 89.1
# 633.898: patient1121: Patient 775 predicted hospital LOS: 59.7
# 634.224: patient932: Patient 776 predicted hospital LOS: 85.5
# 635.11: patient195: Patient 777 predicted hospital LOS: 89.4
# 635.161: patient1105: Patient 778 predicted hospital LOS: 55.5
# 635.424: patient594: Patient 779 predicted hospital LOS: 41.7
# ...
# 1365.79: patient2771: Patient 3001 predicted hospital LOS: 66.2
# 1366.55: patient3242: Patient 3002 predicted hospital LOS: 16.2
# 1366.65: patient2832: Patient 3003 predicted hospital LOS: 24.4
# 1366.71: patient3256: Patient 3004 predicted hospital LOS: 75.4
# 1366.87: patient2650: Patient 3005 predicted hospital LOS: 75.7
# 1366.93: patient3940: Patient 3006 predicted hospital LOS: 76.7
# 1367.28: patient3477: Patient 3007 predicted hospital LOS: 22.4
# 1367.29: patient3212: Patient 3008 predicted hospital LOS: 86.7
# 1367.33: patient3534: Patient 3009 predicted hospital LOS: 43.7
# 1367.79: patient4022: Patient 3010 predicted hospital LOS: 69.6
# 1367.82: patient3900: Patient 3011 predicted hospital LOS: 52.1
# 1368.26: patient246: Patient 3012 predicted hospital LOS: 20.2
# 1368.67: patient3312: Patient 3013 predicted hospital LOS: 64.5
# 1369.74: patient3583: Patient 3014 predicted hospital LOS: 65.1
# 1369.96: patient2152: Patient 3015 predicted hospital LOS: 53
# 1370.14: patient2244: Patient 3016 predicted hospital LOS: 78.5
# 1370.59: patient3344: Patient 3017 predicted hospital LOS: 31.6
# 1370.8: patient4203: Patient 3018 predicted hospital LOS: 75.6
# 1371.26: patient4069: Patient 3019 predicted hospital LOS: 22.5
# 1371.61: patient3932: Patient 3020 predicted hospital LOS: 76.1
# 1371.75: patient3658: Patient 3021 predicted hospital LOS: 50.7
# 1371.9: patient3453: Patient 3022 predicted hospital LOS: 41.1
# 1372.22: patient3303: Patient 3023 predicted hospital LOS: 82
# 1372.62: patient3704: Patient 3024 predicted hospital LOS: 56.1
# 1372.8: patient1570: Patient 3025 predicted hospital LOS: 60.7
# 1372.82: patient3518: Patient 3026 predicted hospital LOS: 29.7
# 1372.87: patient3272: Patient 3027 predicted hospital LOS: 61.9
# 1373.14: patient3266: Patient 3028 predicted hospital LOS: 26.1
# 1373.22: patient2690: Patient 3029 predicted hospital LOS: 60.5
# 1373.27: patient2421: Patient 3030 predicted hospital LOS: 21.9
# 1373.66: patient3290: Patient 3031 predicted hospital LOS: 21.6
# 1373.76: patient3586: Patient 3032 predicted hospital LOS: 57.9
# 1373.77: patient3197: Patient 3033 predicted hospital LOS: 29.3
# 1373.98: patient3097: Patient 3034 predicted hospital LOS: 41.1
# 1374.2: patient3401: Patient 3035 predicted hospital LOS: 18.5
# 1374.29: patient2734: Patient 3036 predicted hospital LOS: 77.6
# 1374.34: patient3379: Patient 3037 predicted hospital LOS: 54.6
# 1374.57: patient3774: Patient 3038 predicted hospital LOS: 20.2
# 1374.78: patient3938: Patient 3039 predicted hospital LOS: 52.8
# 1374.82: patient2872: Patient 3040 predicted hospital LOS: 66.6
# 1375.04: patient3412: Patient 3041 predicted hospital LOS: 70.8
# 1375.39: patient3723: Patient 3042 predicted hospital LOS: 77.7
# 1376.58: patient3007: Patient 3043 predicted hospital LOS: 44.7
# 1376.65: patient2248: Patient 3044 predicted hospital LOS: 45.6
# 1376.98: patient2956: Patient 3045 predicted hospital LOS: 51.7
# 1377.35: patient3084: Patient 3046 predicted hospital LOS: 18.6
# 1377.39: patient2206: Patient 3047 predicted hospital LOS: 49.9
# 1377.4: patient3830: Patient 3048 predicted hospital LOS: 248.5
# 1377.46: patient3612: Patient 3049 predicted hospital LOS: 67
# 1377.52: patient3680: Patient 3050 predicted hospital LOS: 50.3
# 1377.56: patient2321: Patient 3051 predicted hospital LOS: 78.2
# 1378.19: patient3666: Patient 3052 predicted hospital LOS: 74.2
# 1378.32: patient2545: Patient 3053 predicted hospital LOS: 59
# 1378.38: patient3386: Patient 3054 predicted hospital LOS: 73.7
# 1378.64: patient1744: Patient 3055 predicted hospital LOS: 22.1
# 1379.06: patient1206: Patient 3056 predicted hospital LOS: 51.1
# 1379.23: patient3732: Patient 3057 predicted hospital LOS: 30.3
# 1379.3: patient3170: Patient 3058 predicted hospital LOS: 96.2
# 1379.45: patient3751: Patient 3059 predicted hospital LOS: 74.9
# 1379.81: patient3541: Patient 3060 predicted hospital LOS: 74.4
# 1379.96: patient3122: Patient 3061 predicted hospital LOS: 81.8
# 1379.97: patient2136: Patient 3062 predicted hospital LOS: 63.5
# 1380.58: patient1953: Patient 3063 predicted hospital LOS: 61.8
# 1380.69: patient4005: Patient 3064 predicted hospital LOS: 54.8
# 1380.74: patient3645: Patient 3065 predicted hospital LOS: 60.2
# 1381.08: patient3455: Patient 3066 predicted hospital LOS: 55.3
# 1381.36: patient3152: Patient 3067 predicted hospital LOS: 40
# 1382.07: patient3618: Patient 3068 predicted hospital LOS: 53.8
# 1383.05: patient3882: Patient 3069 predicted hospital LOS: 28
# 1383.4: patient2878: Patient 3070 predicted hospital LOS: 70.2
# 1383.45: patient3278: Patient 3071 predicted hospital LOS: 38.4
# 1384.02: patient3544: Patient 3072 predicted hospital LOS: 100.5
# 1384.02: patient4267: Patient 3073 predicted hospital LOS: 61.5
# 1384.14: patient3189: Patient 3074 predicted hospital LOS: 105.3
# 1384.31: patient3445: Patient 3075 predicted hospital LOS: 58.5
# 1384.79: patient3449: Patient 3076 predicted hospital LOS: 18.7
# 1385.42: patient506: Patient 3077 predicted hospital LOS: 91.9
# 1385.8: patient3897: Patient 3078 predicted hospital LOS: 54
# 1386.4: patient3350: Patient 3079 predicted hospital LOS: 14.6
# 1386.93: patient3022: Patient 3080 predicted hospital LOS: 85
# 1387.78: patient3082: Patient 3081 predicted hospital LOS: 68.5
# 1388.5: patient3051: Patient 3082 predicted hospital LOS: 31.1
# 1388.82: patient3062: Patient 3083 predicted hospital LOS: 28.4
# 1388.87: patient4057: Patient 3084 predicted hospital LOS: 38.8
# 1390.1: patient2903: Patient 3085 predicted hospital LOS: 23.3
# 1390.15: patient1521: Patient 3086 predicted hospital LOS: 48
# 1390.17: patient3808: Patient 3087 predicted hospital LOS: 32.8
# 1390.51: patient2632: Patient 3088 predicted hospital LOS: 47.6
# 1390.72: patient3781: Patient 3089 predicted hospital LOS: 50.6
# 1392.4: patient3464: Patient 3090 predicted hospital LOS: 47.7
# 1392.53: patient2578: Patient 3091 predicted hospital LOS: 30
# 1392.7: patient2997: Patient 3092 predicted hospital LOS: 43.9
# 1392.88: patient3232: Patient 3093 predicted hospital LOS: 93.4
# 1392.95: patient3928: Patient 3094 predicted hospital LOS: 138.2
# 1392.95: patient3945: Patient 3095 predicted hospital LOS: 73.1
# 1393.19: patient3447: Patient 3096 predicted hospital LOS: 37.4
# 1393.67: patient3101: Patient 3097 predicted hospital LOS: 29.6
# 1393.74: patient3930: Patient 3098 predicted hospital LOS: 61.3
# 1393.82: patient3011: Patient 3099 predicted hospital LOS: 68.6
# 1393.94: patient3230: Patient 3100 predicted hospital LOS: 44.3
# 1393.99: patient3818: Patient 3101 predicted hospital LOS: 69.9
# 1394.4: patient3698: Patient 3102 predicted hospital LOS: 56.2
# 1394.46: patient3194: Patient 3103 predicted hospital LOS: 74.1
# 1395.2: patient3522: Patient 3104 predicted hospital LOS: 51.8
# 1395.41: patient3669: Patient 3105 predicted hospital LOS: 88.9
# 1395.88: patient2081: Patient 3106 predicted hospital LOS: 71.1
# 1396.72: patient3700: Patient 3107 predicted hospital LOS: 19.2
# 1397.44: patient1862: Patient 3108 predicted hospital LOS: 79.6
# 1397.61: patient2848: Patient 3109 predicted hospital LOS: 25.6
# 1397.66: patient2617: Patient 3110 predicted hospital LOS: 57.4
# 1397.87: patient3226: Patient 3111 predicted hospital LOS: 23.5
# 1398.67: patient2714: Patient 3112 predicted hospital LOS: 14.9
# 1399.08: patient2391: Patient 3113 predicted hospital LOS: 74.6
# 1399.52: patient3243: Patient 3114 predicted hospital LOS: 93.4
# 1399.82: patient3593: Patient 3115 predicted hospital LOS: 40.3
# 1400.39: patient3576: Patient 3116 predicted hospital LOS: 36.2
# 1400.41: patient3992: Patient 3117 predicted hospital LOS: 81.1
# 1400.82: patient2973: Patient 3118 predicted hospital LOS: 66.7
# 1401.51: patient2514: Patient 3119 predicted hospital LOS: 57
# 1401.66: patient3364: Patient 3120 predicted hospital LOS: 58.7
# 1401.9: patient2885: Patient 3121 predicted hospital LOS: 83.2
# 1401.93: patient3823: Patient 3122 predicted hospital LOS: 94
# 1401.93: patient2659: Patient 3123 predicted hospital LOS: 29.8
# 1402.5: patient3223: Patient 3124 predicted hospital LOS: 83.5
# 1402.64: patient2850: Patient 3125 predicted hospital LOS: 78.4
# 1403.05: patient3120: Patient 3126 predicted hospital LOS: 50.4
# 1403.11: patient3403: Patient 3127 predicted hospital LOS: 57.3
# 1403.17: patient3668: Patient 3128 predicted hospital LOS: 74.7
# 1403.33: patient120: Patient 3129 predicted hospital LOS: 36.7
# 1404.01: patient3646: Patient 3130 predicted hospital LOS: 75.9
# 1404.15: patient3569: Patient 3131 predicted hospital LOS: 84.7
# 1404.6: patient3511: Patient 3132 predicted hospital LOS: 21.1
# 1404.92: patient3858: Patient 3133 predicted hospital LOS: 15.7
# 1405.29: patient3515: Patient 3134 predicted hospital LOS: 80.9
# 1405.57: patient3380: Patient 3135 predicted hospital LOS: 62.7
# 1405.69: patient2561: Patient 3136 predicted hospital LOS: 24
# 1406.31: patient3448: Patient 3137 predicted hospital LOS: 73.8
# 1407.27: patient3826: Patient 3138 predicted hospital LOS: 32
# 1407.59: patient3759: Patient 3139 predicted hospital LOS: 42.1
# 1407.74: patient2319: Patient 3140 predicted hospital LOS: 61.2
# 1408.02: patient3406: Patient 3141 predicted hospital LOS: 34.7
# 1408.3: patient3025: Patient 3142 predicted hospital LOS: 11
# 1408.49: patient3506: Patient 3143 predicted hospital LOS: 96.4
# 1408.93: patient3964: Patient 3144 predicted hospital LOS: 49.5
# 1409.27: patient3839: Patient 3145 predicted hospital LOS: 64.4
# 1409.7: patient2400: Patient 3146 predicted hospital LOS: 48.7
# 1410.31: patient2684: Patient 3147 predicted hospital LOS: 42.2
# 1410.67: patient3291: Patient 3148 predicted hospital LOS: 51.5
# 1410.7: patient3028: Patient 3149 predicted hospital LOS: 70.4
# 1410.7: patient2602: Patient 3150 predicted hospital LOS: 66.3
# 1410.71: patient3195: Patient 3151 predicted hospital LOS: 42.5
# 1410.84: patient2056: Patient 3152 predicted hospital LOS: 64.3
# 1411.02: patient3156: Patient 3153 predicted hospital LOS: 18.8
# 1411.32: patient3157: Patient 3154 predicted hospital LOS: 40.6
# 1411.38: patient3981: Patient 3155 predicted hospital LOS: 71.5
# 1411.45: patient2048: Patient 3156 predicted hospital LOS: 57.2
# 1411.54: patient535: Patient 3157 predicted hospital LOS: 61.4
# 1412.22: patient3737: Patient 3158 predicted hospital LOS: 60.4
# 1412.56: patient4032: Patient 3159 predicted hospital LOS: 52.2
# 1413.69: patient1866: Patient 3160 predicted hospital LOS: 86.7
# 1414.35: patient3452: Patient 3161 predicted hospital LOS: 28.2
# 1414.51: patient4194: Patient 3162 predicted hospital LOS: 66.1
# 1414.52: patient3687: Patient 3163 predicted hospital LOS: 34.2
# 1414.62: patient3127: Patient 3164 predicted hospital LOS: 18.5
# 1415.17: patient3749: Patient 3165 predicted hospital LOS: 33.3
# 1415.35: patient3713: Patient 3166 predicted hospital LOS: 43
# 1415.44: patient1961: Patient 3167 predicted hospital LOS: 56.9
# 1415.74: patient4326: Patient 3168 predicted hospital LOS: 63.7
# 1415.76: patient3166: Patient 3169 predicted hospital LOS: 46.5
# 1416.41: patient3935: Patient 3170 predicted hospital LOS: 61.4
# 1416.77: patient3089: Patient 3171 predicted hospital LOS: 70.8
# 1417.14: patient3065: Patient 3172 predicted hospital LOS: 89.6
# 1417.48: patient3555: Patient 3173 predicted hospital LOS: 23.5
# 1417.98: patient3581: Patient 3174 predicted hospital LOS: 69
# 1417.99: patient2485: Patient 3175 predicted hospital LOS: 71.1
# 1418.07: patient3420: Patient 3176 predicted hospital LOS: 26.7
# 1418.56: patient3470: Patient 3177 predicted hospital LOS: 64.2
# 1418.67: patient3657: Patient 3178 predicted hospital LOS: 18.9
# 1418.77: patient3148: Patient 3179 predicted hospital LOS: 72.6
# 1418.88: patient221: Patient 3180 predicted hospital LOS: 46.8
# 1419.16: patient3866: Patient 3181 predicted hospital LOS: 53.7
# 1420.27: patient3879: Patient 3182 predicted hospital LOS: 51.5
# 1420.81: patient3777: Patient 3183 predicted hospital LOS: 58
# 1421.41: patient3026: Patient 3184 predicted hospital LOS: 51.1
# 1421.63: patient1008: Patient 3185 predicted hospital LOS: 55.7
# 1422.32: patient3499: Patient 3186 predicted hospital LOS: 23.6
# 1422.33: patient2847: Patient 3187 predicted hospital LOS: 50.6
# 1422.98: patient4109: Patient 3188 predicted hospital LOS: 79.5
# 1423.43: patient1972: Patient 3189 predicted hospital LOS: 70.5
# 1424.24: patient2697: Patient 3190 predicted hospital LOS: 43.9
# 1424.57: patient3422: Patient 3191 predicted hospital LOS: 66.1
# 1424.88: patient4172: Patient 3192 predicted hospital LOS: 64.5
# 1425.11: patient3161: Patient 3193 predicted hospital LOS: 46.9
# 1425.2: patient2584: Patient 3194 predicted hospital LOS: 69.3
# 1425.27: patient1758: Patient 3195 predicted hospital LOS: 62.7
# 1425.46: patient3324: Patient 3196 predicted hospital LOS: 67.4
# 1425.57: patient3003: Patient 3197 predicted hospital LOS: 35.9
# 1425.71: patient3050: Patient 3198 predicted hospital LOS: 99.3
# 1426.36: patient2773: Patient 3199 predicted hospital LOS: 77.4
# 1426.44: patient3191: Patient 3200 predicted hospital LOS: 66.4
# 1426.82: patient3402: Patient 3201 predicted hospital LOS: 34.3
# 1426.85: patient3057: Patient 3202 predicted hospital LOS: 87.2
# 1426.99: patient3561: Patient 3203 predicted hospital LOS: 60.9
# 1427.39: patient1834: Patient 3204 predicted hospital LOS: 18.1
# 1427.61: patient3301: Patient 3205 predicted hospital LOS: 52.3
# 1427.67: patient3819: Patient 3206 predicted hospital LOS: 42.6
# 1428.69: patient4025: Patient 3207 predicted hospital LOS: 81.6
# 1428.8: patient3607: Patient 3208 predicted hospital LOS: 59.5
# 1428.81: patient3381: Patient 3209 predicted hospital LOS: 80.5
# 1428.96: patient3438: Patient 3210 predicted hospital LOS: 34.6
# 1429.22: patient3524: Patient 3211 predicted hospital LOS: 16.3
# 1429.31: patient1005: Patient 3212 predicted hospital LOS: 53.8
# 1429.4: patient3652: Patient 3213 predicted hospital LOS: 73.6
# 1430.02: patient2468: Patient 3214 predicted hospital LOS: 37.7
# 1430.75: patient3441: Patient 3215 predicted hospital LOS: 85.1
# 1430.75: patient3705: Patient 3216 predicted hospital LOS: 63.5
# 1431.39: patient3601: Patient 3217 predicted hospital LOS: 13.3
# 1431.74: patient4070: Patient 3218 predicted hospital LOS: 67.9
# 1431.76: patient3617: Patient 3219 predicted hospital LOS: 18.7
# 1432.52: patient4357: Patient 3220 predicted hospital LOS: 88.2
# 1432.52: patient2687: Patient 3221 predicted hospital LOS: 16.9
# 1432.77: patient4210: Patient 3222 predicted hospital LOS: 69.1
# 1432.88: patient2576: Patient 3223 predicted hospital LOS: 59.4
# 1432.89: patient3389: Patient 3224 predicted hospital LOS: 77.4
# 1433.07: patient2707: Patient 3225 predicted hospital LOS: 115.9
# 1433.21: patient3486: Patient 3226 predicted hospital LOS: 30.9
# 1433.55: patient3579: Patient 3227 predicted hospital LOS: 72.5
# 1433.6: patient3708: Patient 3228 predicted hospital LOS: 60.9
# 1433.79: patient3488: Patient 3229 predicted hospital LOS: 58.7
# 1434.03: patient4006: Patient 3230 predicted hospital LOS: 91.4
# 1434.16: patient3198: Patient 3231 predicted hospital LOS: 70.6
# 1434.94: patient3211: Patient 3232 predicted hospital LOS: 60.2
# 1435.42: patient3731: Patient 3233 predicted hospital LOS: 72.6
# 1435.68: patient3771: Patient 3234 predicted hospital LOS: 28.9
# 1436.07: patient3434: Patient 3235 predicted hospital LOS: 67.1
# 1436.3: patient4092: Patient 3236 predicted hospital LOS: 62.1
# 1436.32: patient2327: Patient 3237 predicted hospital LOS: 70.4
# 1436.74: patient427: Patient 3238 predicted hospital LOS: 46.6
# 1437.33: patient2930: Patient 3239 predicted hospital LOS: 90
# 1437.39: patient2828: Patient 3240 predicted hospital LOS: 56.3
# 1437.45: patient3734: Patient 3241 predicted hospital LOS: 64.7
# 1437.48: patient3268: Patient 3242 predicted hospital LOS: 47.5
# 1437.89: patient3609: Patient 3243 predicted hospital LOS: 41.9
# 1438.25: patient3476: Patient 3244 predicted hospital LOS: 53.2
# 1439.59: patient2713: Patient 3245 predicted hospital LOS: 77.7
# 1439.67: patient3357: Patient 3246 predicted hospital LOS: 50.1
# 1439.84: patient4129: Patient 3247 predicted hospital LOS: 66.5
# simmer environment: ED Simulation V1 | now: 1440 | next: 1440.05570445264
# { Monitor: in memory }
# { Resource: ed_bed | monitored: TRUE | server status: 1370(Inf) | queue status: 0(Inf) }
# { Source: patient | monitored: 2 | n_generated: 4618 }
# [1] 1440

# %% [markdown]
# Extract Results

# %%
# Get monitoring data
arrivals <- get_mon_arrivals(ed_sim)
resources <- get_mon_resources(ed_sim)

# Quick summary
summary(arrivals$activity_time)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   18.78  236.00  333.50  365.36  464.00 1297.03

# %%
# predicted hosp LOS
head(hospital_los_log)
# Out:
#   patient_id pred_hosp_los
# 1 1          72.50734
# 2 2          49.73247
# 3 3          63.37629
# 4 4          24.47674
# 5 5          79.72897
# 6 6          82.77594

# %% [markdown]
# Visualizations

# %%
# Plot resource usage over time
plot(resources, metric = "usage")

# Plot resource utilization
plot(resources, metric = "utilization")

# Histogram of length of stay
ggplot(arrivals, aes(x = activity_time)) +
  geom_histogram(bins = 30, fill = "steelblue", color = "white") +
  geom_vline(aes(xintercept = mean(activity_time)), 
             color = "red", linetype = "dashed", size = 1) +
  geom_vline(aes(xintercept = quantile(activity_time, 0.80)), 
             color = "orange", linetype = "dashed", size = 1) +
  labs(
    title = "Distribution of Length of Stay",
    subtitle = "Red = mean, Orange = 80th percentile",
    x = "LOS (minutes)",
    y = "Count"
  ) +
  theme_minimal()
# Out:
# plot without title
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title
# plot without title
