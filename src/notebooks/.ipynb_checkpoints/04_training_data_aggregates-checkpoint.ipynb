# %% [markdown]
# # 04: Creating Training Dataframe for Model + Probability Aggregates for Sim
# This notebook prepares datasets that will be used for our R predictive model and simulation
#
# includes probability tables for sex and disposition, and the training data that the admitted LOS will use

# %%
import pandas as pd
from IPython.display import display, HTML
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import all tables created from notebook 3

# %%
root = '../../../MIMIC_ED/processed/'

# tables generated from notebook 03
ed_stays_df = pd.read_csv(root + 'ed_stays.csv')
ed_activity_log = pd.read_csv(root + 'ed_activity_log.csv')
triage_df = pd.read_csv(root + 'ed_diagnoses.csv')
med_df  = pd.read_csv(root + 'ed_medications.csv')

# %%
df = pd.read_csv(root + 'los_training_df.csv')
admissions_df = pd.read_csv('../../../MIMIC_ED/raw/admissions.csv.gz')

# %%
print(admissions_df.shape)

admissions_df.head()
# Out:
# (546028, 16)
#    subject_id   hadm_id            admittime            dischtime deathtime  \
# 0    10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN
# 1    10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00       NaN
# 2    10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00       NaN
# 3    10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00       NaN
# 4    10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00       NaN
#
#    admission_type admit_provider_id      admission_location  \
# 0          URGENT            P49AFC  TRANSFER FROM HOSPITAL
# 1        EW EMER.            P784FA          EMERGENCY ROOM
# 2        EW EMER.            P19UTS          EMERGENCY ROOM
# 3        EW EMER.            P06OTX          EMERGENCY ROOM
# 4  EU OBSERVATION            P39NWO          EMERGENCY ROOM
#
#   discharge_location insurance language marital_status   race  \
# 0               HOME  Medicaid  English        WIDOWED  WHITE
# 1               HOME  Medicaid  English        WIDOWED  WHITE
# 2            HOSPICE  Medicaid  English        WIDOWED  WHITE
# 3               HOME  Medicaid  English        WIDOWED  WHITE
# 4                NaN       NaN  English         SINGLE  WHITE
#
#              edregtime            edouttime  hospital_expire_flag
# 0  2180-05-06 19:17:00  2180-05-06 23:30:00                     0
# 1  2180-06-26 15:54:00  2180-06-26 21:31:00                     0
# 2  2180-08-05 20:58:00  2180-08-06 01:44:00                     0
# 3  2180-07-23 05:54:00  2180-07-23 14:00:00                     0
# 4  2160-03-03 21:55:00  2160-03-04 06:26:00                     0

# %% [markdown]
# 175 rows in admissions have negative admit time, we'll drop these

# %%
admissions_df['admittime'] = pd.to_datetime(admissions_df['admittime'])
admissions_df['dischtime'] = pd.to_datetime(admissions_df['dischtime'])
admissions_df[admissions_df['admittime'] > admissions_df['dischtime']]
# Out:
#         subject_id   hadm_id           admittime           dischtime  \
# 1913      10035271  26463092 2165-08-13 14:00:00 2165-08-13 00:00:00
# 2677      10049642  26714941 2177-02-20 03:15:00 2177-02-20 02:30:00
# 3961      10077373  23874669 2187-12-18 19:14:00 2187-12-18 12:22:00
# 6919      10136283  29334858 2163-03-01 20:43:00 2163-03-01 02:32:00
# 14081     10271174  26331353 2117-01-09 02:57:00 2117-01-09 02:19:00
# ...            ...       ...                 ...                 ...
# 527166    19649539  20159343 2117-05-27 22:04:00 2117-05-27 21:16:00
# 539630    19887023  24942188 2128-11-12 09:54:00 2128-11-12 00:00:00
# 540596    19904685  24196469 2171-12-10 14:49:00 2171-12-10 00:00:00
# 541279    19914761  22348782 2145-07-10 18:28:00 2145-07-10 00:01:00
# 544186    19966756  29577757 2145-08-13 05:54:00 2145-08-13 04:30:00
#
#                   deathtime      admission_type admit_provider_id  \
# 1913    2165-08-13 22:20:00            EW EMER.            P26WQF
# 2677    2177-02-20 20:30:00            EW EMER.            P70GWM
# 3961                    NaN  DIRECT OBSERVATION            P96870
# 6919                    NaN      EU OBSERVATION            P96870
# 14081   2117-01-09 20:51:00            EW EMER.            P46834
# ...                     ...                 ...               ...
# 527166                  NaN      EU OBSERVATION            P60DDG
# 539630  2128-11-12 20:45:00            EW EMER.            P595QV
# 540596  2171-12-10 19:50:00            EW EMER.            P740G6
# 541279  2145-07-10 00:01:00            EW EMER.            P8286C
# 544186                  NaN            EW EMER.            P1969S
#
#             admission_location discharge_location insurance language  \
# 1913    TRANSFER FROM HOSPITAL               DIED  Medicare  English
# 2677            EMERGENCY ROOM               DIED   Private      NaN
# 3961            EMERGENCY ROOM                NaN  Medicare  English
# 6919            EMERGENCY ROOM                NaN   Private  English
# 14081           EMERGENCY ROOM               DIED  Medicare  English
# ...                        ...                ...       ...      ...
# 527166          EMERGENCY ROOM                NaN  Medicaid    Other
# 539630          EMERGENCY ROOM               DIED  Medicare  English
# 540596          EMERGENCY ROOM               DIED   Private  English
# 541279          EMERGENCY ROOM               DIED  Medicare  English
# 544186          EMERGENCY ROOM               HOME   Private  English
#
#        marital_status                    race            edregtime  \
# 1913           SINGLE                 UNKNOWN  2165-08-13 10:55:00
# 2677              NaN                 UNKNOWN  2177-02-20 01:15:00
# 3961          MARRIED                   WHITE  2187-12-18 16:27:00
# 6919           SINGLE                   WHITE  2163-03-01 19:22:00
# 14081             NaN                 UNKNOWN  2117-01-09 02:07:00
# ...               ...                     ...                  ...
# 527166         SINGLE                   WHITE  2117-05-27 12:02:00
# 539630        MARRIED                   WHITE  2128-11-12 06:47:00
# 540596        MARRIED                   WHITE  2171-12-10 11:37:00
# 541279         SINGLE                   WHITE  2145-07-10 15:16:00
# 544186        MARRIED  BLACK/AFRICAN AMERICAN  2145-08-13 01:54:00
#
#                   edouttime  hospital_expire_flag
# 1913    2165-08-13 14:44:00                     1
# 2677    2177-02-20 04:25:00                     1
# 3961    2187-12-19 12:59:00                     0
# 6919    2163-03-02 00:39:00                     0
# 14081   2117-01-09 06:24:00                     1
# ...                     ...                   ...
# 527166  2117-05-27 22:37:00                     0
# 539630  2128-11-12 10:44:00                     1
# 540596  2171-12-10 16:10:00                     1
# 541279  2145-07-10 19:43:00                     1
# 544186  2145-08-13 08:45:00                     0
#
# [175 rows x 16 columns]

# %% [markdown]
# # Lookup function by `stay_id`

# %%
def lookup(stay_id):
    print(f"Stay ID: {stay_id}")
    stay_summary = ed_stays_df[ed_stays_df['stay_id'] == stay_id].to_html()
    activity_summary = ed_activity_log[ed_activity_log['stay_id'] == stay_id].to_html()
    med_summary = med_df[med_df['stay_id'] == stay_id].to_html()
    triage_summary = triage_df[triage_df['stay_id'] == stay_id].to_html()
    
    display(HTML(f"""
    <div style="display: flex; gap: 50px;">
        <div>{stay_summary}</div>
    </div>
    <div>{activity_summary}</div>
    <div style="display: flex; gap: 50px;">
        <div>{med_summary}</div>
        <div>{triage_summary}</div>
    </div>
    """))

# %%
lookup(30000936)
# Out:
# Stay ID: 30000936
#     <div style="display: flex; gap: 50px;">
#         <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stay_id</th>
#       <th>subject_id</th>
#       <th>hadm_id</th>
#       <th>gender</th>
#       <th>race</th>
#       <th>arrival_transport</th>
#       <th>disposition</th>
#       <th>acuity</th>
#       <th>chiefcomplaint</th>
#       <th>arrival_time</th>
#       <th>triage_time</th>
#       <th>depart_time</th>
#       <th>ed_los_hours</th>
#       <th>is_admitted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>46</th>
#       <td>30000936</td>
#       <td>16235004</td>
#       <td>NaN</td>
#       <td>M</td>
#       <td>WHITE</td>
#       <td>UNKNOWN</td>
#       <td>LEFT WITHOUT BEING SEEN</td>
#       <td>4.0</td>
#       <td>L Ankle pain</td>
#       <td>2150-12-16 18:30:00</td>
#       <td>2150-12-16 18:30:01</td>
#       <td>2150-12-16 19:30:00</td>
#       <td>1.0</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table></div>
#     </div>
#     <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stay_id</th>
#       <th>subject_id</th>
#       <th>hadm_id</th>
#       <th>timestamps</th>
#       <th>activity</th>
#       <th>acuity</th>
#       <th>activity_seq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>403</th>
#       <td>30000936</td>
#       <td>16235004</td>
#       <td>NaN</td>
#       <td>2150-12-16 18:30:00</td>
#       <td>Enter the ED</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>404</th>
#       <td>30000936</td>
#       <td>16235004</td>
#       <td>NaN</td>
#       <td>2150-12-16 18:30:01</td>
#       <td>Triage in the ED</td>
#       <td>4.0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>405</th>
#       <td>30000936</td>
#       <td>16235004</td>
#       <td>NaN</td>
#       <td>2150-12-16 18:36:00</td>
#       <td>Vital sign check</td>
#       <td>NaN</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>406</th>
#       <td>30000936</td>
#       <td>16235004</td>
#       <td>NaN</td>
#       <td>2150-12-16 19:30:00</td>
#       <td>Discharge from the ED</td>
#       <td>NaN</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table></div>
#     <div style="display: flex; gap: 50px;">
#         <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stay_id</th>
#       <th>subject_id</th>
#       <th>timestamps</th>
#       <th>medication_name</th>
#       <th>gsn</th>
#       <th>ndc</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table></div>
#         <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stay_id</th>
#       <th>subject_id</th>
#       <th>icd_code</th>
#       <th>icd_version</th>
#       <th>icd_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>115</th>
#       <td>30000936</td>
#       <td>16235004</td>
#       <td>M25572</td>
#       <td>10</td>
#       <td>PAIN IN LEFT ANKLE AND JOINTS OF LEFT FOOT</td>
#     </tr>
#   </tbody>
# </table></div>
#     </div>

# %% [markdown]
# # Creating features for training df

# %% [markdown]
# We want to predict based on acuity, gender, race, ed length of stay, acuity, and medication count

# %%
X_df = ed_stays_df[['stay_id', 
                    'subject_id', 
                    'hadm_id', 
                    'gender', 
                    'race', 
                    'ed_los_hours', 
                    'acuity', 
                    'is_admitted', 
                    'disposition',]]
# icd_df = triage_df[['stay_id', 'icd_code', 'icd_version']]



med_count_per_stay = (
    med_df.groupby('stay_id')
          .count()['subject_id']
          .rename('medication_count')
)

# if the stay isnt found in ed_stays, it will populate as NaN, which means there wasn't any meds administered for that stay
X_df = X_df.merge(med_count_per_stay, how='left', on='stay_id')
# X_df = X_df.merge(icd_df, how = 'left', on = 'stay_id')
X_df['medication_count'] = X_df['medication_count'].fillna(0)
X_df['is_admitted'] = ~X_df['hadm_id'].isna()
X_df.head()
# Out:
#     stay_id  subject_id     hadm_id gender                    race  \
# 0  30000012    11714491  21562392.0      F                   WHITE
# 1  30000017    14230614         NaN      M  BLACK/AFRICAN AMERICAN
# 2  30000038    13821532  26255538.0      F                   WHITE
# 3  30000039    13340997  23100190.0      M                   WHITE
# 4  30000055    19848164         NaN      F                   OTHER
#
#    ed_los_hours  acuity  is_admitted disposition  medication_count
# 0      5.616667     2.0         True    ADMITTED              14.0
# 1      4.033333     3.0        False      ELOPED               3.0
# 2      3.300000     3.0         True    ADMITTED              12.0
# 3      8.516667     3.0         True    ADMITTED               4.0
# 4      4.150000     3.0        False        HOME               1.0

# %% [markdown]
# We will go off of the presence of hadm_id to determine if a patient was admitted or not (before it was based on whether disposition == 'ADMITTED')
#
# Now we pull out admitted only patients to merge with the hospital admission data

# %%
X_df = X_df[X_df['is_admitted']]

# %%
X_df.head()
# Out:
#     stay_id  subject_id     hadm_id gender                      race  \
# 0  30000012    11714491  21562392.0      F                     WHITE
# 2  30000038    13821532  26255538.0      F                     WHITE
# 3  30000039    13340997  23100190.0      M                     WHITE
# 7  30000177    17937834  23831044.0      M  ASIAN - SOUTH EAST ASIAN
# 9  30000204    11615015  25540031.0      M                     WHITE
#
#    ed_los_hours  acuity  is_admitted disposition  medication_count
# 0      5.616667     2.0         True    ADMITTED              14.0
# 2      3.300000     3.0         True    ADMITTED              12.0
# 3      8.516667     3.0         True    ADMITTED               4.0
# 7      4.966667     2.0         True    ADMITTED              16.0
# 9     12.150000     3.0         True        HOME              10.0

# %%
# admissions_df.merge(X_df, how = 'right', on = 'hadm_id')
admissions_df.columns

admissions_df = admissions_df[['subject_id', 'hadm_id', 'admittime', 'dischtime', 'edregtime', 'edouttime']]

# %% [markdown]
# I can confirn that `edregtime` and `edouttime` aligns with the ED activity log dataset

# %%
# convert to datetime
admissions_df['admittime'] = pd.to_datetime(admissions_df['admittime'])
admissions_df['dischtime'] = pd.to_datetime(admissions_df['dischtime'])

# %%
admissions_df['hosp_los_hours'] = (admissions_df['dischtime'] - admissions_df['admittime']).dt.total_seconds() / 3600

# %%
X_df = X_df.merge(admissions_df[['hadm_id', 'hosp_los_hours']], 
           how = 'left', 
           on = 'hadm_id'
          )


X_df.head()
# Out:
#     stay_id  subject_id     hadm_id gender                      race  \
# 0  30000012    11714491  21562392.0      F                     WHITE
# 1  30000038    13821532  26255538.0      F                     WHITE
# 2  30000039    13340997  23100190.0      M                     WHITE
# 3  30000177    17937834  23831044.0      M  ASIAN - SOUTH EAST ASIAN
# 4  30000204    11615015  25540031.0      M                     WHITE
#
#    ed_los_hours  acuity  is_admitted disposition  medication_count  \
# 0      5.616667     2.0         True    ADMITTED              14.0
# 1      3.300000     3.0         True    ADMITTED              12.0
# 2      8.516667     3.0         True    ADMITTED               4.0
# 3      4.966667     2.0         True    ADMITTED              16.0
# 4     12.150000     3.0         True        HOME              10.0
#
#    hosp_los_hours
# 0       65.000000
# 1       45.616667
# 2       46.766667
# 3       37.266667
# 4        7.083333

# %%
X_df.shape
# Out:
# (203016, 11)

# %% [markdown]
# 78 rows have negative hosp_los_hours, we'll just drop these since it's a small amount compared to total shape

# %% [markdown]
# ## Imputing missingness

# %%
X_df.isna().sum()
# Out:
# stay_id                0
# subject_id             0
# hadm_id                0
# gender                 0
# race                   0
# ed_los_hours           0
# acuity              5192
# is_admitted            0
# disposition            0
# medication_count       0
# hosp_los_hours        26
# dtype: int64

# %% [markdown]
# Majority of missing values in `acuity`

# %% [markdown]
# We'll impute `acuity` missingness with the median since we have an imbalanced distribution

# %%
X_df['acuity'].plot(kind='hist')
plt.title('Distribution of Acuity')
plt.xlabel('Acuity')
# Out:
# Text(0.5, 0, 'Acuity')

# %%
X_df['acuity'] = X_df['acuity'].fillna(X_df['acuity'].median())

# %%
X_df.isna().sum()
# Out:
# stay_id              0
# subject_id           0
# hadm_id              0
# gender               0
# race                 0
# ed_los_hours         0
# acuity               0
# is_admitted          0
# disposition          0
# medication_count     0
# hosp_los_hours      26
# dtype: int64

# %% [markdown]
# ### Distribution of ED LOS

# %%
X_df['ed_los_hours'].plot(kind = 'hist', bins = 50)
plt.title('Distribution of ED Length of Stay (hours)')
plt.xlabel('Hours')
# Out:
# Text(0.5, 0, 'Hours')

# %%
# X_df[['ed_los_hours', 'hosp_los_hours']].plot(x = 'ed_los_hours', 
#                                               y = 'hosp_los_hours',
#                                               kind = 'scatter')

# %% [markdown]
# ## Dealing with Race column

# %% [markdown]
# The race column is very granular, this will cause issues for our predictor

# %%
X_df['race'].unique()
# Out:
# array(['WHITE', 'ASIAN - SOUTH EAST ASIAN', 'BLACK/AFRICAN AMERICAN',
#        'HISPANIC/LATINO - PUERTO RICAN', 'ASIAN - ASIAN INDIAN',
#        'HISPANIC/LATINO - DOMINICAN', 'HISPANIC/LATINO - SALVADORAN',
#        'ASIAN', 'HISPANIC/LATINO - MEXICAN', 'WHITE - OTHER EUROPEAN',
#        'WHITE - EASTERN EUROPEAN', 'OTHER', 'UNKNOWN',
#        'HISPANIC OR LATINO', 'HISPANIC/LATINO - HONDURAN',
#        'HISPANIC/LATINO - GUATEMALAN', 'BLACK/AFRICAN', 'WHITE - RUSSIAN',
#        'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'PORTUGUESE',
#        'SOUTH AMERICAN', 'ASIAN - CHINESE', 'WHITE - BRAZILIAN',
#        'HISPANIC/LATINO - CUBAN', 'UNABLE TO OBTAIN',
#        'BLACK/CAPE VERDEAN', 'BLACK/CARIBBEAN ISLAND',
#        'AMERICAN INDIAN/ALASKA NATIVE',
#        'HISPANIC/LATINO - CENTRAL AMERICAN',
#        'HISPANIC/LATINO - COLUMBIAN', 'PATIENT DECLINED TO ANSWER',
#        'ASIAN - KOREAN', 'MULTIPLE RACE/ETHNICITY'], dtype=object)

# %% [markdown]
# Lets define 6 main categories: white, black, hispanic, asian, native/PI, and other

# %%
def simplify_race(r):
    r = str(r).upper()  # make sure comparison is case-insensitive
    if 'WHITE' in r:
        return 'WHITE'
    elif 'BLACK' in r or 'AFRICAN' in r:
        return 'BLACK'
    elif 'HISPANIC' in r or 'LATINO' in r:
        return 'HISPANIC'
    elif 'ASIAN' in r:
        return 'ASIAN'
    elif 'NATIVE' in r or 'PACIFIC' in r or 'ALASKA' in r:
        return 'NATIVE/PI'
    else:
        return 'OTHER'

# %%
X_df['race'] = X_df['race'].apply(simplify_race)

# %%
X_df['race'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='race'>

# %% [markdown]
# ## Missing/Negative `hosp_los_hours`

# %%
X_df['hosp_los_hours'].describe()
# Out:
# count    202990.000000
# mean        102.644086
# std         152.808069
# min         -22.650000
# 25%          21.683333
# 50%          61.883333
# 75%         121.400000
# max        5990.050000
# Name: hosp_los_hours, dtype: float64

# %%
X_df['hosp_los_hours'].plot(kind = 'hist', bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 78 Rows have admitted los <= 0, and

# %%
print('Num negative hours:' , (X_df['hosp_los_hours']< 0).sum())

print('Num na:', (X_df['hosp_los_hours'].isna().sum()))
# Out:
# Num negative hours: 78
# Num na: 26

# %%
print((78+26)/X_df.shape[0])
print(X_df.shape[0])
# Out:
# 0.000512274894589589
# 203016

# %% [markdown]
# **We'll just drop these rows since it makes up a small proportion of total number of rows in training data**)

# %%
X_df = X_df[X_df['hosp_los_hours'].notna()]

print(X_df.shape)

X_df = X_df[X_df['hosp_los_hours'] > 0]
print('shape after dropping')
print(X_df.shape)
# Out:
# (202990, 11)
# shape after dropping
# (202912, 11)

# %%
print('Num negative hours:' , (X_df['hosp_los_hours']< 0).sum())

print('Num na:', (X_df['hosp_los_hours'].isna().sum()))
# Out:
# Num negative hours: 0
# Num na: 0

# %% [markdown]
# Since `hosp_los_hours` is right skewed, lets apply log

# %%
X_df['log_hosp_los_hours'] = np.log(X_df['hosp_los_hours'])

# %%
X_df['log_hosp_los_hours'].plot(kind = 'hist', bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Including ICD as Predictor

# %% [markdown]
# We will be using `triage_df` to pull icd information as predictor

# %%
triage_df.head()
# Out:
#     stay_id  subject_id icd_code  icd_version                   icd_title
# 0  30000012    11714491     5722            9      HEPATIC ENCEPHALOPATHY
# 1  30000012    11714491     5990            9    URIN TRACT INFECTION NOS
# 2  30000017    14230614      V08            9  ASYMPTOMATIC HIV INFECTION
# 3  30000017    14230614     4019            9            HYPERTENSION NOS
# 4  30000017    14230614    30300            9     AC ALCOHOL INTOX-UNSPEC

# %%
icd_df = triage_df[['stay_id', 'icd_code', 'icd_version', 'icd_title']]

# %% [markdown]
# One stay_id can have multiple icd_codes attached to it

# %%
icd_df.groupby('stay_id').count()
# Out:
#           icd_code  icd_version  icd_title
# stay_id
# 30000012         2            2          2
# 30000017         5            5          5
# 30000038         1            1          1
# 30000039         4            4          4
# 30000055         2            2          2
# ...            ...          ...        ...
# 39999939         3            3          3
# 39999953         2            2          2
# 39999961         3            3          3
# 39999964         2            2          2
# 39999965         2            2          2
#
# [423930 rows x 3 columns]

# %% [markdown]
# We confirm that each stay is recorded with one icd_version only

# %%
version_counts = (
    icd_df
    .groupby("stay_id")["icd_version"]
    .nunique()
)

(version_counts > 1).sum()
# Out:
# 0

# %%
X_df = X_df.merge(icd_df, how = 'left', on = 'stay_id')

# %%
icd_missing_count = X_df[X_df['icd_code'].isna()].shape[0]

print('# Rows missing icd:', icd_missing_count)
print('Proportion of dataset:', icd_missing_count/len(X_df))
# Out:
# # Rows missing icd: 798
# Proportion of dataset: 0.0018908563588930672

# %%
print(X_df.shape)
X_df = X_df[X_df['icd_code'].notna()]
X_df.shape
# Out:
# (422031, 15)
# (421233, 15)

# %%
X_df.head()
# Out:
#     stay_id  subject_id     hadm_id gender   race  ed_los_hours  acuity  \
# 0  30000012    11714491  21562392.0      F  WHITE      5.616667     2.0
# 1  30000012    11714491  21562392.0      F  WHITE      5.616667     2.0
# 2  30000038    13821532  26255538.0      F  WHITE      3.300000     3.0
# 3  30000039    13340997  23100190.0      M  WHITE      8.516667     3.0
# 4  30000039    13340997  23100190.0      M  WHITE      8.516667     3.0
#
#    is_admitted disposition  medication_count  hosp_los_hours  \
# 0         True    ADMITTED              14.0       65.000000
# 1         True    ADMITTED              14.0       65.000000
# 2         True    ADMITTED              12.0       45.616667
# 3         True    ADMITTED               4.0       46.766667
# 4         True    ADMITTED               4.0       46.766667
#
#    log_hosp_los_hours icd_code  icd_version                        icd_title
# 0            4.174387     5722          9.0           HEPATIC ENCEPHALOPATHY
# 1            4.174387     5990          9.0         URIN TRACT INFECTION NOS
# 2            3.820273     J189         10.0  PNEUMONIA, UNSPECIFIED ORGANISM
# 3            3.845171    80709          9.0          FX MULT RIBS NOS-CLOSED
# 4            3.845171     8054          9.0         FX LUMBAR VERTEBRA-CLOSE

# %%
# X_df.to_csv('../../../MIMIC_ED/processed/los_training_df.csv', index=False)

# %% [markdown]
# # Probability aggregates for simmer

# %% [markdown]
# ## Probability Distribution for Sex

# %%
p_sex = (
    ed_stays_df['gender']
    .value_counts(normalize=True)     
    .rename('probability')           
    .to_frame()                      
)

p_sex
# Out:
#         probability
# gender
# F           0.54083
# M           0.45917

# %% [markdown]
# ## Probability Distribution for Disposition

# %%
p_disposition = (
    ed_stays_df['disposition']
    .value_counts(normalize=True)     # gives proportions
    .rename('probability')            # name the resulting column
    .to_frame()                       # convert Series → DataFrame
)
p_disposition
# Out:
#                              probability
# disposition
# HOME                            0.568494
# ADMITTED                        0.371764
# TRANSFER                        0.016528
# LEFT WITHOUT BEING SEEN         0.014479
# ELOPED                          0.013434
# OTHER                           0.009988
# LEFT AGAINST MEDICAL ADVICE     0.004426
# EXPIRED                         0.000887

# %% [markdown]
# ## Activity Transition Probabilities + Inter Activity Mean Times

# %%
# Ensure sorted by patient/stay and activity sequence
ed_activities = ed_activity_log.sort_values(['subject_id', 'stay_id', 'activity_seq'])

# Create a column for the next activity per stay
ed_activities['next_activity'] = ed_activities.groupby('stay_id')['activity'].shift(-1)

# %%
ed_activities[ed_activities['next_activity'] == 'Enter the ED']
# Out:
#           stay_id  subject_id     hadm_id           timestamps  \
# 3337465  38926302    10004235  24181354.0  2196-02-24 11:41:00
# 2311001  36185653    10012853  26369609.0  2175-04-05 06:05:00
# 3006334  38041922    10015129  28571111.0  2130-02-11 00:00:00
# 3493885  39346340    10022281  29642388.0  2125-06-16 20:31:00
# 3329605  38904496    10026754         NaN  2137-03-18 00:00:00
# ...           ...         ...         ...                  ...
# 1466625  33927080    19935090  29758053.0  2116-07-14 03:55:00
# 1010598  32707171    19959042  22613316.0  2139-10-22 13:51:00
# 1695282  34539013    19960879  29288546.0  2169-05-08 11:54:00
# 2552573  36832103    19973404  23868350.0  2166-01-01 06:02:00
# 3080299  38241198    19996070  21342238.0  2163-03-17 01:20:00
#
#                        activity  acuity  activity_seq next_activity
# 3337465  Medicine dispensations     NaN             1  Enter the ED
# 2311001        Vital sign check     NaN             1  Enter the ED
# 3006334        Vital sign check     NaN             1  Enter the ED
# 3493885        Vital sign check     NaN             1  Enter the ED
# 3329605        Vital sign check     NaN             1  Enter the ED
# ...                         ...     ...           ...           ...
# 1466625  Medicine dispensations     NaN             2  Enter the ED
# 1010598  Medicine dispensations     NaN             1  Enter the ED
# 1695282        Vital sign check     NaN             1  Enter the ED
# 2552573  Medicine dispensations     NaN             2  Enter the ED
# 3080299        Vital sign check     NaN             1  Enter the ED
#
# [1254 rows x 8 columns]

# %%
# Drop rows where next_activity is NaN (i.e., last activity in stay)
transitions = ed_activities.dropna(subset=['next_activity'])

# Count how many times each transition occurs
transition_counts = transitions.groupby(['activity', 'next_activity']).size().unstack(fill_value=0)
# Divide each row by its sum to get probabilities

activity_order = ['Enter the ED', 'Triage in the ED', 'Medicine reconciliation', 'Medicine dispensations', 'Vital sign check',]
next_activity_order = ['Enter the ED', 'Triage in the ED', 'Medicine reconciliation', 'Medicine dispensations', 'Vital sign check', 'Discharge from the ED']

transition_matrix = transition_counts.div(transition_counts.sum(axis=1), axis=0)
transition_matrix = transition_matrix.loc[activity_order, next_activity_order]

# %%
transition_matrix
# Out:
# next_activity            Enter the ED  Triage in the ED  \
# activity
# Enter the ED                 0.000000          0.815297
# Triage in the ED             0.000000          0.000000
# Medicine reconciliation      0.000009          0.000000
# Medicine dispensations       0.000326          0.000118
# Vital sign check             0.000721          0.055848
#
# next_activity            Medicine reconciliation  Medicine dispensations  \
# activity
# Enter the ED                            0.000000                0.000252
# Triage in the ED                        0.301775                0.163615
# Medicine reconciliation                 0.042222                0.356961
# Medicine dispensations                  0.065990                0.264208
# Vital sign check                        0.098206                0.249485
#
# next_activity            Vital sign check  Discharge from the ED
# activity
# Enter the ED                     0.184451               0.000000
# Triage in the ED                 0.507623               0.026986
# Medicine reconciliation          0.545015               0.055793
# Medicine dispensations           0.580144               0.089215
# Vital sign check                 0.360656               0.235083

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(transition_matrix, annot=True, fmt=".2f", cmap="Blues")
plt.title("ED Activity Transition Probabilities")
plt.xticks(rotation = 45)
plt.show()

# %%
# Ensure timestamps are datetime
ed_activities['timestamps'] = pd.to_datetime(ed_activities['timestamps'])

# Create next_timestamp per stay
ed_activities['next_timestamp'] = (
    ed_activities
    .groupby('stay_id')['timestamps']
    .shift(-1)
)

# Compute inter-activity time
ed_activities['inter_time'] = (
    ed_activities['next_timestamp'] - ed_activities['timestamps']
)

# Mean time between activity → next_activity
mean_inter_times = (
    ed_activities
    .groupby(['activity', 'next_activity'])['inter_time']
    .mean()
    .dropna()
)

# Convert to minutes
mean_inter_times_minutes = mean_inter_times.dt.total_seconds() / 60


activity_order = ['Enter the ED', 'Triage in the ED', 'Medicine reconciliation', 'Medicine dispensations', 'Vital sign check',]
next_activity_order = ['Enter the ED', 'Triage in the ED', 'Medicine reconciliation', 'Medicine dispensations', 'Vital sign check', 'Discharge from the ED']


# Make matrix for heatmap
mean_inter_matrix = mean_inter_times_minutes.unstack(fill_value=0)
mean_inter_matrix = mean_inter_matrix.loc[activity_order, next_activity_order]

# Plot heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(mean_inter_matrix, cmap='Blues', annot=True, fmt=".1f")
plt.title("Mean Inter-Activity Times (minutes): A → B")
plt.xlabel("Next Activity")
plt.ylabel("Current Activity")
plt.xticks(rotation = 45)

plt.show()

# %%
mean_inter_matrix
# Out:
# next_activity            Enter the ED  Triage in the ED  \
# activity
# Enter the ED                 0.000000          0.016667
# Triage in the ED             0.000000          0.000000
# Medicine reconciliation     12.333333          0.000000
# Medicine dispensations     790.092437          0.016667
# Vital sign check           754.843040          0.016667
#
# next_activity            Medicine reconciliation  Medicine dispensations  \
# activity
# Enter the ED                            0.000000                0.000000
# Triage in the ED                       73.012710               80.488187
# Medicine reconciliation                20.000072               57.976733
# Medicine dispensations                 27.537236               52.129917
# Vital sign check                       55.110634               61.603814
#
# next_activity            Vital sign check  Discharge from the ED
# activity
# Enter the ED                     0.000000               0.000000
# Triage in the ED                35.426041             138.866097
# Medicine reconciliation         72.168554              84.014439
# Medicine dispensations          58.709472              60.674971
# Vital sign check               102.512005              47.124184

# %%
transition_matrix
# Out:
# next_activity            Enter the ED  Triage in the ED  \
# activity
# Enter the ED                 0.000000          0.815297
# Triage in the ED             0.000000          0.000000
# Medicine reconciliation      0.000009          0.000000
# Medicine dispensations       0.000326          0.000118
# Vital sign check             0.000721          0.055848
#
# next_activity            Medicine reconciliation  Medicine dispensations  \
# activity
# Enter the ED                            0.000000                0.000252
# Triage in the ED                        0.301775                0.163615
# Medicine reconciliation                 0.042222                0.356961
# Medicine dispensations                  0.065990                0.264208
# Vital sign check                        0.098206                0.249485
#
# next_activity            Vital sign check  Discharge from the ED
# activity
# Enter the ED                     0.184451               0.000000
# Triage in the ED                 0.507623               0.026986
# Medicine reconciliation          0.545015               0.055793
# Medicine dispensations           0.580144               0.089215
# Vital sign check                 0.360656               0.235083
