# %% [markdown]
# # Instead of always being admitted to hospital, dispostition decision is sampled from dataset

# %% [markdown]
# Setup

# %%
# Load libraries
library(simmer)
library(simmer.plot)
library(tidyverse)
library(tidymodels)

# Set seed for reproducibility
set.seed(42)
# Out:
# Loading required package: ggplot2
#
#
# Attaching package: ‘simmer.plot’
#
#
# The following objects are masked from ‘package:simmer’:
#
#     get_mon_arrivals, get_mon_attributes, get_mon_resources
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.5.2
# ✔ lubridate 1.9.4     ✔ tibble    3.3.0
# ✔ purrr     1.1.0     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()       masks stats::filter()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ lubridate::now()      masks simmer::now()
# ✖ lubridate::rollback() masks simmer::rollback()
# ✖ dplyr::select()       masks simmer::select()
# ✖ tidyr::separate()     masks simmer::separate()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.4.1 ──
#
# ✔ broom        1.0.10     ✔ rsample      1.3.1
# ✔ dials        1.4.2      ✔ tailor       0.1.0
# ✔ infer        1.0.9      ✔ tune         2.0.1
# ✔ modeldata    1.5.1      ✔ workflows    1.3.0
# ✔ parsnip      1.3.3      ✔ workflowsets 1.1.1
# ✔ recipes      1.3.1      ✔ yardstick    1.3.2
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ dplyr::select()   masks simmer::select()
# ✖ tidyr::separate() masks simmer::separate()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
# Load MIMIC-IV data

# Define data directory
# data_dir <- "~/Desktop/MIMIC_ED/processed/"
data_dir <- "../../../MIMIC_ED/processed/" 


# Load all four tables
ed_stays <- read_csv(paste0(data_dir, "ed_stays.csv"))
ed_activities <- read_csv(paste0(data_dir, "ed_activity_log.csv"))
ed_diagnoses <- read_csv(paste0(data_dir, "ed_diagnoses.csv"))
ed_medications <- read_csv(paste0(data_dir, "ed_medications.csv"))


# query medcount per stay
med_count_per_stay <- ed_medications %>%
  group_by(stay_id) %>%
  summarise(medication_count = n())
# Out:
# Rows: 425028 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): gender, race, arrival_transport, disposition, chiefcomplaint
# dbl  (5): stay_id, subject_id, hadm_id, acuity, ed_los_hours
# lgl  (1): is_admitted
# dttm (3): arrival_time, triage_time, depart_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3737756 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): activity
# dbl  (5): stay_id, subject_id, hadm_id, acuity, activity_seq
# dttm (1): timestamps
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 898730 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): icd_code, icd_title
# dbl (3): stay_id, subject_id, icd_version
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3607490 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): medication_name, gsn, ndc
# dbl  (2): stay_id, subject_id
# dttm (1): timestamps
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# DATA CLEANING FOR ED SIMULATION

# Filter for admitted patients only
ed_admitted <- ed_stays %>%
  filter(is_admitted == TRUE) %>%
  mutate(
    los_minutes = ed_los_hours * 60,
    los_minutes = if_else(is.na(los_minutes) | los_minutes <= 0, 
                          median(los_minutes, na.rm = TRUE), 
                          los_minutes)
  )

# Check for inconsistencies
inconsistencies <- ed_stays %>%
  filter(disposition == "ADMITTED" & is_admitted == FALSE) %>%
  nrow()

cat("\n=== DATA QUALITY CHECKS ===\n")
cat("Inconsistent records (disposition=ADMITTED but is_admitted=FALSE):", inconsistencies, "\n")

# Overall statistics
total_visits <- nrow(ed_stays)
total_admitted <- nrow(ed_admitted)
admission_rate <- round(100 * total_admitted / total_visits, 1)

cat("\n=== COHORT SUMMARY ===\n")
cat("Total ED visits:", format(total_visits, big.mark = ","), "\n")
cat("Admitted patients:", format(total_admitted, big.mark = ","), 
    "(", admission_rate, "%)\n")

# LOS distribution for admitted patients
cat("\n=== LOS DISTRIBUTION (Admitted Patients) ===\n")
cat("Minutes:\n")
print(summary(ed_admitted$los_minutes))
cat("\nHours:\n")
print(summary(ed_admitted$ed_los_hours))

# Calculate 80th percentile threshold
los_threshold_80 <- quantile(ed_admitted$los_minutes, 0.80, na.rm = TRUE)
cat("\n=== TRANSFER THRESHOLD (for Phase 2) ===\n")
cat("80th percentile:", round(los_threshold_80, 2), "minutes")
cat(" (", round(los_threshold_80/60, 2), "hours)\n")

# Visualize real MIMIC distribution
ggplot(ed_admitted, aes(x = los_minutes)) +
  geom_histogram(bins = 50, fill = "steelblue", color = "white", alpha = 0.8) +
  geom_vline(aes(xintercept = mean(los_minutes, na.rm = TRUE)), 
             color = "red", linetype = "dashed", linewidth = 1) +
  geom_vline(aes(xintercept = los_threshold_80), 
             color = "orange", linetype = "dashed", linewidth = 1) +
  labs(
    title = "MIMIC-IV: Distribution of LOS for Admitted ED Patients",
    subtitle = "Red = mean | Orange = 80th percentile (future transfer threshold)",
    x = "Length of Stay (minutes)",
    y = "Count of Patients"
  ) +
  theme_minimal() +
  theme(plot.title = element_text(face = "bold"))
# Out:
# === DATA QUALITY CHECKS ===
# Inconsistent records (disposition=ADMITTED but is_admitted=FALSE): 0
#
# === COHORT SUMMARY ===
# Total ED visits: 425,028
# Admitted patients: 158,010 ( 37.2 %)
#
# === LOS DISTRIBUTION (Admitted Patients) ===
# Minutes:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0   260.0   374.0   436.6   527.0 29584.2
#
# Hours:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#   0.0167   4.3333   6.2333   7.2772   8.7833 493.0694
#
# === TRANSFER THRESHOLD (for Phase 2) ===
# 80th percentile: 573 minutes ( 9.55 hours)
# plot without title

# %% [markdown]
# Parameters

# %%
# function that simplifies race into 6 main categories (the model uses it so it needs to be defined here)
simplify_race <- function(r) {
  r <- toupper(as.character(r))
  
  if (grepl("WHITE", r)) {
    "WHITE"
  } else if (grepl("BLACK", r) || grepl("AFRICAN", r)) {
    "BLACK"
  } else if (grepl("HISPANIC", r) || grepl("LATINO", r)) {
    "HISPANIC"
  } else if (grepl("ASIAN", r)) {
    "ASIAN"
  } else if (grepl("NATIVE", r) || grepl("PACIFIC", r) || grepl("ALASKA", r)) {
    "NATIVE/PI"
  } else {
    "OTHER"
  }
}

simplify_race_vec <- function(r) {
  sapply(r, simplify_race)
}

# log_hosp_los_hours ~ acuity + race + gender + ed_los_hours + medication_count
mod <- readRDS("../models/model_v1.rds")

# %%
# Resource capacities (start with infinite as Karandeep suggested)
ED_BED_CAPACITY <- Inf

# Time distributions using MIMIC IV data
los_time <- function() sample(ed_admitted$los_minutes, 1)



# Arrival rate (placeholder, used Karandeep's code ~3.33 patients per hour)
arrival_interval <- function() rexp(1, 1/(18/60))

# Store the transfer threshold for Phase 2
LOS_TRANSFER_THRESHOLD <- los_threshold_80

cat("   - LOS: Sampling from", format(nrow(ed_admitted), big.mark = ","), 
    "admitted patient records\n")
cat("   - Mean LOS:", round(mean(ed_admitted$los_minutes), 1), "minutes",
    "(", round(mean(ed_admitted$los_minutes)/60, 2), "hours)\n")
cat("   - Transfer threshold:", round(LOS_TRANSFER_THRESHOLD, 1), "minutes",
    "(", round(LOS_TRANSFER_THRESHOLD/60, 2), "hours)\n")
# Out:
#    - LOS: Sampling from 158,010 admitted patient records
#    - Mean LOS: 436.6 minutes ( 7.28 hours)
#    - Transfer threshold: 573 minutes ( 9.55 hours)

# %% [markdown]
# Patient Trajectory

# %%
# Define patient flow through ED
patient_trajectory <- trajectory("ED patient flow") %>%
  seize("ed_bed", 1) %>%              # Patient occupies ED bed
  timeout(los_time) %>%               # Stay for length of stay
  release("ed_bed", 1) %>%               # Leave ED (disposition)

# Predict hospital LOS and store it
  log_(function() {
    patient_counter <<- patient_counter + 1  # increment patient ID
    
    # Sample predictors
    new_patient <- tibble(
      acuity = sample(ed_stays$acuity, 1),
      race = sample(ed_stays$race, 1),
      gender = sample(ed_stays$gender, 1),
      ed_los_hours = sample(ed_stays$ed_los_hours, 1),
      medication_count = sample(med_count_per_stay$medication_count, 1)
    )
    
    # Predict hospital LOS
    pred_hours <- predict(mod, new_data = new_patient)$.pred %>% expm1()
    
    # Save to tibble
    hospital_los_log <<- bind_rows(
      hospital_los_log,
      tibble(patient_id = patient_counter, pred_hosp_los = pred_hours)
    )
    
    paste("predicted hospital LOS (hours):", round(pred_hours, 1))
    
  })

# %% [markdown]
# Build Sim Environment

# %%
# Create environment
ed_sim <- simmer("ED Simulation V1")

# Add resources
ed_sim %>%
  add_resource("ed_bed", capacity = ED_BED_CAPACITY)

# Add patient generator
ed_sim %>%
  add_generator("patient", patient_trajectory, arrival_interval, mon = 2)
# Out:
# simmer environment: ED Simulation V1 | now: 0 | next:
# { Monitor: in memory }
# { Resource: ed_bed | monitored: TRUE | server status: 0(Inf) | queue status: 0(Inf) }
# simmer environment: ED Simulation V1 | now: 0 | next: 0
# { Monitor: in memory }
# { Resource: ed_bed | monitored: TRUE | server status: 0(Inf) | queue status: 0(Inf) }
# { Source: patient | monitored: 2 | n_generated: 0 }

# %% [markdown]
# Run Sim

# %%
# Create an empty tibble to store results for predicted LOS
hospital_los_log <- tibble(patient_id = integer(), pred_hosp_los = numeric())

# Counter for patient IDs
# patient_counter <- 0

# Run for 24 hours (1440 minutes)
ed_sim %>% run(until = 1440)

# Check final time
simmer::now(ed_sim)
# Out:
# 104.815: patient223: predicted hospital LOS (hours): 66.4
# 122.718: patient12: predicted hospital LOS (hours): 73.4
# 125.967: patient5: predicted hospital LOS (hours): 48.6
# 131.633: patient213: predicted hospital LOS (hours): 10.3
# 134.151: patient140: predicted hospital LOS (hours): 45.5
# 141.099: patient151: predicted hospital LOS (hours): 87.5
# 145.604: patient220: predicted hospital LOS (hours): 25.2
# 160.723: patient25: predicted hospital LOS (hours): 34.1
# 161.229: patient94: predicted hospital LOS (hours): 44.3
# 161.427: patient10: predicted hospital LOS (hours): 243.9
# 161.495: patient4: predicted hospital LOS (hours): 33.6
# 162.837: patient72: predicted hospital LOS (hours): 42
# 166.441: patient197: predicted hospital LOS (hours): 65.5
# 174.638: patient31: predicted hospital LOS (hours): 59.1
# 177.615: patient379: predicted hospital LOS (hours): 79
# 178.48: patient124: predicted hospital LOS (hours): 36.5
# 180.74: patient201: predicted hospital LOS (hours): 83.5
# 181.194: patient142: predicted hospital LOS (hours): 51.1
# 190.542: patient398: predicted hospital LOS (hours): 58.3
# 191.038: patient373: predicted hospital LOS (hours): 52.7
# 191.52: patient112: predicted hospital LOS (hours): 69.1
# 191.752: patient340: predicted hospital LOS (hours): 74.4
# 192.468: patient189: predicted hospital LOS (hours): 47.5
# 193.371: patient110: predicted hospital LOS (hours): 59.3
# 195.455: patient302: predicted hospital LOS (hours): 62.2
# 197.993: patient121: predicted hospital LOS (hours): 50.7
# 199.437: patient255: predicted hospital LOS (hours): 77.2
# 201.899: patient368: predicted hospital LOS (hours): 33.5
# 202.06: patient87: predicted hospital LOS (hours): 93.2
# 204.113: patient53: predicted hospital LOS (hours): 19.9
# 204.915: patient15: predicted hospital LOS (hours): 93
# 204.935: patient56: predicted hospital LOS (hours): 17.8
# 208.655: patient221: predicted hospital LOS (hours): 98.8
# 211.835: patient41: predicted hospital LOS (hours): 50.1
# 213.822: patient67: predicted hospital LOS (hours): 23.8
# 216.577: patient219: predicted hospital LOS (hours): 54.8
# 217.011: patient78: predicted hospital LOS (hours): 60.4
# 217.703: patient49: predicted hospital LOS (hours): 57.2
# 217.797: patient425: predicted hospital LOS (hours): 68.6
# 220.445: patient261: predicted hospital LOS (hours): 81.4
# 226.198: patient234: predicted hospital LOS (hours): 42.9
# 226.455: patient58: predicted hospital LOS (hours): 55.5
# 226.526: patient3: predicted hospital LOS (hours): 66.9
# 229.166: patient23: predicted hospital LOS (hours): 52.7
# 229.999: patient147: predicted hospital LOS (hours): 62.4
# 232.105: patient187: predicted hospital LOS (hours): 98.7
# 236.643: patient108: predicted hospital LOS (hours): 78.7
# 237.323: patient2: predicted hospital LOS (hours): 46
# 240.884: patient83: predicted hospital LOS (hours): 43.8
# 244.019: patient206: predicted hospital LOS (hours): 69
# 245.446: patient635: predicted hospital LOS (hours): 61
# 245.865: patient171: predicted hospital LOS (hours): 16.4
# 247.57: patient299: predicted hospital LOS (hours): 36.6
# 251.74: patient420: predicted hospital LOS (hours): 26
# 253.452: patient45: predicted hospital LOS (hours): 39.9
# 254.708: patient380: predicted hospital LOS (hours): 75.4
# 255.761: patient210: predicted hospital LOS (hours): 25.5
# 256.988: patient16: predicted hospital LOS (hours): 99.9
# 258.513: patient81: predicted hospital LOS (hours): 12
# 261.565: patient175: predicted hospital LOS (hours): 52.2
# 261.608: patient30: predicted hospital LOS (hours): 18.3
# 261.721: patient181: predicted hospital LOS (hours): 82.8
# 263.18: patient11: predicted hospital LOS (hours): 80.3
# 263.617: patient102: predicted hospital LOS (hours): 69.3
# 263.894: patient225: predicted hospital LOS (hours): 62.4
# 263.997: patient115: predicted hospital LOS (hours): 72.8
# 264.136: patient423: predicted hospital LOS (hours): 30.8
# 264.468: patient319: predicted hospital LOS (hours): 19.6
# 266.373: patient385: predicted hospital LOS (hours): 42.3
# 267.74: patient60: predicted hospital LOS (hours): 62.9
# 268.167: patient8: predicted hospital LOS (hours): 40.9
# 268.793: patient352: predicted hospital LOS (hours): 29.6
# 271.146: patient188: predicted hospital LOS (hours): 70.5
# 274.945: patient502: predicted hospital LOS (hours): 71.8
# 275.243: patient309: predicted hospital LOS (hours): 81.5
# 275.494: patient84: predicted hospital LOS (hours): 70.7
# 277.813: patient37: predicted hospital LOS (hours): 225.6
# 278.184: patient671: predicted hospital LOS (hours): 49.4
# 279.325: patient42: predicted hospital LOS (hours): 61.2
# 279.402: patient270: predicted hospital LOS (hours): 61.6
# 279.729: patient410: predicted hospital LOS (hours): 64.6
# 279.743: patient155: predicted hospital LOS (hours): 60
# 280.172: patient333: predicted hospital LOS (hours): 74.6
# 280.661: patient46: predicted hospital LOS (hours): 21.5
# 280.984: patient137: predicted hospital LOS (hours): 9
# 281.514: patient525: predicted hospital LOS (hours): 102.1
# 281.582: patient623: predicted hospital LOS (hours): 78.5
# 282.096: patient64: predicted hospital LOS (hours): 26.1
# 282.808: patient417: predicted hospital LOS (hours): 63.6
# 283.756: patient224: predicted hospital LOS (hours): 70.6
# 284.405: patient21: predicted hospital LOS (hours): 86.1
# 284.947: patient164: predicted hospital LOS (hours): 66.3
# 286.954: patient167: predicted hospital LOS (hours): 30.1
# 288.299: patient191: predicted hospital LOS (hours): 66.9
# 288.842: patient160: predicted hospital LOS (hours): 66.9
# 289.858: patient316: predicted hospital LOS (hours): 60.6
# 289.862: patient127: predicted hospital LOS (hours): 69.6
# 290.155: patient325: predicted hospital LOS (hours): 73.6
# 292.188: patient111: predicted hospital LOS (hours): 77
# 294.253: patient475: predicted hospital LOS (hours): 54.4
# 294.402: patient131: predicted hospital LOS (hours): 50.9
# 294.44: patient736: predicted hospital LOS (hours): 73.5
# 295.219: patient88: predicted hospital LOS (hours): 28.4
# 295.28: patient29: predicted hospital LOS (hours): 24.4
# 296.299: patient521: predicted hospital LOS (hours): 53.6
# 297.027: patient205: predicted hospital LOS (hours): 58.9
# 298.472: patient386: predicted hospital LOS (hours): 62.5
# 299.521: patient70: predicted hospital LOS (hours): 21.2
# 301.08: patient174: predicted hospital LOS (hours): 82.8
# 301.49: patient464: predicted hospital LOS (hours): 72.4
# 303.204: patient55: predicted hospital LOS (hours): 45.8
# 305.158: patient286: predicted hospital LOS (hours): 83.1
# 305.973: patient550: predicted hospital LOS (hours): 50.8
# 306.412: patient116: predicted hospital LOS (hours): 21.5
# 306.993: patient150: predicted hospital LOS (hours): 61.9
# 308.437: patient377: predicted hospital LOS (hours): 58.6
# 309.167: patient169: predicted hospital LOS (hours): 82.8
# 311.622: patient149: predicted hospital LOS (hours): 77.3
# 312.157: patient39: predicted hospital LOS (hours): 60.4
# 312.538: patient180: predicted hospital LOS (hours): 88.7
# 313.15: patient275: predicted hospital LOS (hours): 66.3
# 313.278: patient486: predicted hospital LOS (hours): 19.8
# 313.558: patient617: predicted hospital LOS (hours): 48.8
# 313.805: patient397: predicted hospital LOS (hours): 69
# 314.262: patient227: predicted hospital LOS (hours): 80.4
# 314.643: patient193: predicted hospital LOS (hours): 69.5
# 315.51: patient558: predicted hospital LOS (hours): 40.4
# 316.487: patient355: predicted hospital LOS (hours): 65.4
# 318.325: patient278: predicted hospital LOS (hours): 32
# 318.435: patient443: predicted hospital LOS (hours): 19.8
# 318.626: patient24: predicted hospital LOS (hours): 58.4
# 318.996: patient434: predicted hospital LOS (hours): 77.2
# 319.212: patient555: predicted hospital LOS (hours): 63.5
# 319.712: patient559: predicted hospital LOS (hours): 18.3
# 320.721: patient99: predicted hospital LOS (hours): 48.5
# 320.908: patient267: predicted hospital LOS (hours): 21.7
# 321.976: patient9: predicted hospital LOS (hours): 77
# 322.043: patient707: predicted hospital LOS (hours): 72.6
# 322.231: patient535: predicted hospital LOS (hours): 50.7
# 322.942: patient51: predicted hospital LOS (hours): 70.1
# 323.543: patient920: predicted hospital LOS (hours): 20.5
# 326.116: patient419: predicted hospital LOS (hours): 26.1
# 326.751: patient296: predicted hospital LOS (hours): 25.6
# 327.257: patient79: predicted hospital LOS (hours): 51.7
# 327.556: patient690: predicted hospital LOS (hours): 43.9
# 327.955: patient161: predicted hospital LOS (hours): 83.5
# 328.415: patient17: predicted hospital LOS (hours): 90.3
# 329.275: patient654: predicted hospital LOS (hours): 21.4
# 330.652: patient699: predicted hospital LOS (hours): 62.9
# 330.984: patient244: predicted hospital LOS (hours): 71.5
# 331.249: patient466: predicted hospital LOS (hours): 44.2
# 333.198: patient104: predicted hospital LOS (hours): 60.1
# 333.492: patient276: predicted hospital LOS (hours): 55.6
# 335.016: patient753: predicted hospital LOS (hours): 67.7
# 335.912: patient382: predicted hospital LOS (hours): 65
# 337.083: patient336: predicted hospital LOS (hours): 24.7
# 337.297: patient190: predicted hospital LOS (hours): 49.5
# 337.551: patient13: predicted hospital LOS (hours): 78
# 339.027: patient597: predicted hospital LOS (hours): 12
# 339.805: patient314: predicted hospital LOS (hours): 62.6
# 340.791: patient512: predicted hospital LOS (hours): 23.9
# 340.796: patient787: predicted hospital LOS (hours): 67.8
# 341.223: patient339: predicted hospital LOS (hours): 78.7
# 343.214: patient727: predicted hospital LOS (hours): 21.5
# 343.946: patient259: predicted hospital LOS (hours): 56
# 344.813: patient572: predicted hospital LOS (hours): 40.8
# 345.093: patient564: predicted hospital LOS (hours): 18.8
# 345.698: patient450: predicted hospital LOS (hours): 54.6
# 346.127: patient479: predicted hospital LOS (hours): 28.7
# 346.16: patient588: predicted hospital LOS (hours): 84.6
# 346.259: patient988: predicted hospital LOS (hours): 59.7
# 346.967: patient239: predicted hospital LOS (hours): 67.3
# 349.123: patient527: predicted hospital LOS (hours): 93.7
# 349.405: patient606: predicted hospital LOS (hours): 41.7
# 349.673: patient560: predicted hospital LOS (hours): 27.1
# 351.421: patient236: predicted hospital LOS (hours): 44.1
# 352.136: patient101: predicted hospital LOS (hours): 42.1
# 353.176: patient683: predicted hospital LOS (hours): 62.1
# 353.472: patient107: predicted hospital LOS (hours): 17.9
# 354.059: patient536: predicted hospital LOS (hours): 65.9
# 356.415: patient343: predicted hospital LOS (hours): 44.1
# 358.284: patient467: predicted hospital LOS (hours): 43.8
# 358.301: patient850: predicted hospital LOS (hours): 56.9
# 359.305: patient62: predicted hospital LOS (hours): 24.8
# 360.137: patient531: predicted hospital LOS (hours): 35.1
# 360.771: patient978: predicted hospital LOS (hours): 50
# 360.795: patient318: predicted hospital LOS (hours): 81.1
# 361.297: patient135: predicted hospital LOS (hours): 68.7
# 361.423: patient157: predicted hospital LOS (hours): 53.8
# 361.651: patient476: predicted hospital LOS (hours): 50.2
# 361.927: patient678: predicted hospital LOS (hours): 36.9
# 362.204: patient404: predicted hospital LOS (hours): 104.4
# 363.523: patient33: predicted hospital LOS (hours): 22.7
# 363.84: patient795: predicted hospital LOS (hours): 69.1
# 364.114: patient324: predicted hospital LOS (hours): 29.4
# 364.772: patient416: predicted hospital LOS (hours): 99.4
# 366.623: patient144: predicted hospital LOS (hours): 91.9
# 367.665: patient331: predicted hospital LOS (hours): 23.9
# 367.734: patient533: predicted hospital LOS (hours): 84
# 369.441: patient593: predicted hospital LOS (hours): 48.6
# 370.225: patient519: predicted hospital LOS (hours): 48.1
# 370.948: patient908: predicted hospital LOS (hours): 58.2
# 371.036: patient242: predicted hospital LOS (hours): 69.6
# 371.038: patient313: predicted hospital LOS (hours): 76.6
# 373.747: patient415: predicted hospital LOS (hours): 63.1
# 375.429: patient372: predicted hospital LOS (hours): 35.9
# 378.328: patient260: predicted hospital LOS (hours): 50.2
# 378.349: patient268: predicted hospital LOS (hours): 76.9
# 379.035: patient285: predicted hospital LOS (hours): 69.1
# 379.09: patient186: predicted hospital LOS (hours): 41.5
# 379.178: patient139: predicted hospital LOS (hours): 73
# 379.435: patient89: predicted hospital LOS (hours): 20.3
# 379.97: patient837: predicted hospital LOS (hours): 59.9
# 380.659: patient424: predicted hospital LOS (hours): 76.5
# 380.889: patient804: predicted hospital LOS (hours): 79.4
# 381.506: patient659: predicted hospital LOS (hours): 100.6
# 381.897: patient458: predicted hospital LOS (hours): 86.8
# 382.455: patient447: predicted hospital LOS (hours): 66.4
# 383.146: patient159: predicted hospital LOS (hours): 52.1
# 383.807: patient511: predicted hospital LOS (hours): 31.1
# 384.11: patient442: predicted hospital LOS (hours): 23
# 384.37: patient409: predicted hospital LOS (hours): 88.5
# 384.673: patient510: predicted hospital LOS (hours): 69.6
# 384.799: patient177: predicted hospital LOS (hours): 26.1
# 384.821: patient429: predicted hospital LOS (hours): 62.3
# 385.391: patient661: predicted hospital LOS (hours): 60.5
# 386.319: patient436: predicted hospital LOS (hours): 67
# 386.94: patient470: predicted hospital LOS (hours): 102.1
# 387.439: patient506: predicted hospital LOS (hours): 52.4
# 388.661: patient488: predicted hospital LOS (hours): 24.2
# 389.098: patient518: predicted hospital LOS (hours): 60
# 389.628: patient720: predicted hospital LOS (hours): 62.7
# 390.895: patient184: predicted hospital LOS (hours): 88.5
# 391.626: patient509: predicted hospital LOS (hours): 44.7
# 392.48: patient91: predicted hospital LOS (hours): 66.7
# 392.662: patient614: predicted hospital LOS (hours): 66.8
# 393.829: patient677: predicted hospital LOS (hours): 108.9
# 394.104: patient344: predicted hospital LOS (hours): 44.4
# 394.462: patient375: predicted hospital LOS (hours): 16
# 394.852: patient551: predicted hospital LOS (hours): 66.9
# 397.088: patient185: predicted hospital LOS (hours): 94.8
# 397.908: patient310: predicted hospital LOS (hours): 67.7
# 397.955: patient462: predicted hospital LOS (hours): 39.9
# 398.906: patient173: predicted hospital LOS (hours): 29.3
# 399.183: patient711: predicted hospital LOS (hours): 57.2
# 399.391: patient668: predicted hospital LOS (hours): 70.4
# 400.285: patient440: predicted hospital LOS (hours): 31.2
# 400.542: patient59: predicted hospital LOS (hours): 72.2
# 401.111: patient589: predicted hospital LOS (hours): 26.7
# 402.336: patient322: predicted hospital LOS (hours): 319.2
# 403.079: patient449: predicted hospital LOS (hours): 98.2
# 403.088: patient138: predicted hospital LOS (hours): 50.4
# 404.419: patient391: predicted hospital LOS (hours): 61.7
# 404.553: patient632: predicted hospital LOS (hours): 16.9
# 405.316: patient451: predicted hospital LOS (hours): 71
# 406.304: patient245: predicted hospital LOS (hours): 50.9
# 407.213: patient308: predicted hospital LOS (hours): 66.6
# 407.966: patient405: predicted hospital LOS (hours): 79.2
# 408.611: patient63: predicted hospital LOS (hours): 21.8
# 409.59: patient965: predicted hospital LOS (hours): 43.1
# 409.793: patient50: predicted hospital LOS (hours): 72.2
# 410.603: patient295: predicted hospital LOS (hours): 67.3
# 410.686: patient590: predicted hospital LOS (hours): 16.4
# 411.472: patient141: predicted hospital LOS (hours): 88.7
# 411.676: patient274: predicted hospital LOS (hours): 50.8
# 411.859: patient241: predicted hospital LOS (hours): 146
# 412.738: patient1056: predicted hospital LOS (hours): 11.5
# 412.797: patient6: predicted hospital LOS (hours): 276.7
# 413.383: patient422: predicted hospital LOS (hours): 49.1
# 413.801: patient265: predicted hospital LOS (hours): 47.4
# 414.514: patient48: predicted hospital LOS (hours): 16.7
# 414.728: patient1098: predicted hospital LOS (hours): 29.7
# 415.045: patient854: predicted hospital LOS (hours): 28
# 417.097: patient584: predicted hospital LOS (hours): 81.5
# 417.781: patient448: predicted hospital LOS (hours): 52
# 418.203: patient556: predicted hospital LOS (hours): 47.5
# 418.22: patient498: predicted hospital LOS (hours): 55.9
# 418.687: patient778: predicted hospital LOS (hours): 20.9
# 419.029: patient401: predicted hospital LOS (hours): 75.7
# 419.527: patient813: predicted hospital LOS (hours): 73.4
# 419.969: patient413: predicted hospital LOS (hours): 179.9
# 420.735: patient495: predicted hospital LOS (hours): 79.2
# 420.809: patient301: predicted hospital LOS (hours): 82.6
# 421.33: patient646: predicted hospital LOS (hours): 52.5
# 421.357: patient723: predicted hospital LOS (hours): 50.9
# 422.518: patient941: predicted hospital LOS (hours): 54.8
# 422.577: patient526: predicted hospital LOS (hours): 71
# 422.636: patient627: predicted hospital LOS (hours): 63.7
# 422.65: patient414: predicted hospital LOS (hours): 81.8
# 423.176: patient152: predicted hospital LOS (hours): 82.9
# 423.181: patient670: predicted hospital LOS (hours): 92.7
# 425.876: patient183: predicted hospital LOS (hours): 83.8
# 425.928: patient642: predicted hospital LOS (hours): 20
# 426.216: patient688: predicted hospital LOS (hours): 56.5
# 427.187: patient133: predicted hospital LOS (hours): 26.5
# 427.256: patient399: predicted hospital LOS (hours): 70.6
# 427.521: patient282: predicted hospital LOS (hours): 59.7
# 427.539: patient212: predicted hospital LOS (hours): 96.1
# 427.582: patient408: predicted hospital LOS (hours): 77.6
# 428.796: patient609: predicted hospital LOS (hours): 37.9
# 429.061: patient328: predicted hospital LOS (hours): 104
# 429.286: patient492: predicted hospital LOS (hours): 60
# 429.312: patient757: predicted hospital LOS (hours): 71.4
# 429.968: patient128: predicted hospital LOS (hours): 58.2
# 430.301: patient106: predicted hospital LOS (hours): 86.1
# 430.436: patient532: predicted hospital LOS (hours): 67.7
# 430.504: patient456: predicted hospital LOS (hours): 51.1
# 430.554: patient739: predicted hospital LOS (hours): 51.1
# 431.751: patient473: predicted hospital LOS (hours): 71.6
# 431.783: patient496: predicted hospital LOS (hours): 78.7
# 433.635: patient350: predicted hospital LOS (hours): 19
# 433.773: patient664: predicted hospital LOS (hours): 61.9
# 434.066: patient166: predicted hospital LOS (hours): 100
# 434.089: patient387: predicted hospital LOS (hours): 62.4
# 434.357: patient297: predicted hospital LOS (hours): 72.5
# 435.096: patient561: predicted hospital LOS (hours): 72.9
# 435.456: patient708: predicted hospital LOS (hours): 63.9
# 438.418: patient604: predicted hospital LOS (hours): 46.1
# 438.93: patient605: predicted hospital LOS (hours): 62
# 440.074: patient570: predicted hospital LOS (hours): 65.5
# 440.22: patient689: predicted hospital LOS (hours): 90.7
# 442.03: patient687: predicted hospital LOS (hours): 15.7
# 442.138: patient742: predicted hospital LOS (hours): 40.6
# 443.898: patient812: predicted hospital LOS (hours): 88.9
# 444.083: patient516: predicted hospital LOS (hours): 18.4
# 444.168: patient907: predicted hospital LOS (hours): 31.5
# 444.566: patient143: predicted hospital LOS (hours): 46.3
# 444.773: patient153: predicted hospital LOS (hours): 59.1
# 445.203: patient358: predicted hospital LOS (hours): 91.5
# 445.744: patient1147: predicted hospital LOS (hours): 59.6
# 446.274: patient433: predicted hospital LOS (hours): 67.4
# 446.59: patient229: predicted hospital LOS (hours): 54.4
# 446.594: patient663: predicted hospital LOS (hours): 62.9
# 447.87: patient489: predicted hospital LOS (hours): 99.8
# 448.191: patient35: predicted hospital LOS (hours): 52.9
# 448.668: patient292: predicted hospital LOS (hours): 39.6
# 449.457: patient716: predicted hospital LOS (hours): 62.3
# 450.147: patient281: predicted hospital LOS (hours): 74.1
# 451.195: patient905: predicted hospital LOS (hours): 70.7
# 451.216: patient200: predicted hospital LOS (hours): 88.3
# 452.726: patient1079: predicted hospital LOS (hours): 81.3
# 453.057: patient870: predicted hospital LOS (hours): 48.8
# 453.493: patient766: predicted hospital LOS (hours): 76.1
# 453.738: patient919: predicted hospital LOS (hours): 66.4
# 454.064: patient215: predicted hospital LOS (hours): 64.6
# 455.23: patient287: predicted hospital LOS (hours): 64.9
# 455.426: patient345: predicted hospital LOS (hours): 61.8
# 456.791: patient638: predicted hospital LOS (hours): 23.3
# 457.551: patient363: predicted hospital LOS (hours): 28.8
# 458.065: patient685: predicted hospital LOS (hours): 34.4
# 458.228: patient684: predicted hospital LOS (hours): 60.4
# 458.573: patient258: predicted hospital LOS (hours): 87.6
# 458.775: patient1220: predicted hospital LOS (hours): 55.9
# 460.418: patient922: predicted hospital LOS (hours): 44.2
# 461.415: patient644: predicted hospital LOS (hours): 71.9
# 461.806: patient52: predicted hospital LOS (hours): 24.5
# 462.144: patient552: predicted hospital LOS (hours): 62
# 462.394: patient608: predicted hospital LOS (hours): 50.2
# 464.698: patient863: predicted hospital LOS (hours): 74
# 464.87: patient760: predicted hospital LOS (hours): 64.9
# 465.48: patient170: predicted hospital LOS (hours): 53.9
# 465.632: patient955: predicted hospital LOS (hours): 74
# 465.878: patient347: predicted hospital LOS (hours): 58.5
# 468.056: patient280: predicted hospital LOS (hours): 76.5
# 468.261: patient1013: predicted hospital LOS (hours): 60.4
# 468.42: patient216: predicted hospital LOS (hours): 87.3
# 468.977: patient952: predicted hospital LOS (hours): 61.7
# 469.086: patient763: predicted hospital LOS (hours): 44
# 469.228: patient793: predicted hospital LOS (hours): 97.4
# 469.386: patient312: predicted hospital LOS (hours): 32.2
# 469.507: patient780: predicted hospital LOS (hours): 75.4
# 469.75: patient523: predicted hospital LOS (hours): 59.4
# 470.018: patient953: predicted hospital LOS (hours): 43.6
# 470.081: patient826: predicted hospital LOS (hours): 37.8
# 470.207: patient543: predicted hospital LOS (hours): 65.4
# 470.965: patient38: predicted hospital LOS (hours): 47.5
# 470.979: patient168: predicted hospital LOS (hours): 59.1
# 472.146: patient833: predicted hospital LOS (hours): 65.2
# 473.517: patient445: predicted hospital LOS (hours): 53.9
# 473.797: patient26: predicted hospital LOS (hours): 61.6
# 473.819: patient1016: predicted hospital LOS (hours): 42.2
# 474.458: patient900: predicted hospital LOS (hours): 71.7
# 474.652: patient125: predicted hospital LOS (hours): 37.2
# 475.445: patient702: predicted hospital LOS (hours): 52
# 475.46: patient304: predicted hospital LOS (hours): 56.2
# 477.34: patient317: predicted hospital LOS (hours): 49.5
# 477.447: patient1115: predicted hospital LOS (hours): 34.7
# 477.7: patient814: predicted hospital LOS (hours): 58
# 477.734: patient637: predicted hospital LOS (hours): 72.4
# 478.671: patient636: predicted hospital LOS (hours): 74.8
# 478.869: patient120: predicted hospital LOS (hours): 74.1
# 479.352: patient228: predicted hospital LOS (hours): 37.5
# 480.146: patient354: predicted hospital LOS (hours): 22.3
# 480.38: patient178: predicted hospital LOS (hours): 71.8
# 480.416: patient348: predicted hospital LOS (hours): 120.9
# 481.434: patient715: predicted hospital LOS (hours): 245.4
# 482.071: patient27: predicted hospital LOS (hours): 63.7
# 482.367: patient788: predicted hospital LOS (hours): 71.2
# 482.691: patient853: predicted hospital LOS (hours): 54.7
# 483.065: patient361: predicted hospital LOS (hours): 42.6
# 483.278: patient569: predicted hospital LOS (hours): 62.2
# 483.734: patient307: predicted hospital LOS (hours): 80
# 483.775: patient782: predicted hospital LOS (hours): 101.8
# 484.038: patient674: predicted hospital LOS (hours): 50.9
# 484.218: patient656: predicted hospital LOS (hours): 54.2
# 485.155: patient1: predicted hospital LOS (hours): 97.2
# 485.219: patient571: predicted hospital LOS (hours): 90.6
# 485.353: patient1138: predicted hospital LOS (hours): 28.9
# 486.592: patient483: predicted hospital LOS (hours): 41.5
# 487.257: patient666: predicted hospital LOS (hours): 107.3
# 488.592: patient858: predicted hospital LOS (hours): 57.1
# 490.592: patient484: predicted hospital LOS (hours): 45.2
# 491.004: patient118: predicted hospital LOS (hours): 46.5
# 491.55: patient1228: predicted hospital LOS (hours): 94.9
# 492.175: patient357: predicted hospital LOS (hours): 88.1
# 492.633: patient802: predicted hospital LOS (hours): 77.5
# 492.864: patient474: predicted hospital LOS (hours): 18.4
# 492.978: patient71: predicted hospital LOS (hours): 77.6
# 493.184: patient1122: predicted hospital LOS (hours): 43.4
# 493.266: patient459: predicted hospital LOS (hours): 72
# 494.146: patient735: predicted hospital LOS (hours): 18.9
# 494.351: patient754: predicted hospital LOS (hours): 64.4
# 494.432: patient840: predicted hospital LOS (hours): 29.5
# 494.566: patient452: predicted hospital LOS (hours): 40.3
# 494.571: patient1253: predicted hospital LOS (hours): 59.6
# 494.79: patient872: predicted hospital LOS (hours): 81.9
# 494.857: patient195: predicted hospital LOS (hours): 24.4
# 495.526: patient728: predicted hospital LOS (hours): 61.2
# 498.35: patient1332: predicted hospital LOS (hours): 64.4
# 499.189: patient226: predicted hospital LOS (hours): 94.2
# 500.027: patient969: predicted hospital LOS (hours): 108
# 500.755: patient694: predicted hospital LOS (hours): 38.7
# 500.952: patient591: predicted hospital LOS (hours): 47.2
# 501.655: patient1210: predicted hospital LOS (hours): 61.2
# 501.967: patient1089: predicted hospital LOS (hours): 48.8
# 502.253: patient673: predicted hospital LOS (hours): 26
# 502.567: patient123: predicted hospital LOS (hours): 83.3
# 502.76: patient600: predicted hospital LOS (hours): 71.1
# 504.447: patient903: predicted hospital LOS (hours): 36.2
# 506.017: patient73: predicted hospital LOS (hours): 52.5
# 506.535: patient829: predicted hospital LOS (hours): 40.7
# 507.113: patient1149: predicted hospital LOS (hours): 77.8
# 507.175: patient1033: predicted hospital LOS (hours): 72.9
# 507.651: patient783: predicted hospital LOS (hours): 24
# 507.838: patient596: predicted hospital LOS (hours): 66.2
# 507.953: patient576: predicted hospital LOS (hours): 21.4
# 508.045: patient290: predicted hospital LOS (hours): 80.9
# 508.705: patient717: predicted hospital LOS (hours): 70.5
# 510.266: patient578: predicted hospital LOS (hours): 17.9
# 510.273: patient701: predicted hospital LOS (hours): 37.7
# 511.416: patient74: predicted hospital LOS (hours): 33.9
# 511.469: patient544: predicted hospital LOS (hours): 67.9
# 511.545: patient777: predicted hospital LOS (hours): 43.1
# 512.451: patient240: predicted hospital LOS (hours): 22.6
# 512.745: patient1209: predicted hospital LOS (hours): 96.2
# 512.887: patient1395: predicted hospital LOS (hours): 27.9
# 512.97: patient602: predicted hospital LOS (hours): 73.2
# 513.92: patient263: predicted hospital LOS (hours): 49.6
# 514.659: patient1452: predicted hospital LOS (hours): 27.1
# 514.749: patient40: predicted hospital LOS (hours): 27.8
# 515.693: patient928: predicted hospital LOS (hours): 72.2
# 516.281: patient851: predicted hospital LOS (hours): 20.6
# 516.542: patient697: predicted hospital LOS (hours): 38.5
# 516.589: patient411: predicted hospital LOS (hours): 46.3
# 516.6: patient653: predicted hospital LOS (hours): 31.8
# 516.89: patient892: predicted hospital LOS (hours): 44.7
# 517.016: patient1523: predicted hospital LOS (hours): 184.2
# 517.474: patient622: predicted hospital LOS (hours): 69.7
# 518.453: patient252: predicted hospital LOS (hours): 61.9
# 518.765: patient412: predicted hospital LOS (hours): 46
# 519.164: patient1068: predicted hospital LOS (hours): 41.1
# 519.299: patient676: predicted hospital LOS (hours): 52.8
# 519.787: patient1087: predicted hospital LOS (hours): 64.3
# 519.855: patient145: predicted hospital LOS (hours): 80.7
# 519.931: patient1261: predicted hospital LOS (hours): 74.6
# 520.213: patient1203: predicted hospital LOS (hours): 95.4
# 520.953: patient146: predicted hospital LOS (hours): 57
# 521.108: patient696: predicted hospital LOS (hours): 60.5
# 521.205: patient329: predicted hospital LOS (hours): 85.2
# 521.279: patient985: predicted hospital LOS (hours): 58.7
# 521.35: patient1021: predicted hospital LOS (hours): 58.9
# 522.755: patient781: predicted hospital LOS (hours): 72.4
# 522.936: patient371: predicted hospital LOS (hours): 68.8
# 523.366: patient97: predicted hospital LOS (hours): 82.5
# 524.114: patient832: predicted hospital LOS (hours): 30.2
# 524.181: patient480: predicted hospital LOS (hours): 29
# 524.967: patient917: predicted hospital LOS (hours): 78.7
# 525.039: patient1134: predicted hospital LOS (hours): 73.4
# 525.411: patient658: predicted hospital LOS (hours): 72.5
# 526.654: patient744: predicted hospital LOS (hours): 78.6
# 526.679: patient305: predicted hospital LOS (hours): 94.7
# 527.251: patient935: predicted hospital LOS (hours): 67.2
# 527.694: patient431: predicted hospital LOS (hours): 78.2
# 528.073: patient1237: predicted hospital LOS (hours): 36.2
# 528.497: patient1101: predicted hospital LOS (hours): 78.7
# 529.462: patient461: predicted hospital LOS (hours): 25.5
# 529.83: patient835: predicted hospital LOS (hours): 62.3
# 530.48: patient129: predicted hospital LOS (hours): 22.9
# 531.172: patient1403: predicted hospital LOS (hours): 37.8
# 531.207: patient105: predicted hospital LOS (hours): 75.8
# 531.648: patient772: predicted hospital LOS (hours): 73.2
# 532.039: patient463: predicted hospital LOS (hours): 86.7
# 532.18: patient838: predicted hospital LOS (hours): 74.2
# 533.647: patient1265: predicted hospital LOS (hours): 241.6
# 534.28: patient1359: predicted hospital LOS (hours): 74.8
# 534.351: patient1238: predicted hospital LOS (hours): 51.5
# 534.562: patient165: predicted hospital LOS (hours): 75.8
# 537.663: patient1143: predicted hospital LOS (hours): 67.7
# 538.187: patient1218: predicted hospital LOS (hours): 86.8
# 538.607: patient253: predicted hospital LOS (hours): 71.2
# 539.295: patient80: predicted hospital LOS (hours): 82.6
# 539.387: patient303: predicted hospital LOS (hours): 50.8
# 540.747: patient388: predicted hospital LOS (hours): 81.7
# 541.068: patient1088: predicted hospital LOS (hours): 55.8
# 541.897: patient1520: predicted hospital LOS (hours): 18.6
# 542.784: patient993: predicted hospital LOS (hours): 66.9
# 543.212: patient1296: predicted hospital LOS (hours): 76.3
# 543.679: patient364: predicted hospital LOS (hours): 41.2
# 544.519: patient179: predicted hospital LOS (hours): 97.9
# 544.738: patient524: predicted hospital LOS (hours): 50.3
# 544.856: patient381: predicted hospital LOS (hours): 25.8
# 545.948: patient1233: predicted hospital LOS (hours): 78.2
# 546.28: patient619: predicted hospital LOS (hours): 84.3
# 547.125: patient577: predicted hospital LOS (hours): 40.9
# 547.246: patient767: predicted hospital LOS (hours): 65
# 547.457: patient98: predicted hospital LOS (hours): 62.9
# 547.559: patient500: predicted hospital LOS (hours): 80.6
# 547.56: patient1032: predicted hospital LOS (hours): 97.9
# 547.848: patient902: predicted hospital LOS (hours): 58.5
# 548.296: patient759: predicted hospital LOS (hours): 54.7
# 548.46: patient980: predicted hospital LOS (hours): 57.2
# 548.858: patient881: predicted hospital LOS (hours): 80.8
# 549.102: patient298: predicted hospital LOS (hours): 33.4
# 549.344: patient972: predicted hospital LOS (hours): 66.6
# 551.101: patient28: predicted hospital LOS (hours): 21.8
# 551.66: patient554: predicted hospital LOS (hours): 38.3
# 551.757: patient808: predicted hospital LOS (hours): 29.7
# 551.874: patient528: predicted hospital LOS (hours): 54.5
# 552.162: patient248: predicted hospital LOS (hours): 53.8
# 552.404: patient20: predicted hospital LOS (hours): 31.6
# 552.447: patient378: predicted hospital LOS (hours): 80.3
# 552.711: patient134: predicted hospital LOS (hours): 74.5
# 553.318: patient1091: predicted hospital LOS (hours): 29
# 554.61: patient692: predicted hospital LOS (hours): 71.4
# 554.932: patient335: predicted hospital LOS (hours): 52.4
# 555.066: patient1120: predicted hospital LOS (hours): 64
# 555.182: patient592: predicted hospital LOS (hours): 55.2
# 555.73: patient997: predicted hospital LOS (hours): 17
# 556.876: patient714: predicted hospital LOS (hours): 58.5
# 557.067: patient563: predicted hospital LOS (hours): 105.9
# 557.1: patient337: predicted hospital LOS (hours): 40.6
# 557.536: patient1040: predicted hospital LOS (hours): 20.4
# 559.482: patient1097: predicted hospital LOS (hours): 46.6
# 559.617: patient1258: predicted hospital LOS (hours): 79.5
# 559.807: patient884: predicted hospital LOS (hours): 27.9
# 561.147: patient0: predicted hospital LOS (hours): 14.4
# 562.677: patient648: predicted hospital LOS (hours): 45.5
# 562.924: patient1090: predicted hospital LOS (hours): 60.4
# 563.008: patient85: predicted hospital LOS (hours): 37.5
# 563.646: patient1531: predicted hospital LOS (hours): 75.1
# 563.865: patient1321: predicted hospital LOS (hours): 55.3
# 564.375: patient1152: predicted hospital LOS (hours): 67.4
# 564.561: patient1390: predicted hospital LOS (hours): 34.6
# 564.873: patient1392: predicted hospital LOS (hours): 69.9
# 564.9: patient57: predicted hospital LOS (hours): 81.6
# 565.002: patient257: predicted hospital LOS (hours): 13.1
# 565.203: patient1217: predicted hospital LOS (hours): 41.8
# 565.259: patient1409: predicted hospital LOS (hours): 79.2
# 565.386: patient934: predicted hospital LOS (hours): 88.9
# 565.523: patient998: predicted hospital LOS (hours): 16.4
# 565.787: patient649: predicted hospital LOS (hours): 42.2
# 565.976: patient643: predicted hospital LOS (hours): 29.5
# 566.055: patient82: predicted hospital LOS (hours): 85.4
# 566.554: patient1050: predicted hospital LOS (hours): 76.7
# 567.529: patient983: predicted hospital LOS (hours): 62.1
# 568.01: patient444: predicted hospital LOS (hours): 61.3
# 568.122: patient565: predicted hospital LOS (hours): 61.8
# 568.341: patient1055: predicted hospital LOS (hours): 67.5
# 568.684: patient1257: predicted hospital LOS (hours): 24
# 569.064: patient801: predicted hospital LOS (hours): 211.4
# 569.396: patient1313: predicted hospital LOS (hours): 52.9
# 569.416: patient326: predicted hospital LOS (hours): 92.5
# 569.651: patient933: predicted hospital LOS (hours): 40.3
# 570.147: patient601: predicted hospital LOS (hours): 24.8
# 570.349: patient321: predicted hospital LOS (hours): 25.3
# 571.543: patient1552: predicted hospital LOS (hours): 80.3
# 571.635: patient1270: predicted hospital LOS (hours): 61.1
# 571.766: patient710: predicted hospital LOS (hours): 66.2
# 571.933: patient196: predicted hospital LOS (hours): 62.4
# 572.162: patient1302: predicted hospital LOS (hours): 80.7
# 572.518: patient923: predicted hospital LOS (hours): 50.6
# 572.662: patient745: predicted hospital LOS (hours): 22.9
# 573.499: patient93: predicted hospital LOS (hours): 32.4
# 573.657: patient1153: predicted hospital LOS (hours): 16.8
# 575.32: patient1053: predicted hospital LOS (hours): 27.8
# 575.554: patient758: predicted hospital LOS (hours): 56.1
# 576.074: patient915: predicted hospital LOS (hours): 73.6
# 576.209: patient776: predicted hospital LOS (hours): 57.1
# 576.298: patient1175: predicted hospital LOS (hours): 73
# 576.898: patient1348: predicted hospital LOS (hours): 78
# 577.817: patient748: predicted hospital LOS (hours): 81.2
# 579.05: patient1074: predicted hospital LOS (hours): 138.5
# 579.108: patient916: predicted hospital LOS (hours): 66.8
# 579.111: patient272: predicted hospital LOS (hours): 77.9
# 579.256: patient1538: predicted hospital LOS (hours): 84.6
# 579.344: patient369: predicted hospital LOS (hours): 81.5
# 579.953: patient831: predicted hospital LOS (hours): 63.1
# 580.437: patient566: predicted hospital LOS (hours): 38.2
# 580.474: patient505: predicted hospital LOS (hours): 62.6
# 581.456: patient1029: predicted hospital LOS (hours): 46.3
# 581.591: patient367: predicted hospital LOS (hours): 54.7
# 581.833: patient86: predicted hospital LOS (hours): 67.9
# 581.87: patient266: predicted hospital LOS (hours): 70
# 582.02: patient1268: predicted hospital LOS (hours): 64.7
# 582.517: patient1239: predicted hospital LOS (hours): 64.3
# 583.126: patient19: predicted hospital LOS (hours): 60.9
# 583.802: patient517: predicted hospital LOS (hours): 54.1
# 584.057: patient1007: predicted hospital LOS (hours): 77.6
# 584.107: patient1100: predicted hospital LOS (hours): 56.9
# 584.317: patient615: predicted hospital LOS (hours): 35.9
# 584.471: patient651: predicted hospital LOS (hours): 76.9
# 584.911: patient618: predicted hospital LOS (hours): 35.3
# 585.425: patient43: predicted hospital LOS (hours): 40.6
# 585.433: patient389: predicted hospital LOS (hours): 34.2
# 585.924: patient887: predicted hospital LOS (hours): 90
# 586.468: patient691: predicted hospital LOS (hours): 91.3
# 587.394: patient522: predicted hospital LOS (hours): 15.6
# 588.327: patient1193: predicted hospital LOS (hours): 28.8
# 588.742: patient807: predicted hospital LOS (hours): 51.7
# 588.814: patient1037: predicted hospital LOS (hours): 78.7
# 589.049: patient725: predicted hospital LOS (hours): 49.5
# 589.62: patient549: predicted hospital LOS (hours): 21.2
# 589.674: patient962: predicted hospital LOS (hours): 57.1
# 589.87: patient803: predicted hospital LOS (hours): 94
# 590.04: patient1142: predicted hospital LOS (hours): 83.1
# 590.52: patient762: predicted hospital LOS (hours): 31.9
# 591.117: patient878: predicted hospital LOS (hours): 64.2
# 591.429: patient455: predicted hospital LOS (hours): 57.4
# 591.51: patient437: predicted hospital LOS (hours): 61
# 592.033: patient1162: predicted hospital LOS (hours): 83
# 592.165: patient294: predicted hospital LOS (hours): 47.1
# 592.786: patient1752: predicted hospital LOS (hours): 29
# 592.848: patient945: predicted hospital LOS (hours): 141.1
# 593.624: patient103: predicted hospital LOS (hours): 49.4
# 593.672: patient901: predicted hospital LOS (hours): 56.9
# 593.683: patient1278: predicted hospital LOS (hours): 36.4
# 593.724: patient977: predicted hospital LOS (hours): 73.3
# 593.751: patient117: predicted hospital LOS (hours): 60.2
# 593.873: patient1229: predicted hospital LOS (hours): 68.3
# 594.251: patient1148: predicted hospital LOS (hours): 77.9
# 594.422: patient1063: predicted hospital LOS (hours): 40.3
# 594.664: patient895: predicted hospital LOS (hours): 45
# 595.483: patient1085: predicted hospital LOS (hours): 116.8
# 596.931: patient846: predicted hospital LOS (hours): 69
# 597.128: patient61: predicted hospital LOS (hours): 79.6
# 597.327: patient1679: predicted hospital LOS (hours): 60.1
# 597.421: patient932: predicted hospital LOS (hours): 55.2
# 597.776: patient32: predicted hospital LOS (hours): 79.9
# 598.685: patient789: predicted hospital LOS (hours): 76.8
# 598.733: patient1279: predicted hospital LOS (hours): 62.1
# 598.836: patient877: predicted hospital LOS (hours): 47
# 598.981: patient1207: predicted hospital LOS (hours): 71.7
# 598.988: patient203: predicted hospital LOS (hours): 65.7
# 600.01: patient204: predicted hospital LOS (hours): 43.8
# 600.011: patient1256: predicted hospital LOS (hours): 26.3
# 600.185: patient968: predicted hospital LOS (hours): 48.4
# 600.251: patient1069: predicted hospital LOS (hours): 61.1
# 601.366: patient652: predicted hospital LOS (hours): 69.9
# 602.19: patient607: predicted hospital LOS (hours): 50.2
# 602.276: patient839: predicted hospital LOS (hours): 23.4
# 602.53: patient249: predicted hospital LOS (hours): 30.7
# 602.748: patient1010: predicted hospital LOS (hours): 71.6
# 602.894: patient14: predicted hospital LOS (hours): 72.6
# 603.188: patient54: predicted hospital LOS (hours): 54.4
# 603.936: patient427: predicted hospital LOS (hours): 41
# 605.006: patient1080: predicted hospital LOS (hours): 45.5
# 605.571: patient300: predicted hospital LOS (hours): 46
# 605.611: patient1336: predicted hospital LOS (hours): 54.7
# 605.857: patient724: predicted hospital LOS (hours): 104.7
# 606.029: patient1067: predicted hospital LOS (hours): 53.3
# 606.619: patient960: predicted hospital LOS (hours): 23.8
# 606.894: patient1117: predicted hospital LOS (hours): 33.3
# 607.216: patient1222: predicted hospital LOS (hours): 69.9
# 608.234: patient1146: predicted hospital LOS (hours): 43.2
# 608.37: patient889: predicted hospital LOS (hours): 17.6
# 608.685: patient1759: predicted hospital LOS (hours): 75.7
# 609.249: patient485: predicted hospital LOS (hours): 299.2
# 609.733: patient1328: predicted hospital LOS (hours): 65.7
# 609.97: patient1516: predicted hospital LOS (hours): 55.4
# 610.024: patient672: predicted hospital LOS (hours): 82.1
# 610.666: patient798: predicted hospital LOS (hours): 62.6
# 610.905: patient421: predicted hospital LOS (hours): 85.9
# 611.327: patient909: predicted hospital LOS (hours): 60
# 611.51: patient1632: predicted hospital LOS (hours): 93.5
# 611.586: patient580: predicted hospital LOS (hours): 95.6
# 611.755: patient823: predicted hospital LOS (hours): 56
# 612.131: patient786: predicted hospital LOS (hours): 109.3
# 612.322: patient820: predicted hospital LOS (hours): 60.6
# 612.337: patient407: predicted hospital LOS (hours): 90.1
# 612.496: patient721: predicted hospital LOS (hours): 20.5
# 612.583: patient852: predicted hospital LOS (hours): 70.4
# 613.197: patient426: predicted hospital LOS (hours): 91
# 613.288: patient770: predicted hospital LOS (hours): 69.9
# 613.596: patient585: predicted hospital LOS (hours): 20
# 613.661: patient1445: predicted hospital LOS (hours): 69
# 613.683: patient640: predicted hospital LOS (hours): 80.8
# 613.69: patient472: predicted hospital LOS (hours): 58.8
# 614.075: patient864: predicted hospital LOS (hours): 34.8
# 614.184: patient680: predicted hospital LOS (hours): 34.8
# 614.408: patient931: predicted hospital LOS (hours): 62
# 614.442: patient119: predicted hospital LOS (hours): 62.9
# 614.702: patient612: predicted hospital LOS (hours): 59.4
# 615.171: patient1083: predicted hospital LOS (hours): 60.2
# 615.356: patient503: predicted hospital LOS (hours): 15.8
# 616.346: patient338: predicted hospital LOS (hours): 62.3
# 616.374: patient582: predicted hospital LOS (hours): 50.3
# 616.786: patient457: predicted hospital LOS (hours): 67.7
# 617.029: patient822: predicted hospital LOS (hours): 59.8
# 617.046: patient1617: predicted hospital LOS (hours): 30.2
# 617.19: patient737: predicted hospital LOS (hours): 77.2
# 617.244: patient1505: predicted hospital LOS (hours): 47.3
# 618.003: patient675: predicted hospital LOS (hours): 44.2
# 618.218: patient848: predicted hospital LOS (hours): 57.2
# 618.446: patient1038: predicted hospital LOS (hours): 58.6
# 618.508: patient362: predicted hospital LOS (hours): 67.1
# 618.677: patient1049: predicted hospital LOS (hours): 44.8
# 618.968: patient1833: predicted hospital LOS (hours): 66.5
# 619.462: patient1468: predicted hospital LOS (hours): 14.8
# 619.667: patient1008: predicted hospital LOS (hours): 78.2
# 619.855: patient327: predicted hospital LOS (hours): 60.4
# 619.868: patient718: predicted hospital LOS (hours): 52.9
# 620.721: patient22: predicted hospital LOS (hours): 87.4
# 621.432: patient682: predicted hospital LOS (hours): 46.8
# 622.038: patient1082: predicted hospital LOS (hours): 54.7
# 622.58: patient752: predicted hospital LOS (hours): 21.2
# 622.971: patient493: predicted hospital LOS (hours): 55.2
# 623.132: patient542: predicted hospital LOS (hours): 62.5
# 623.397: patient400: predicted hospital LOS (hours): 76.4
# 623.722: patient857: predicted hospital LOS (hours): 11.5
# 624.475: patient508: predicted hospital LOS (hours): 67.7
# 624.569: patient743: predicted hospital LOS (hours): 68
# 624.992: patient747: predicted hospital LOS (hours): 102.5
# 626.653: patient1051: predicted hospital LOS (hours): 59.1
# 627.841: patient891: predicted hospital LOS (hours): 17.9
# 627.85: patient834: predicted hospital LOS (hours): 83.5
# 627.98: patient1264: predicted hospital LOS (hours): 19.4
# 628.316: patient765: predicted hospital LOS (hours): 55.7
# 628.775: patient1116: predicted hospital LOS (hours): 34.8
# 628.883: patient546: predicted hospital LOS (hours): 22.6
# 629.319: patient869: predicted hospital LOS (hours): 147
# 629.799: patient880: predicted hospital LOS (hours): 28.6
# 631.475: patient1496: predicted hospital LOS (hours): 50.2
# 631.533: patient393: predicted hospital LOS (hours): 20.9
# 631.806: patient918: predicted hospital LOS (hours): 21.2
# 632.27: patient1035: predicted hospital LOS (hours): 51.8
# 632.703: patient598: predicted hospital LOS (hours): 46.8
# 632.982: patient1093: predicted hospital LOS (hours): 16.8
# 633.082: patient1618: predicted hospital LOS (hours): 48.9
# 633.357: patient1127: predicted hospital LOS (hours): 64.2
# 633.395: patient751: predicted hospital LOS (hours): 13
# 633.443: patient1721: predicted hospital LOS (hours): 71.5
# 633.738: patient1043: predicted hospital LOS (hours): 64.7
# 633.886: patient497: predicted hospital LOS (hours): 48.1
# 634.163: patient1058: predicted hospital LOS (hours): 31.5
# 634.653: patient879: predicted hospital LOS (hours): 82
# 634.906: patient873: predicted hospital LOS (hours): 35.8
# 635.095: patient841: predicted hospital LOS (hours): 64.8
# 635.587: patient490: predicted hospital LOS (hours): 80.2
# 635.72: patient961: predicted hospital LOS (hours): 68.9
# 635.732: patient1405: predicted hospital LOS (hours): 72.8
# 636.087: patient1655: predicted hospital LOS (hours): 59.1
# 636.276: patient1474: predicted hospital LOS (hours): 25.7
# 637.315: patient1419: predicted hospital LOS (hours): 16.9
# 637.373: patient1167: predicted hospital LOS (hours): 71.8
# 637.507: patient959: predicted hospital LOS (hours): 80.8
# 637.702: patient929: predicted hospital LOS (hours): 57.2
# 637.762: patient818: predicted hospital LOS (hours): 65.3
# 638.169: patient750: predicted hospital LOS (hours): 60.7
# 638.824: patient136: predicted hospital LOS (hours): 324.4
# 639.321: patient441: predicted hospital LOS (hours): 74.3
# 639.328: patient1331: predicted hospital LOS (hours): 66.1
# 640.409: patient1022: predicted hospital LOS (hours): 55.3
# 641.038: patient341: predicted hospital LOS (hours): 73.7
# 641.161: patient574: predicted hospital LOS (hours): 36.1
# 641.217: patient162: predicted hospital LOS (hours): 93.4
# 641.266: patient130: predicted hospital LOS (hours): 94.2
# 641.882: patient469: predicted hospital LOS (hours): 38.1
# 641.9: patient1274: predicted hospital LOS (hours): 56.9
# 642.242: patient628: predicted hospital LOS (hours): 81.3
# 642.32: patient1104: predicted hospital LOS (hours): 75.3
# 642.347: patient897: predicted hospital LOS (hours): 57.2
# 642.368: patient994: predicted hospital LOS (hours): 17.9
# 642.834: patient1671: predicted hospital LOS (hours): 62
# 642.972: patient1280: predicted hospital LOS (hours): 27
# 643.393: patient1064: predicted hospital LOS (hours): 70.7
# 643.405: patient817: predicted hospital LOS (hours): 35
# 644.156: patient1393: predicted hospital LOS (hours): 42.3
# 644.242: patient520: predicted hospital LOS (hours): 86.3
# 644.336: patient1194: predicted hospital LOS (hours): 60.3
# 644.447: patient794: predicted hospital LOS (hours): 67.3
# 644.726: patient1289: predicted hospital LOS (hours): 62.2
# 644.981: patient1513: predicted hospital LOS (hours): 83.4
# 645.996: patient779: predicted hospital LOS (hours): 71.1
# 646.388: patient1277: predicted hospital LOS (hours): 76.4
# 646.46: patient964: predicted hospital LOS (hours): 29.6
# 646.498: patient374: predicted hospital LOS (hours): 62.4
# 646.799: patient734: predicted hospital LOS (hours): 36.1
# 646.93: patient233: predicted hospital LOS (hours): 53.4
# 647.197: patient784: predicted hospital LOS (hours): 18.1
# 647.753: patient1673: predicted hospital LOS (hours): 101
# 648.481: patient1094: predicted hospital LOS (hours): 34.8
# 649.456: patient557: predicted hospital LOS (hours): 74.7
# 649.628: patient395: predicted hospital LOS (hours): 54.9
# 649.656: patient1376: predicted hospital LOS (hours): 46.3
# 649.889: patient1171: predicted hospital LOS (hours): 79.5
# 650.331: patient1633: predicted hospital LOS (hours): 67.9
# 650.412: patient1330: predicted hospital LOS (hours): 96
# 651.185: patient660: predicted hospital LOS (hours): 55.6
# 651.194: patient1743: predicted hospital LOS (hours): 55.7
# 651.296: patient756: predicted hospital LOS (hours): 33.8
# 651.333: patient209: predicted hospital LOS (hours): 62.2
# 652.408: patient504: predicted hospital LOS (hours): 20.3
# 652.526: patient217: predicted hospital LOS (hours): 29
# 652.719: patient733: predicted hospital LOS (hours): 57
# 652.994: patient938: predicted hospital LOS (hours): 39.3
# 653.741: patient876: predicted hospital LOS (hours): 67.7
# 653.762: patient914: predicted hospital LOS (hours): 61.2
# 653.833: patient1500: predicted hospital LOS (hours): 74.5
# 654.129: patient1260: predicted hospital LOS (hours): 72.8
# 655.168: patient946: predicted hospital LOS (hours): 53
# ...
# 1346.08: patient3774: predicted hospital LOS (hours): 66.8
# 1346.81: patient3393: predicted hospital LOS (hours): 83.6
# 1347.17: patient3501: predicted hospital LOS (hours): 50.9
# 1347.27: patient3287: predicted hospital LOS (hours): 52.2
# 1347.36: patient3588: predicted hospital LOS (hours): 78.2
# 1347.4: patient3001: predicted hospital LOS (hours): 85.5
# 1347.41: patient2286: predicted hospital LOS (hours): 46.9
# 1347.58: patient2741: predicted hospital LOS (hours): 21.1
# 1348.15: patient3064: predicted hospital LOS (hours): 42.4
# 1348.45: patient3513: predicted hospital LOS (hours): 22.9
# 1349.42: patient2888: predicted hospital LOS (hours): 51.9
# 1349.79: patient824: predicted hospital LOS (hours): 39.5
# 1350.02: patient2921: predicted hospital LOS (hours): 72.6
# 1351.49: patient1786: predicted hospital LOS (hours): 50.7
# 1351.58: patient3118: predicted hospital LOS (hours): 68.9
# 1352.04: patient3104: predicted hospital LOS (hours): 59.1
# 1352.67: patient3336: predicted hospital LOS (hours): 85.2
# 1353.49: patient3800: predicted hospital LOS (hours): 68.5
# 1353.64: patient3828: predicted hospital LOS (hours): 52.4
# 1353.81: patient3222: predicted hospital LOS (hours): 85.7
# 1354.95: patient2515: predicted hospital LOS (hours): 55.7
# 1355.02: patient3586: predicted hospital LOS (hours): 56.6
# 1355.53: patient2758: predicted hospital LOS (hours): 121.1
# 1355.97: patient2162: predicted hospital LOS (hours): 42.1
# 1356.29: patient2814: predicted hospital LOS (hours): 44.6
# 1356.55: patient3564: predicted hospital LOS (hours): 22.7
# 1356.83: patient3547: predicted hospital LOS (hours): 49.9
# 1357.41: patient3145: predicted hospital LOS (hours): 69
# 1357.59: patient3713: predicted hospital LOS (hours): 33.7
# 1357.74: patient3986: predicted hospital LOS (hours): 29
# 1357.74: patient2692: predicted hospital LOS (hours): 74.2
# 1358.17: patient2122: predicted hospital LOS (hours): 42.7
# 1358.41: patient1825: predicted hospital LOS (hours): 79.5
# 1358.7: patient3351: predicted hospital LOS (hours): 299.9
# 1359.16: patient3646: predicted hospital LOS (hours): 61.7
# 1359.95: patient3445: predicted hospital LOS (hours): 94.5
# 1360.15: patient2314: predicted hospital LOS (hours): 30.8
# 1360.29: patient3121: predicted hospital LOS (hours): 29.1
# 1360.96: patient882: predicted hospital LOS (hours): 41.9
# 1361.22: patient3936: predicted hospital LOS (hours): 76.7
# 1361.49: patient3086: predicted hospital LOS (hours): 64.6
# 1361.67: patient3304: predicted hospital LOS (hours): 42.8
# 1362.03: patient3604: predicted hospital LOS (hours): 70.4
# 1362.61: patient1690: predicted hospital LOS (hours): 43
# 1362.71: patient3773: predicted hospital LOS (hours): 80
# 1362.76: patient2034: predicted hospital LOS (hours): 63.9
# 1363.12: patient3481: predicted hospital LOS (hours): 80.6
# 1363.13: patient2749: predicted hospital LOS (hours): 45.1
# 1363.98: patient2984: predicted hospital LOS (hours): 62.9
# 1364.75: patient2919: predicted hospital LOS (hours): 68.5
# 1364.98: patient2751: predicted hospital LOS (hours): 49.9
# 1365.1: patient2553: predicted hospital LOS (hours): 45.3
# 1365.19: patient3682: predicted hospital LOS (hours): 55.3
# 1365.61: patient2856: predicted hospital LOS (hours): 39.6
# 1365.64: patient3652: predicted hospital LOS (hours): 62.9
# 1366.24: patient3355: predicted hospital LOS (hours): 36.9
# 1366.24: patient1774: predicted hospital LOS (hours): 75.6
# 1366.73: patient3772: predicted hospital LOS (hours): 102.7
# 1367.5: patient2611: predicted hospital LOS (hours): 63.3
# 1367.56: patient3597: predicted hospital LOS (hours): 73.4
# 1367.69: patient2382: predicted hospital LOS (hours): 56.6
# 1367.95: patient3382: predicted hospital LOS (hours): 38.8
# 1368.28: patient3296: predicted hospital LOS (hours): 61.3
# 1368.98: patient1778: predicted hospital LOS (hours): 68.1
# 1369.28: patient3137: predicted hospital LOS (hours): 74.6
# 1369.38: patient2645: predicted hospital LOS (hours): 61.5
# 1369.85: patient3401: predicted hospital LOS (hours): 74.6
# 1369.92: patient2307: predicted hospital LOS (hours): 72.4
# 1369.99: patient3548: predicted hospital LOS (hours): 93.1
# 1371.22: patient3292: predicted hospital LOS (hours): 63.7
# 1371.33: patient3712: predicted hospital LOS (hours): 42.8
# 1371.62: patient2914: predicted hospital LOS (hours): 52.1
# 1371.74: patient3657: predicted hospital LOS (hours): 75.1
# 1372.09: patient3129: predicted hospital LOS (hours): 43.8
# 1372.64: patient2777: predicted hospital LOS (hours): 46.1
# 1372.67: patient114: predicted hospital LOS (hours): 13.6
# 1373.14: patient2694: predicted hospital LOS (hours): 74.2
# 1373.4: patient3623: predicted hospital LOS (hours): 16.8
# 1373.58: patient3416: predicted hospital LOS (hours): 22.9
# 1373.93: patient3532: predicted hospital LOS (hours): 62.9
# 1374.43: patient3029: predicted hospital LOS (hours): 100.3
# 1374.44: patient3493: predicted hospital LOS (hours): 40.9
# 1374.51: patient1951: predicted hospital LOS (hours): 17.5
# 1374.6: patient3932: predicted hospital LOS (hours): 31.5
# 1375.16: patient3699: predicted hospital LOS (hours): 61.3
# 1375.25: patient2933: predicted hospital LOS (hours): 74.9
# 1375.3: patient843: predicted hospital LOS (hours): 71.6
# 1375.56: patient3407: predicted hospital LOS (hours): 47.7
# 1377.09: patient3495: predicted hospital LOS (hours): 44.1
# 1377.85: patient3602: predicted hospital LOS (hours): 28.1
# 1378.62: patient1025: predicted hospital LOS (hours): 43
# 1379.56: patient3587: predicted hospital LOS (hours): 33.1
# 1380.55: patient3430: predicted hospital LOS (hours): 25.8
# 1380.64: patient3554: predicted hospital LOS (hours): 114.4
# 1380.8: patient3123: predicted hospital LOS (hours): 65.8
# 1380.91: patient2674: predicted hospital LOS (hours): 61.2
# 1381.7: patient3635: predicted hospital LOS (hours): 76.1
# 1381.92: patient2700: predicted hospital LOS (hours): 47.7
# 1383.05: patient2964: predicted hospital LOS (hours): 64.4
# 1383.76: patient3017: predicted hospital LOS (hours): 77.2
# 1383.94: patient3447: predicted hospital LOS (hours): 80.6
# 1384.32: patient311: predicted hospital LOS (hours): 21.5
# 1384.73: patient2585: predicted hospital LOS (hours): 18.8
# 1385: patient3526: predicted hospital LOS (hours): 54.4
# 1385.15: patient4092: predicted hospital LOS (hours): 68.1
# 1385.19: patient3464: predicted hospital LOS (hours): 71.1
# 1385.85: patient3976: predicted hospital LOS (hours): 83.6
# 1386.53: patient2381: predicted hospital LOS (hours): 59.4
# 1386.54: patient3421: predicted hospital LOS (hours): 49.6
# 1386.96: patient2542: predicted hospital LOS (hours): 257.3
# 1387.53: patient3750: predicted hospital LOS (hours): 30.5
# 1387.65: patient4081: predicted hospital LOS (hours): 39.1
# 1388.44: patient3683: predicted hospital LOS (hours): 102.1
# 1388.69: patient3286: predicted hospital LOS (hours): 57.1
# 1388.79: patient3045: predicted hospital LOS (hours): 50.9
# 1389.37: patient3575: predicted hospital LOS (hours): 85.2
# 1389.78: patient3855: predicted hospital LOS (hours): 82.6
# 1389.78: patient3703: predicted hospital LOS (hours): 37.2
# 1390.22: patient3424: predicted hospital LOS (hours): 64.3
# 1390.46: patient3026: predicted hospital LOS (hours): 76.3
# 1391.94: patient3521: predicted hospital LOS (hours): 71.6
# 1392: patient3627: predicted hospital LOS (hours): 58.2
# 1392.04: patient3061: predicted hospital LOS (hours): 58.2
# 1392.34: patient3150: predicted hospital LOS (hours): 61.6
# 1392.77: patient2934: predicted hospital LOS (hours): 36.3
# 1392.83: patient2521: predicted hospital LOS (hours): 30.2
# 1392.92: patient2915: predicted hospital LOS (hours): 35
# 1393.2: patient3284: predicted hospital LOS (hours): 68.9
# 1393.34: patient3850: predicted hospital LOS (hours): 79.8
# 1393.83: patient3092: predicted hospital LOS (hours): 72.8
# 1394.21: patient3968: predicted hospital LOS (hours): 51.3
# 1394.51: patient2167: predicted hospital LOS (hours): 72.7
# 1394.66: patient2584: predicted hospital LOS (hours): 93.4
# 1395.58: patient3534: predicted hospital LOS (hours): 62.1
# 1395.65: patient4287: predicted hospital LOS (hours): 26.8
# 1395.69: patient1931: predicted hospital LOS (hours): 78.6
# 1396.74: patient4122: predicted hospital LOS (hours): 24.6
# 1396.75: patient2860: predicted hospital LOS (hours): 77.8
# 1396.95: patient3620: predicted hospital LOS (hours): 75.7
# 1397.26: patient2607: predicted hospital LOS (hours): 27.2
# 1397.31: patient2709: predicted hospital LOS (hours): 97.2
# 1397.46: patient2456: predicted hospital LOS (hours): 80.2
# 1397.46: patient2470: predicted hospital LOS (hours): 228
# 1397.96: patient3549: predicted hospital LOS (hours): 47.4
# 1398.04: patient3594: predicted hospital LOS (hours): 64.2
# 1398.19: patient3533: predicted hospital LOS (hours): 191.1
# 1398.31: patient3289: predicted hospital LOS (hours): 112.5
# 1398.38: patient3695: predicted hospital LOS (hours): 71.4
# 1398.45: patient3856: predicted hospital LOS (hours): 93.5
# 1398.91: patient2383: predicted hospital LOS (hours): 27.8
# 1398.93: patient3468: predicted hospital LOS (hours): 67.4
# 1399.33: patient2556: predicted hospital LOS (hours): 63.2
# 1400.48: patient2969: predicted hospital LOS (hours): 91.2
# 1401.12: patient3491: predicted hospital LOS (hours): 24.9
# 1401.16: patient3460: predicted hospital LOS (hours): 71.8
# 1401.27: patient3392: predicted hospital LOS (hours): 87.8
# 1401.58: patient4033: predicted hospital LOS (hours): 21.7
# 1401.59: patient3200: predicted hospital LOS (hours): 62
# 1401.72: patient3628: predicted hospital LOS (hours): 71.4
# 1401.85: patient3070: predicted hospital LOS (hours): 67.8
# 1402.13: patient3596: predicted hospital LOS (hours): 87.6
# 1402.14: patient2486: predicted hospital LOS (hours): 46.8
# 1402.19: patient4002: predicted hospital LOS (hours): 58.7
# 1402.26: patient3227: predicted hospital LOS (hours): 70
# 1402.41: patient3845: predicted hospital LOS (hours): 63.5
# 1402.79: patient3257: predicted hospital LOS (hours): 37.4
# 1402.82: patient3231: predicted hospital LOS (hours): 16.2
# 1402.92: patient3585: predicted hospital LOS (hours): 45.3
# 1403.15: patient3709: predicted hospital LOS (hours): 10.5
# 1403.31: patient3542: predicted hospital LOS (hours): 89.3
# 1403.51: patient3686: predicted hospital LOS (hours): 47
# 1403.76: patient3563: predicted hospital LOS (hours): 74.7
# 1403.86: patient3824: predicted hospital LOS (hours): 73
# 1403.91: patient3894: predicted hospital LOS (hours): 99.5
# 1404.03: patient3798: predicted hospital LOS (hours): 79.8
# 1404.85: patient4042: predicted hospital LOS (hours): 65.2
# 1405.55: patient2776: predicted hospital LOS (hours): 47.2
# 1405.58: patient3700: predicted hospital LOS (hours): 62.6
# 1405.65: patient3403: predicted hospital LOS (hours): 76
# 1406.09: patient1569: predicted hospital LOS (hours): 72.5
# 1406.27: patient3967: predicted hospital LOS (hours): 42.2
# 1406.58: patient3417: predicted hospital LOS (hours): 28.3
# 1406.79: patient2277: predicted hospital LOS (hours): 65.1
# 1407.29: patient2938: predicted hospital LOS (hours): 68.9
# 1407.47: patient3637: predicted hospital LOS (hours): 59
# 1407.52: patient2870: predicted hospital LOS (hours): 27.1
# 1407.53: patient3881: predicted hospital LOS (hours): 58.4
# 1408.21: patient3451: predicted hospital LOS (hours): 94
# 1408.44: patient2857: predicted hospital LOS (hours): 25
# 1409.24: patient3595: predicted hospital LOS (hours): 98.1
# 1409.63: patient3244: predicted hospital LOS (hours): 63.7
# 1409.87: patient3866: predicted hospital LOS (hours): 41.1
# 1410.18: patient2661: predicted hospital LOS (hours): 19.5
# 1410.71: patient3305: predicted hospital LOS (hours): 30.1
# 1410.95: patient3930: predicted hospital LOS (hours): 101.2
# 1411.14: patient3148: predicted hospital LOS (hours): 78.6
# 1411.28: patient3726: predicted hospital LOS (hours): 78.1
# 1411.53: patient2566: predicted hospital LOS (hours): 67.1
# 1412.98: patient3506: predicted hospital LOS (hours): 68.7
# 1413.13: patient3310: predicted hospital LOS (hours): 37.1
# 1413.31: patient3111: predicted hospital LOS (hours): 54.7
# 1413.57: patient2452: predicted hospital LOS (hours): 18.7
# 1413.71: patient3702: predicted hospital LOS (hours): 58.7
# 1414.42: patient1576: predicted hospital LOS (hours): 19.8
# 1415.57: patient3365: predicted hospital LOS (hours): 24.2
# 1415.61: patient2098: predicted hospital LOS (hours): 50.2
# 1416.11: patient3605: predicted hospital LOS (hours): 59.4
# 1416.11: patient3822: predicted hospital LOS (hours): 86.3
# 1416.44: patient3917: predicted hospital LOS (hours): 82.9
# 1416.88: patient2908: predicted hospital LOS (hours): 79.3
# 1417.62: patient3402: predicted hospital LOS (hours): 113.5
# 1418.29: patient3360: predicted hospital LOS (hours): 19.7
# 1418.79: patient3185: predicted hospital LOS (hours): 67.3
# 1419.17: patient3617: predicted hospital LOS (hours): 54
# 1419.37: patient3741: predicted hospital LOS (hours): 15.6
# 1420.04: patient2285: predicted hospital LOS (hours): 18.6
# 1420.26: patient3928: predicted hospital LOS (hours): 76.3
# 1420.33: patient3277: predicted hospital LOS (hours): 51.7
# 1420.77: patient4041: predicted hospital LOS (hours): 97.8
# 1421.33: patient3651: predicted hospital LOS (hours): 40.8
# 1422.01: patient4090: predicted hospital LOS (hours): 49.3
# 1422.08: patient4182: predicted hospital LOS (hours): 78.1
# 1422.19: patient2911: predicted hospital LOS (hours): 88
# 1422.35: patient2955: predicted hospital LOS (hours): 45.8
# 1423.39: patient3197: predicted hospital LOS (hours): 31.6
# 1423.56: patient3524: predicted hospital LOS (hours): 15.6
# 1423.7: patient3256: predicted hospital LOS (hours): 58.9
# 1423.85: patient2330: predicted hospital LOS (hours): 137.5
# 1423.88: patient3443: predicted hospital LOS (hours): 92.1
# 1424.16: patient1457: predicted hospital LOS (hours): 32.6
# 1425.11: patient3842: predicted hospital LOS (hours): 56.7
# 1425.34: patient3643: predicted hospital LOS (hours): 83.9
# 1425.4: patient3540: predicted hospital LOS (hours): 57.3
# 1425.73: patient3116: predicted hospital LOS (hours): 79.3
# 1426.09: patient3470: predicted hospital LOS (hours): 119.3
# 1426.27: patient2513: predicted hospital LOS (hours): 16.6
# 1426.7: patient3440: predicted hospital LOS (hours): 20.6
# 1427.44: patient4202: predicted hospital LOS (hours): 82.4
# 1427.46: patient3183: predicted hospital LOS (hours): 72.7
# 1428.23: patient3719: predicted hospital LOS (hours): 62.7
# 1428.23: patient3725: predicted hospital LOS (hours): 41.7
# 1428.36: patient1905: predicted hospital LOS (hours): 55.4
# 1428.6: patient3833: predicted hospital LOS (hours): 88.8
# 1428.75: patient3642: predicted hospital LOS (hours): 41.9
# 1428.78: patient2750: predicted hospital LOS (hours): 79.2
# 1429.46: patient3507: predicted hospital LOS (hours): 40
# 1430.07: patient3405: predicted hospital LOS (hours): 15
# 1430.15: patient3736: predicted hospital LOS (hours): 124.4
# 1431.64: patient3701: predicted hospital LOS (hours): 48.7
# 1432.09: patient3885: predicted hospital LOS (hours): 65.2
# 1432.1: patient1572: predicted hospital LOS (hours): 61
# 1432.27: patient3356: predicted hospital LOS (hours): 57.7
# 1433.77: patient2437: predicted hospital LOS (hours): 54.5
# 1434.44: patient3220: predicted hospital LOS (hours): 27.4
# 1434.45: patient3007: predicted hospital LOS (hours): 57.4
# 1434.47: patient3311: predicted hospital LOS (hours): 51.3
# 1434.56: patient3141: predicted hospital LOS (hours): 75.6
# 1435.05: patient3059: predicted hospital LOS (hours): 33.2
# 1435.81: patient3321: predicted hospital LOS (hours): 68.3
# 1436.02: patient3955: predicted hospital LOS (hours): 68.7
# 1436.66: patient3235: predicted hospital LOS (hours): 84.5
# 1436.73: patient4505: predicted hospital LOS (hours): 26.6
# 1437.02: patient3677: predicted hospital LOS (hours): 98.5
# 1437.38: patient1470: predicted hospital LOS (hours): 57.6
# 1437.75: patient3019: predicted hospital LOS (hours): 51.2
# 1438.24: patient4043: predicted hospital LOS (hours): 75.4
# 1439.83: patient3972: predicted hospital LOS (hours): 90.4
# simmer environment: ED Simulation V1 | now: 1440 | next: 1440.04827605435
# { Monitor: in memory }
# { Resource: ed_bed | monitored: TRUE | server status: 1406(Inf) | queue status: 0(Inf) }
# { Source: patient | monitored: 2 | n_generated: 4684 }
# [1] 1440

# %% [markdown]
# Extract Results

# %%
# Get monitoring data
arrivals <- get_mon_arrivals(ed_sim)
resources <- get_mon_resources(ed_sim)

# Quick summary
summary(arrivals$activity_time)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   18.78  236.00  333.50  365.36  464.00 1297.03

# %%
# predicted hosp LOS
head(hospital_los_log)
# Out:
#   patient_id pred_hosp_los
# 1 1          72.50734
# 2 2          49.73247
# 3 3          63.37629
# 4 4          24.47674
# 5 5          79.72897
# 6 6          82.77594

# %% [markdown]
# Visualizations

# %%
# Plot resource usage over time
plot(resources, metric = "usage")

# Plot resource utilization
plot(resources, metric = "utilization")

# Histogram of length of stay
ggplot(arrivals, aes(x = activity_time)) +
  geom_histogram(bins = 30, fill = "steelblue", color = "white") +
  geom_vline(aes(xintercept = mean(activity_time)), 
             color = "red", linetype = "dashed", size = 1) +
  geom_vline(aes(xintercept = quantile(activity_time, 0.80)), 
             color = "orange", linetype = "dashed", size = 1) +
  labs(
    title = "Distribution of Length of Stay",
    subtitle = "Red = mean, Orange = 80th percentile",
    x = "LOS (minutes)",
    y = "Count"
  ) +
  theme_minimal()
# Out:
# plot without title
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title
# plot without title
